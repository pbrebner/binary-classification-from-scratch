# %% [markdown]
# # Task 1: Acquire, Preprocess, and Analyze the Data
#
#
# ## DataSet Analysis - White Wine Quality DataSet
#
# Link:https://archive.ics.uci.edu/ml/datasets/Wine+Quality
#
# Note: Only the white wine dataset will be used. The dataset includes 12 features with the values being a ranking from 1-10. In order to keep the classification binary, I will set qualities equal to or greater than 6 as good wine (value of 1) and any other quality value as bad wine (value of 0)
#
# The important results of this analysis are reported in the writeup.pdf

# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
# Load the Red Wines dataset using pandas
URL = "https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv"
data = pd.read_csv(URL, sep =';')

# Display top results
data.head(20)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.0              0.27         0.36           20.70      0.045
# 1             6.3              0.30         0.34            1.60      0.049
# 2             8.1              0.28         0.40            6.90      0.050
# 3             7.2              0.23         0.32            8.50      0.058
# 4             7.2              0.23         0.32            8.50      0.058
# 5             8.1              0.28         0.40            6.90      0.050
# 6             6.2              0.32         0.16            7.00      0.045
# 7             7.0              0.27         0.36           20.70      0.045
# 8             6.3              0.30         0.34            1.60      0.049
# 9             8.1              0.22         0.43            1.50      0.044
# 10            8.1              0.27         0.41            1.45      0.033
# 11            8.6              0.23         0.40            4.20      0.035
# 12            7.9              0.18         0.37            1.20      0.040
# 13            6.6              0.16         0.40            1.50      0.044
# 14            8.3              0.42         0.62           19.25      0.040
# 15            6.6              0.17         0.38            1.50      0.032
# 16            6.3              0.48         0.04            1.10      0.046
# 17            6.2              0.66         0.48            1.20      0.029
# 18            7.4              0.34         0.42            1.10      0.033
# 19            6.5              0.31         0.14            7.50      0.044
#
#     free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                  45.0                 170.0   1.0010  3.00       0.45
# 1                  14.0                 132.0   0.9940  3.30       0.49
# 2                  30.0                  97.0   0.9951  3.26       0.44
# 3                  47.0                 186.0   0.9956  3.19       0.40
# 4                  47.0                 186.0   0.9956  3.19       0.40
# 5                  30.0                  97.0   0.9951  3.26       0.44
# 6                  30.0                 136.0   0.9949  3.18       0.47
# 7                  45.0                 170.0   1.0010  3.00       0.45
# 8                  14.0                 132.0   0.9940  3.30       0.49
# 9                  28.0                 129.0   0.9938  3.22       0.45
# 10                 11.0                  63.0   0.9908  2.99       0.56
# 11                 17.0                 109.0   0.9947  3.14       0.53
# 12                 16.0                  75.0   0.9920  3.18       0.63
# 13                 48.0                 143.0   0.9912  3.54       0.52
# 14                 41.0                 172.0   1.0002  2.98       0.67
# 15                 28.0                 112.0   0.9914  3.25       0.55
# 16                 30.0                  99.0   0.9928  3.24       0.36
# 17                 29.0                  75.0   0.9892  3.33       0.39
# 18                 17.0                 171.0   0.9917  3.12       0.53
# 19                 34.0                 133.0   0.9955  3.22       0.50
#
#     alcohol  quality
# 0       8.8        6
# 1       9.5        6
# 2      10.1        6
# 3       9.9        6
# 4       9.9        6
# 5      10.1        6
# 6       9.6        6
# 7       8.8        6
# 8       9.5        6
# 9      11.0        6
# 10     12.0        5
# 11      9.7        5
# 12     10.8        5
# 13     12.4        7
# 14      9.7        5
# 15     11.4        7
# 16      9.6        6
# 17     12.8        8
# 18     11.3        6
# 19      9.5        5

# %%
# Change Quality Values to 1 (good wine) or 0 (bad wine)
data["quality"] = 1*(data["quality"]>5)

print(data["quality"])
data.head(10)
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 4893    1
# 4894    0
# 4895    1
# 4896    1
# 4897    1
# Name: quality, Length: 4898, dtype: int32
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
# 6            6.2              0.32         0.16             7.0      0.045
# 7            7.0              0.27         0.36            20.7      0.045
# 8            6.3              0.30         0.34             1.6      0.049
# 9            8.1              0.22         0.43             1.5      0.044
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
# 5                 30.0                  97.0   0.9951  3.26       0.44
# 6                 30.0                 136.0   0.9949  3.18       0.47
# 7                 45.0                 170.0   1.0010  3.00       0.45
# 8                 14.0                 132.0   0.9940  3.30       0.49
# 9                 28.0                 129.0   0.9938  3.22       0.45
#
#    alcohol  quality
# 0      8.8        1
# 1      9.5        1
# 2     10.1        1
# 3      9.9        1
# 4      9.9        1
# 5     10.1        1
# 6      9.6        1
# 7      8.8        1
# 8      9.5        1
# 9     11.0        1

# %%
#Note above the displayed length is the total number of wines
#Get some basic statistics of the data
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# min       0.009000             2.000000              9.000000     0.987110
# 25%       0.036000            23.000000            108.000000     0.991723
# 50%       0.043000            34.000000            134.000000     0.993740
# 75%       0.050000            46.000000            167.000000     0.996100
# max       0.346000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.514267     0.665169
# std       0.151001     0.114126     1.230621     0.471979
# min       2.720000     0.220000     8.000000     0.000000
# 25%       3.090000     0.410000     9.500000     0.000000
# 50%       3.180000     0.470000    10.400000     1.000000
# 75%       3.280000     0.550000    11.400000     1.000000
# max       3.820000     1.080000    14.200000     1.000000

# %%
 # Get the Number of wines with good and bad quality
    
wine_good = data.loc[(data['quality'] == 1)] 
number_of_good_wine = wine_good.shape[0]

wine_bad = data.loc[(data['quality'] == 0)]
number_of_bad_wine = wine_bad.shape[0]

print("Total Number of Wines = " + str(number_of_good_wine + number_of_bad_wine))
print("Number of Good Quality Wines = " + str(number_of_good_wine))
print("Number of Bad Quality Wines = " + str(number_of_bad_wine))
# Out:
# Total Number of Wines = 4898
# Number of Good Quality Wines = 3258
# Number of Bad Quality Wines = 1640

# %%
#Percentage of Good to Bad
Percentage_of_Good = (number_of_good_wine/(number_of_bad_wine+number_of_good_wine))*100

print("Percentage of Good Quality Wines = " + str(int(Percentage_of_Good)) + '%')
# Out:
# Percentage of Good Quality Wines = 66%

# %%
#Plot the Distributions of the features
for data.column in data:
    sns.displot(data[data.column])

# %%
#Correlation between Features
corr = data.corr()

plt.figure(figsize=(12,10))
sns.heatmap(corr, annot=True, linewidths=0.5, linecolor="white")
# Out:
# <AxesSubplot:>

# %%
#Scatter Plot of Pair Wise Features
Scatter = sns.pairplot(data, hue = "quality")

#Need to reduce this to smaller subsets of features as this plot is difficult to gain much insight from with this number of features

# %%
# Distributions for Good and Bad Wines
good = data['quality'] == 1
good_data = data[good]
bad = data['quality'] == 0
bad_data = data[bad]

# %%
#Correlation for good results
good_corr = good_data.corr()

plt.figure(figsize=(12,10))
sns.heatmap(good_corr, annot=True, linewidths=0.5, linecolor="white")
# Out:
# <AxesSubplot:>

# %%
#Correlation for negative results
bad_corr = bad_data.corr()

plt.figure(figsize=(12,10))
sns.heatmap(bad_corr, annot=True, linewidths=0.5, linecolor="white")
# Out:
# <AxesSubplot:>

# %%
#Distribution of the good vs bad

sns.histplot(good_data['fixed acidity'], color = 'b', kde=True)
sns.histplot(bad_data['fixed acidity'], color = 'r', kde=True)
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='Count'>

# %%
sns.histplot(good_data['volatile acidity'], color = 'b', kde=True)
sns.histplot(bad_data['volatile acidity'], color = 'r', kde=True)
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='Count'>

# %%
sns.histplot(good_data['citric acid'], color = 'b', kde=True)
sns.histplot(bad_data['citric acid'], color = 'r', kde=True)
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='Count'>

# %%
sns.histplot(good_data['residual sugar'], color = 'b', kde=True)
sns.histplot(bad_data['residual sugar'], color = 'r', kde=True)
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='Count'>

# %%
sns.histplot(good_data['chlorides'], color = 'b', kde=True)
sns.histplot(bad_data['chlorides'], color = 'r', kde=True)
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='Count'>

# %%
sns.histplot(good_data['free sulfur dioxide'], color = 'b', kde=True)
sns.histplot(bad_data['free sulfur dioxide'], color = 'r', kde=True)
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='Count'>

# %%
sns.histplot(good_data['total sulfur dioxide'], color = 'b', kde=True)
sns.histplot(bad_data['total sulfur dioxide'], color = 'r', kde=True)
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='Count'>

# %%
sns.histplot(good_data['density'], color = 'b', kde=True)
sns.histplot(bad_data['density'], color = 'r', kde=True)
# Out:
# <AxesSubplot:xlabel='density', ylabel='Count'>

# %%
sns.histplot(good_data['pH'], color = 'b', kde=True)
sns.histplot(bad_data['pH'], color = 'r', kde=True)
# Out:
# <AxesSubplot:xlabel='pH', ylabel='Count'>

# %%
sns.histplot(good_data['alcohol'], color = 'b', kde=True)
sns.histplot(bad_data['alcohol'], color = 'r',kde=True)
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Count'>

# %%
sns.histplot(good_data['sulphates'], color = 'b', kde=True)
sns.histplot(bad_data['sulphates'], color = 'r', kde=True)
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='Count'>

# %%
# Split Data between Training and Test Data (80/20 split)
# Needs to be randomly split

#Create Copy of Data Set and Then create training set and test set
data_copy = data.copy()
train_set = data_copy.sample(frac=0.80, random_state=0)
test_set = data_copy.drop(train_set.index)
          
x_train = np.array(train_set.iloc[:, :-1], dtype = float)
y_train = np.array(train_set["quality"], dtype = int)
          
x_test = np.array(test_set.iloc[:, :-1], dtype = float)
y_test = np.array(test_set["quality"], dtype = int)

print("x_train size: ", x_train.shape)
print("y_train size: ", y_train.shape)
print("x_test size: ", x_test.shape)
print("y_test size: ", y_test.shape)
# Out:
# x_train size:  (3918, 11)
# y_train size:  (3918,)
# x_test size:  (980, 11)
# y_test size:  (980,)

# %%
#Normalize the Data

x_test_mean = np.mean(x_test, axis = 0)
x_test_std = np.std(x_test, axis = 0)

#np.seterr(divide='ignore', invalid='ignore')
x_test = (x_test - x_test_mean)/x_test_std


x_train_mean = np.mean(x_train, axis = 0)
#print(x_train_mean)
x_train_std = np.std(x_train, axis = 0)
#print(x_train_std)

#np.seterr(divide='ignore', invalid='ignore')
x_train = (x_train - x_train_mean)/x_train_std
#print(x_train[:10,:])

print("x_train size: ", x_train.shape)
print("x_test size: ", x_test.shape)
# Out:
# x_train size:  (3918, 11)
# x_test size:  (980, 11)

# %% [markdown]
# ## Task 2 - Implement the Model
#
# ### Logistic Regression from Scratch

# %%
class LogisticRegression:

    def __init__(self, intercept = True): 
        #self.num_steps = num_steps
        #self.leaning_rate = learning_rate
        #self.error_rate = error_rate
        self.intercept = intercept

    
    def add_intercept(self, X):
        intercept = np.ones((X.shape[0],1))
        return np.concatenate((intercept,X), axis = 1)
    
    def sigmoid(self, z):
        return 1/(1 + np.exp(-z))
                  
                  
    def cost_function(self, X, y, w): #Cross Entropy Loss Function
        N,D = X.shape
        z = np.dot(X, w)
        
        J = np.mean(y * np.log1p(np.exp(-z)) + (1-y) * np.log1p(np.exp(z)))
        grad = np.dot(X.T,(self.sigmoid(z) - y)) / N
        
        return grad, J
    
                  
    def gradient_descent(self, X, y, num_steps, learning_rate, min_error):
        # Min error is just the early termination requirement (Set up as Small change is objective right now)
        N,D = X.shape
        w = np.zeros(D)
        grad, J_previous = self.cost_function(X, y, w)
        
        for i in range(num_steps):
                grad, J = self.cost_function(X, y, w)
                w = w - (learning_rate * grad)
                
                if np.linalg.norm(grad) < min_error:
                #if np.abs(J - J_previous) < min_error: # Need to determine the best way to determine the early stopping point
                    break
                else:
                    J_previous = J
                  
        print("Number of Iterations = " + str(i))
        print("Minimum Cost (J) = " + str(J))          
        return w, J

    
    def fit(self, X, y, num_steps, learning_rate, min_error): #Logistic regression and Gradient Descent (Input is X and y, outputs weights of model)
        if self.intercept == True:
            X = self.add_intercept(X)
            
        
        #Gradient function
        w, J = self.gradient_descent(X, y, num_steps, learning_rate, min_error)
        
        print("Weights of Model: ", w)
        return w
    
    def predict(self, X, w): #Ouput is the predicted values for y
        if self.intercept == True:
            X = self.add_intercept(X)
        
        y_pred = self.sigmoid(np.dot(X, w))
        y_pred = y_pred.round() #Rounds the value to 1 or 0
        
        #print("y_pred Shape")
        #print(y_pred.shape)
        return y_pred
    
    def evaluate_acc(self, y, y_pred):
        #Accuracy = (TP + TN)/ P + N
        #Error Rate = (FP + FN)/P + N
        #Precision = TP/RP
        #Recall = TP/P
        
        A = (np.mean(y_pred == y))*100
        #print(A)
        
        #Alternatively
        TP, TN, FN, FP = 0,0,0,0
        for i in range(len(y_pred)):
            if (y[i] == y_pred[i]) & (y_pred[i] == 1):
                TP = TP + 1
            if (y[i] != y_pred[i]) & (y_pred[i] == 1):
                FP = FP + 1
            if (y[i] == y_pred[i]) & (y_pred[i] == 0):
                TN = TN + 1
            if (y[i] != y_pred[i]) & (y_pred[i] == 0):
                FN = FN + 1
        
        # Determine accuracy, error rate, precision and recall
        N = TN + FP
        RP = TP + FP
        RN = TN + FN
        P = TP + FN
        
        accuracy = ((TP + TN) / (P + N))*100
        errorRate = ((FP + FN) / (P + N))*100
        try:  
            precision = (TP / (RP))*100
        except:
            print('Error: Divide by Zero')
            precision = np.nan
        try:
            recall = (TP / (P))*100
        except:
            print('Error: Divide by Zero')
            recall = np.nan


        print("Accuracy: ", accuracy, "%")
        print("Error Rate: ", errorRate, "%")
        print("Precision: ", precision, "%")
        print("Recall: ", recall, "% \n")
        
        return A

# %% [markdown]
# ### Naive Bayes from Scratch

# %%
class NaiveBayes:
    
    def __init__(self):
        pass

    def fit(self, X, y):
        #X here is an array where the rows are the samples and the columns are the features
        n_instances, n_features = X.shape
        
        #We find the number of classes
        self._classes = np.unique(y)
        n_classes = len(self._classes)

        # We compute the  mean, var, and prior for each class
        self._mean = np.zeros((n_classes, n_features), dtype= float)
        self._var = np.zeros((n_classes, n_features), dtype= float)
        
        # For each class we want one prior
        self._priors =  np.zeros(n_classes, dtype = float)

        for c in self._classes:
            #we select the samples that have the class c as an ouput and calculate mean and variance
            X_class = X[y == c]
            self._mean[c,:] = np.mean(X_class, axis=0)
            self._var[c,:] = np.var(X_class, axis=0)
            # we compute the frequency of the class
            # X_class.shape[0] returns the number of samples with Xc as a sample for the class c
            self._priors[c] = X_class.shape[0] / float(n_instances)

    def predict(self, X):
        ypred = [self._predict(x) for x in X]
        #print(ypred)
        return ypred

    def _predict(self, x):
        posteriors = []

        # compute the posterior probability for each class
        #we go through each class
        for c in self._classes:
            prior = np.log(self._priors[c])
            class_likelihood = np.sum(np.log(self._pdf(c, x)))
            posterior = prior + class_likelihood
            posteriors.append(posterior)
            
        # return class with highest posterior probability
        #print(class_likelihood)
        #print(posteriors)
        return self._classes[np.argmax(posteriors)]
            
       # compute the probability density function, we model the class conditional probability with a Gaussian distribution 
    def _pdf(self, class_idx, x):
        mean = self._mean[class_idx]
        var = self._var[class_idx]
        num = np.exp(- (x-mean)**2 / (2 * var))
        den = np.sqrt(2 * np.pi * var)
        return num / den
    
    def evaluate_acc(self, y, y_pred):
        #Accuracy = (TP + TN)/ P + N
        
        A = (np.mean(y_pred == y))*100
        #print(A)
        
        #Alternatively
        TP, TN, FN, FP = 0,0,0,0
        for i in range(len(y_pred)):
            if (y[i] == y_pred[i]) & (y_pred[i] == 1):
                TP = TP + 1
            if (y[i] != y_pred[i]) & (y_pred[i] == 1):
                FP = FP + 1
            if (y[i] == y_pred[i]) & (y_pred[i] == 0):
                TN = TN + 1
            if (y[i] != y_pred[i]) & (y_pred[i] == 0):
                FN = FN + 1
            
        N = TN + FP
        RP = TP + FP
        P = TP + FN
        
        accuracy = ((TP + TN) / (P + N))*100
        errorRate = ((FP + FN) / (P + N))*100
        try:  
            precision = (TP / (RP))*100
        except:
            print('Error: Divide by Zero')
            precision = np.nan
        try:
            recall = (TP / (P))*100
        except:
            print('Error: Divide by Zero')
            recall = np.nan

        print("Accuracy: ", accuracy, "%")
        print("Error Rate: ", errorRate, "%")
        print("Precision: ", precision, "%")
        print("Recall: ", recall, "% \n")
        
        
        
        return A

# %% [markdown]
# ### K-Fold Cross Validation

# %%
# Implement a K-Fold Validation for Logistic Regression
# Split the training set into K folds and determine the average accuracy

def cross_validation_LR(model, x_train, y_train, K, num_steps = 5000, learning_rate = 0.01, min_error = 1e-2, random_shuffle = True):
    # Model: Logistic Regression Class (Initialize Model and if add_intercept = True)
    # x_train: input data
    # y_train: target data
    # K: Number of Folds to split the data
    # num_steps: Number of steps of Gradient Descent before termination
    # learning_rate: learning Rate of Gradient Descent
    # min_error: Early Termination Requirement (Min imrovement in Cost Function)
    # random_shuffle: True if you want the data to be randomly shuffled before cross validation
    
    
    #Ramdomly shuffle the data
    if random_shuffle:
        data = np.concatenate((x_train, y_train), axis = 1)
        data = np.random.shuffle(data)
        x_train = np.array(data.iloc[:, :-1])
        y_train = np.array(data.iloc[:, -1])
    
    #Split into K folds
    data_length = x_train.shape[0]
    #print(data_length)
    fold_size = int(math.floor(data_length/K))
    #print(fold_size)
    
    accuracy = 0
    
    for i in range(K):
        #Run through an iteration for a specific k-fold combination
        Val_fold_start = i * fold_size
        Val_fold_end = Val_fold_start + fold_size
        
        x_val = x_train[Val_fold_start:Val_fold_end,:]
        y_val = y_train[Val_fold_start:Val_fold_end]
        #print("Validation Size")
        #print(x_val.shape)
        #print(y_val.shape)
            
        x_training = np.concatenate((x_train[:Val_fold_start,:],x_train[Val_fold_end:,:]),axis = 0)
        y_training = np.concatenate((y_train[:Val_fold_start],y_train[Val_fold_end:]))
        
        
        #Training data for K Folds (Fit Function)
        w = model.fit(x_training, y_training, num_steps, learning_rate, min_error)
        
        
        #Cross Validation Fold (Predict Function)
        y_pred = model.predict(x_val, w)
        
        #print(y_val)
        #print(y_pred)
    
    
        #Average Cross Validation Error over all instances
        accuracy = accuracy + model.evaluate_acc(y_val, y_pred)

    
    avg_cross_validation_accuracy = accuracy / K
    
    print("average cross validation model accuracy = " + str(avg_cross_validation_accuracy) + "% \n")
    
    return avg_cross_validation_accuracy

# %%
# Implement a K-Fold Validation for Naive Bayes
# Split the training set into K folds and determine the average accuracy

def cross_validation_NB(model, x_train, y_train, K, random_shuffle = True):
    # Model: Logistic Regression Class (Initialize Model and if add_intercept = True)
    # x_train: input data
    # y_train: target data
    # K: Number of Folds to split the data
    # num_steps: Number of steps of Gradient Descent before termination
    # learning_rate: learning Rate of Gradient Descent
    # min_error: Early Termination Requirement (Min imrovement in Cost Function)
    # random_shuffle: True if you want the data to be randomly shuffled before cross validation
    
    
    #Ramdomly shuffle the data
    if random_shuffle:
        data = np.concatenate((x_train, y_train), axis = 1)
        data = np.random.shuffle(data)
        x_train = np.array(data.iloc[:, :-1])
        y_train = np.array(data.iloc[:, -1])
    
    #Split into K folds
    data_length = x_train.shape[0]
    #print(data_length)
    fold_size = int(math.floor(data_length/K))
    #print(fold_size)
    
    accuracy = 0
    
    for i in range(K):
        #Run through an iteration for a specific k-fold combination
        Val_fold_start = i * fold_size
        Val_fold_end = Val_fold_start + fold_size
        
        x_val = x_train[Val_fold_start:Val_fold_end,:]
        y_val = y_train[Val_fold_start:Val_fold_end]
        #print("Validation Size")
        #print(x_val.shape)
        #print(y_val.shape)
            
        x_training = np.concatenate((x_train[:Val_fold_start,:],x_train[Val_fold_end:,:]),axis = 0)
        y_training = np.concatenate((y_train[:Val_fold_start],y_train[Val_fold_end:]))
        
        
        #Training data for K Folds (Fit Function)
        model.fit(x_training, y_training)
        
        
        #Cross Validation Fold (Predict Function)
        y_pred = model.predict(x_val)
        
        #print(y_val)
        #print(y_pred)
    
    
        #Average Cross Validation Error over all instances
        accuracy = accuracy + model.evaluate_acc(y_val, y_pred)

    
    avg_cross_validation_accuracy = accuracy / K
    
    print("average cross validation model accuracy = " + str(avg_cross_validation_accuracy) + "% \n")
    
    return avg_cross_validation_accuracy

# %% [markdown]
# ## Task 3 - Run Experiments
#
# Run Models and test accuracy over varying parameters

# %% [markdown]
# ### Cross Validation on Logistic Regression

# %%
Model_Logistic_Regression = LogisticRegression(intercept = True)

# %%
cross_validation_LR(Model_Logistic_Regression, x_train, y_train, K = 5, num_steps = 25000, learning_rate = 0.001, min_error = 1e-2, random_shuffle = False)
# Out:
# Number of Iterations = 24999
# Minimum Cost (J) = 0.505267601995717
# Weights of Model:  [ 0.85602607 -0.02483874 -0.60870657  0.0079782   0.40902859 -0.05844661
#   0.16281834 -0.07783061 -0.30095698  0.11753423  0.16415508  0.91625365]
# Accuracy:  73.30779054916987 %
# Error Rate:  26.69220945083014 %
# Precision:  74.91582491582491 %
# Recall:  88.11881188118812 %
#
# Number of Iterations = 24999
# Minimum Cost (J) = 0.4977385024573965
# Weights of Model:  [ 0.86314716 -0.08144712 -0.64428796  0.00846966  0.4062919  -0.03408306
#   0.21289984 -0.05958045 -0.28767481  0.04075691  0.17957601  0.97139958]
# Accuracy:  73.9463601532567 %
# Error Rate:  26.053639846743295 %
# Precision:  75.0 %
# Recall:  89.52569169960475 %
#
# Number of Iterations = 24999
# Minimum Cost (J) = 0.5154999771820193
# Weights of Model:  [ 0.80809388 -0.07157987 -0.57272039  0.05339857  0.37530539 -0.04898502
#   0.18615232 -0.07882298 -0.28723464  0.07357752  0.1270092   0.9325597 ]
# Accuracy:  78.03320561941251 %
# Error Rate:  21.966794380587483 %
# Precision:  80.76923076923077 %
# Recall:  89.44444444444444 %
#
# Number of Iterations = 24999
# Minimum Cost (J) = 0.505027459576367
# Weights of Model:  [ 0.81958301 -0.04977681 -0.61186305  0.04006655  0.43101321 -0.03782995
#   0.16841753 -0.11998132 -0.27554226  0.07287342  0.16998038  0.96568978]
# Accuracy:  73.05236270753512 %
# Error Rate:  26.947637292464876 %
# Precision:  77.41379310344828 %
# Recall:  84.87712665406427 %
#
# Number of Iterations = 24999
# Minimum Cost (J) = 0.5030800211060996
# Weights of Model:  [ 0.84033406 -0.0740535  -0.59808224  0.02879147  0.44624445 -0.03657352
#   0.13273703 -0.08019836 -0.28786395  0.07818211  0.16086834  0.98136975]
# Accuracy:  75.35121328224777 %
# Error Rate:  24.648786717752238 %
# Precision:  77.8534923339012 %
# Recall:  87.88461538461539 %
#
# average cross validation model accuracy = 74.73818646232439%
# 74.73818646232439

# %% [markdown]
# ### Cross Validation of Naive Bayes

# %%
Model_Naive_Bayes = NaiveBayes()

# %%
cross_validation_NB(Model_Naive_Bayes, x_train, y_train, K = 5, random_shuffle = False)
# Out:
# Accuracy:  69.47637292464879 %
# Error Rate:  30.52362707535121 %
# Precision:  76.18110236220473 %
# Recall:  76.63366336633663 %
#
# Accuracy:  69.09323116219667 %
# Error Rate:  30.906768837803323 %
# Precision:  74.08759124087592 %
# Recall:  80.23715415019763 %
#
# Accuracy:  73.43550446998724 %
# Error Rate:  26.56449553001277 %
# Precision:  81.08614232209737 %
# Recall:  80.18518518518518 %
#
# Accuracy:  68.45466155810983 %
# Error Rate:  31.545338441890163 %
# Precision:  77.32558139534885 %
# Recall:  75.42533081285444 %
#
# Accuracy:  70.75351213282248 %
# Error Rate:  29.246487867177525 %
# Precision:  78.92644135188867 %
# Recall:  76.34615384615384 %
#
# average cross validation model accuracy = 70.242656449553%
# 70.242656449553

# %% [markdown]
# ### Test Accuracy of Models with Varying Parameters

# %%
#Test Logisitc Regression over different learning rates

#May need to play around with num_steps and min_error (stopping requirement)

#Initialize
learning_rates = [1, 0.5, 0.1, 0.05, 0.01, 0.005, 0.001, 0.0005, 0.0001, 0.00005, 0.00001]
lr_accuracy = []

for learning_rate in learning_rates:
    
    average_cross_validation_accuracy = cross_validation_LR(Model_Logistic_Regression, x_train, y_train, K = 5, num_steps = 30000, learning_rate = learning_rate, min_error = 1e-2, random_shuffle = False)
    lr_accuracy.append(average_cross_validation_accuracy)

#Plot
plt.plot(np.log10(learning_rates), lr_accuracy)
plt.title("Learning Rate vs Model Accuracy (Wine Dataset)")
plt.xlabel("Learning Rate (Logarithmic Scale)")
plt.ylabel("Model Accuracy (%)")
# Out:
# Number of Iterations = 34
# Minimum Cost (J) = 0.5034858818484051
# Weights of Model:  [ 0.89204448 -0.01494436 -0.64797042 -0.0010315   0.48808515 -0.02555389
#   0.16159478 -0.06550112 -0.33474046  0.1264283   0.17398305  1.00918838]
# Accuracy:  73.30779054916987 %
# Error Rate:  26.69220945083014 %
# Precision:  75.0 %
# Recall:  87.92079207920793 %
#
# Number of Iterations = 35
# Minimum Cost (J) = 0.4956782308843829
# Weights of Model:  [ 0.90395243 -0.07792876 -0.69256518 -0.00162922  0.48365308  0.00272604
#   0.21534748 -0.0459757  -0.31096587  0.03956949  0.19556546  1.0859451 ]
# Accuracy:  74.07407407407408 %
# Error Rate:  25.925925925925924 %
# Precision:  75.29215358931552 %
# Recall:  89.13043478260869 %
#
# Number of Iterations = 32
# Minimum Cost (J) = 0.5141314017046765
# Weights of Model:  [ 0.83867539 -0.06841036 -0.60374901  0.04827826  0.43332806 -0.02231058
#   0.18709773 -0.07027314 -0.30563345  0.07631282  0.13371301  1.01508813]
# Accuracy:  78.03320561941251 %
# Error Rate:  21.966794380587483 %
# Precision:  80.97643097643098 %
# Recall:  89.07407407407408 %
#
# Number of Iterations = 35
# Minimum Cost (J) = 0.5030113839600822
# Weights of Model:  [ 0.85792606 -0.04264409 -0.65672611  0.0314607   0.51120256  0.00267685
#   0.16945367 -0.10893848 -0.30275022  0.07700839  0.18659291  1.0757655 ]
# Accuracy:  73.30779054916987 %
# Error Rate:  26.69220945083014 %
# Precision:  77.77777777777779 %
# Recall:  84.68809073724007 %
#
# Number of Iterations = 35
# Minimum Cost (J) = 0.5009784047546113
# Weights of Model:  [ 0.88120738 -0.06896085 -0.6462583   0.01936755  0.52952016  0.00137496
#   0.12769629 -0.06357852 -0.31962297  0.08209988  0.17359719  1.09123901]
# Accuracy:  76.11749680715198 %
# Error Rate:  23.88250319284802 %
# Precision:  78.65748709122204 %
# Recall:  87.88461538461539 %
#
# average cross validation model accuracy = 74.96807151979564%
#
# Number of Iterations = 69
# Minimum Cost (J) = 0.5034950948303579
# Weights of Model:  [ 8.90332344e-01 -1.50987497e-02 -6.46245057e-01 -6.79792296e-04
#   4.85218525e-01 -2.69074404e-02  1.61281251e-01 -6.56684030e-02
#  -3.34254081e-01  1.26288040e-01  1.73487757e-01  1.00456810e+00]
# Accuracy:  73.18007662835248 %
# Error Rate:  26.81992337164751 %
# Precision:  74.87352445193929 %
# Recall:  87.92079207920793 %
#
# Number of Iterations = 70
# Minimum Cost (J) = 0.49574244662123856
# Weights of Model:  [ 9.01061976e-01 -7.81226761e-02 -6.89195472e-01 -9.47828320e-04
#   4.78266276e-01  1.82100087e-04  2.15022960e-01 -4.67814923e-02
#  -3.09372855e-01  3.97270737e-02  1.94374394e-01  1.07782269e+00]
# Accuracy:  74.20178799489145 %
# Error Rate:  25.798212005108557 %
# Precision:  75.33333333333333 %
# Recall:  89.32806324110672 %
#
# Number of Iterations = 66
# Minimum Cost (J) = 0.5140955283828897
# Weights of Model:  [ 0.83800454 -0.06822746 -0.60332028  0.04824931  0.43285433 -0.0225016
#   0.18652108 -0.06985002 -0.30585968  0.0764796   0.13349246  1.01372502]
# Accuracy:  78.16091954022988 %
# Error Rate:  21.839080459770116 %
# Precision:  81.00840336134453 %
# Recall:  89.25925925925927 %
#
# Number of Iterations = 70
# Minimum Cost (J) = 0.5030725465861142
# Weights of Model:  [ 8.55240802e-01 -4.30505634e-02 -6.53601513e-01  3.20287847e-02
#   5.05756490e-01 -7.52721033e-05  1.69277259e-01 -1.09609509e-01
#  -3.01019006e-01  7.68245433e-02  1.85392479e-01  1.06797452e+00]
# Accuracy:  73.30779054916987 %
# Error Rate:  26.69220945083014 %
# Precision:  77.77777777777779 %
# Recall:  84.68809073724007 %
#
# Number of Iterations = 71
# Minimum Cost (J) = 0.5009917387754942
# Weights of Model:  [ 8.79469311e-01 -6.89923884e-02 -6.44353222e-01  1.97075449e-02
#   5.26532246e-01 -6.88251459e-05  1.27564857e-01 -6.38975659e-02
#  -3.18887265e-01  8.21071595e-02  1.73007985e-01  1.08655128e+00]
# Accuracy:  75.98978288633461 %
# Error Rate:  24.010217113665387 %
# Precision:  78.62068965517241 %
# Recall:  87.6923076923077 %
#
# average cross validation model accuracy = 74.96807151979564%
#
# Number of Iterations = 349
# Minimum Cost (J) = 0.5035017109176385
# Weights of Model:  [ 8.88932424e-01 -1.52107633e-02 -6.44854582e-01 -4.11445596e-04
#   4.82950296e-01 -2.79616427e-02  1.61011699e-01 -6.57953876e-02
#  -3.33858606e-01  1.26179174e-01  1.73089098e-01  1.00090005e+00]
# Accuracy:  73.30779054916987 %
# Error Rate:  26.69220945083014 %
# Precision:  74.91582491582491 %
# Recall:  88.11881188118812 %
#
# Number of Iterations = 355
# Minimum Cost (J) = 0.4957441351280498
# Weights of Model:  [ 8.99823331e-01 -7.80865190e-02 -6.87911518e-01 -7.26496529e-04
#   4.76392384e-01 -6.91112972e-04  2.14609499e-01 -4.68142488e-02
#  -3.08975746e-01  3.98966895e-02  1.93856113e-01  1.07468603e+00]
# Accuracy:  74.20178799489145 %
# Error Rate:  25.798212005108557 %
# Precision:  75.33333333333333 %
# Recall:  89.32806324110672 %
#
# Number of Iterations = 331
# Minimum Cost (J) = 0.5141346650515242
# Weights of Model:  [ 0.83580846 -0.06834549 -0.6011875   0.04855299  0.4290103  -0.02424861
#   0.18626425 -0.07026041 -0.304776    0.07638438  0.13298708  1.00793751]
# Accuracy:  78.16091954022988 %
# Error Rate:  21.839080459770116 %
# Precision:  81.00840336134453 %
# Recall:  89.25925925925927 %
#
# Number of Iterations = 353
# Minimum Cost (J) = 0.5030922255994844
# Weights of Model:  [ 0.85366511 -0.04317287 -0.65187161  0.03230417  0.50291387 -0.00152597
#   0.16900386 -0.10979692 -0.30030493  0.0768058   0.18468981  1.06358113]
# Accuracy:  73.18007662835248 %
# Error Rate:  26.81992337164751 %
# Precision:  77.64298093587522 %
# Recall:  84.68809073724007 %
#
# Number of Iterations = 358
# Minimum Cost (J) = 0.50101144233511
# Weights of Model:  [ 0.87782189 -0.06904201 -0.64253361  0.02002621  0.52365618 -0.00142948
#   0.12750517 -0.06427554 -0.31809904  0.0820888   0.17246922  1.08215906]
# Accuracy:  75.98978288633461 %
# Error Rate:  24.010217113665387 %
# Precision:  78.62068965517241 %
# Recall:  87.6923076923077 %
#
# average cross validation model accuracy = 74.96807151979564%
#
# Number of Iterations = 698
# Minimum Cost (J) = 0.5035074728471124
# Weights of Model:  [ 8.88642440e-01 -1.52675233e-02 -6.44549149e-01 -3.47057111e-04
#   4.82377748e-01 -2.82054882e-02  1.60999011e-01 -6.58699660e-02
#  -3.33657423e-01  1.26127397e-01  1.73009037e-01  1.00014565e+00]
# Accuracy:  73.30779054916987 %
# Error Rate:  26.69220945083014 %
# Precision:  74.91582491582491 %
# Recall:  88.11881188118812 %
#
# Number of Iterations = 710
# Minimum Cost (J) = 0.4957505218820471
# Weights of Model:  [ 8.99520116e-01 -7.81010953e-02 -6.87565166e-01 -6.59476023e-04
#   4.75852974e-01 -9.43930550e-04  2.14568612e-01 -4.68912759e-02
#  -3.08821813e-01  3.99162832e-02  1.93734446e-01  1.07385766e+00]
# Accuracy:  74.20178799489145 %
# Error Rate:  25.798212005108557 %
# Precision:  75.33333333333333 %
# Recall:  89.32806324110672 %
#
# Number of Iterations = 662
# Minimum Cost (J) = 0.5141408350759267
# Weights of Model:  [ 0.83549666 -0.06836356 -0.60088364  0.04859613  0.42846268 -0.02449619
#   0.18623174 -0.07032348 -0.30461722  0.07636909  0.13291654  1.00711935]
# Accuracy:  78.16091954022988 %
# Error Rate:  21.839080459770116 %
# Precision:  81.00840336134453 %
# Recall:  89.25925925925927 %
#
# Number of Iterations = 707
# Minimum Cost (J) = 0.5030933932659214
# Weights of Model:  [ 0.8534937  -0.04317968 -0.65168936  0.03233068  0.5026251  -0.00167377
#   0.1689649  -0.10980614 -0.30024387  0.07680862  0.18461377  1.0631145 ]
# Accuracy:  73.18007662835248 %
# Error Rate:  26.81992337164751 %
# Precision:  77.64298093587522 %
# Recall:  84.68809073724007 %
#
# Number of Iterations = 718
# Minimum Cost (J) = 0.5010076141070858
# Weights of Model:  [ 0.87776003 -0.06901904 -0.64248853  0.02002854  0.5236332  -0.00145191
#   0.12745516 -0.0642347  -0.31815845  0.0821093   0.17244607  1.0820106 ]
# Accuracy:  75.98978288633461 %
# Error Rate:  24.010217113665387 %
# Precision:  78.62068965517241 %
# Recall:  87.6923076923077 %
#
# average cross validation model accuracy = 74.96807151979564%
#
# Number of Iterations = 3493
# Minimum Cost (J) = 0.5035090920498545
# Weights of Model:  [ 8.88477454e-01 -1.52867219e-02 -6.44382864e-01 -3.14644349e-04
#   4.82093766e-01 -2.83321359e-02  1.60975125e-01 -6.58939681e-02
#  -3.33587118e-01  1.26109016e-01  1.72962839e-01  9.99720090e-01]
# Accuracy:  73.30779054916987 %
# Error Rate:  26.69220945083014 %
# Precision:  74.91582491582491 %
# Recall:  88.11881188118812 %
# Number of Iterations = 3554
# Minimum Cost (J) = 0.4957516372631763
# Weights of Model:  [ 8.99371393e-01 -7.80997570e-02 -6.87406853e-01 -6.31601393e-04
#   4.75619134e-01 -1.05265205e-03  2.14528230e-01 -4.69058665e-02
#  -3.08766772e-01  3.99333317e-02  1.93673818e-01  1.07347537e+00]
# Accuracy:  74.20178799489145 %
# Error Rate:  25.798212005108557 %
# Precision:  75.33333333333333 %
# Recall:  89.32806324110672 %
#
# Number of Iterations = 3315
# Minimum Cost (J) = 0.5141407712174669
# Weights of Model:  [ 0.83536962 -0.06835817 -0.60077227  0.04860629  0.42828347 -0.02457528
#   0.18619243 -0.07032095 -0.30458568  0.07637353  0.13288546  1.00681224]
# Accuracy:  78.16091954022988 %
# Error Rate:  21.839080459770116 %
# Precision:  81.00840336134453 %
# Recall:  89.25925925925927 %
#
# Number of Iterations = 3540
# Minimum Cost (J) = 0.5030933189686911
# Weights of Model:  [ 0.85337897 -0.04317915 -0.6515717   0.03234606  0.50244694 -0.00176601
#   0.1689311  -0.10980298 -0.30021661  0.0768146   0.18456266  1.0628086 ]
# Accuracy:  73.18007662835248 %
# Error Rate:  26.81992337164751 %
# Precision:  77.64298093587522 %
# Recall:  84.68809073724007 %
#
# Number of Iterations = 3591
# Minimum Cost (J) = 0.5010115354111666
# Weights of Model:  [ 0.87754626 -0.06903197 -0.64224721  0.02007144  0.52323965 -0.00163339
#   0.12746085 -0.06429923 -0.31803113  0.08210082  0.17237787  1.08144219]
# Accuracy:  75.98978288633461 %
# Error Rate:  24.010217113665387 %
# Precision:  78.62068965517241 %
# Recall:  87.6923076923077 %
#
# average cross validation model accuracy = 74.96807151979564%
#
# Number of Iterations = 6986
# Minimum Cost (J) = 0.5035096690629624
# Weights of Model:  [ 8.88448267e-01 -1.52923730e-02 -6.44352195e-01 -3.08220851e-04
#   4.82036414e-01 -2.83565214e-02  1.60973764e-01 -6.59013919e-02
#  -3.33566959e-01  1.26103843e-01  1.72954789e-01  9.99644464e-01]
# Accuracy:  73.30779054916987 %
# Error Rate:  26.69220945083014 %
# Precision:  74.91582491582491 %
# Recall:  88.11881188118812 %
#
# Number of Iterations = 7109
# Minimum Cost (J) = 0.4957517761708269
# Weights of Model:  [ 8.99352785e-01 -7.80995805e-02 -6.87387060e-01 -6.28123925e-04
#   4.75589928e-01 -1.06622339e-03  2.14523171e-01 -4.69076853e-02
#  -3.08759903e-01  3.99354668e-02  1.93666242e-01  1.07342760e+00]
# Accuracy:  74.20178799489145 %
# Error Rate:  25.798212005108557 %
# Precision:  75.33333333333333 %
# Recall:  89.32806324110672 %
#
# Number of Iterations = 6631
# Minimum Cost (J) = 0.5141408877717725
# Weights of Model:  [ 0.83535063 -0.06835797 -0.60075504  0.04860816  0.42825462 -0.02458811
#   0.18618783 -0.07032195 -0.30457936  0.07637367  0.13288094  1.00676516]
# Accuracy:  78.16091954022988 %
# Error Rate:  21.839080459770116 %
# Precision:  81.00840336134453 %
# Recall:  89.25925925925927 %
#
# Number of Iterations = 7081
# Minimum Cost (J) = 0.5030934342455095
# Weights of Model:  [ 0.85336178 -0.0431798  -0.65155347  0.03234868  0.50241813 -0.00178073
#   0.16892717 -0.10980388 -0.30021054  0.07681489  0.18455506  1.06276198]
# Accuracy:  73.18007662835248 %
# Error Rate:  26.81992337164751 %
# Precision:  77.64298093587522 %
# Recall:  84.68809073724007 %
#
# Number of Iterations = 7184
# Minimum Cost (J) = 0.5010111507370795
# Weights of Model:  [ 0.87754009 -0.06902965 -0.64224274  0.02007164  0.52323748 -0.00163555
#   0.12745584 -0.06429514 -0.31803712  0.08210288  0.17237558  1.08142748]
# Accuracy:  75.98978288633461 %
# Error Rate:  24.010217113665387 %
# Precision:  78.62068965517241 %
# Recall:  87.6923076923077 %
#
# average cross validation model accuracy = 74.96807151979564%
#
# Number of Iterations = 29999
# Minimum Cost (J) = 0.5041522018221806
# Weights of Model:  [ 0.87517255 -0.01981524 -0.62931958  0.00328817  0.44990868 -0.04131863
#   0.16267229 -0.07183299 -0.31806448  0.12209697  0.16937695  0.96480809]
# Accuracy:  73.05236270753512 %
# Error Rate:  26.947637292464876 %
# Precision:  74.83108108108108 %
# Recall:  87.72277227722772 %
#
# Number of Iterations = 29999
# Minimum Cost (J) = 0.49651082995653495
# Weights of Model:  [ 0.88355339 -0.07990489 -0.66798776  0.00353684  0.44384788 -0.01618387
#   0.21474979 -0.05355525 -0.2985475   0.04003043  0.18747585  1.02742191]
# Accuracy:  73.81864623243933 %
# Error Rate:  26.181353767560665 %
# Precision:  74.95854063018243 %
# Recall:  89.32806324110672 %
#
# Number of Iterations = 29999
# Minimum Cost (J) = 0.5145211804765842
# Weights of Model:  [ 0.82662692 -0.06961292 -0.59153422  0.05026353  0.410418   -0.03280477
#   0.18674334 -0.07366485 -0.29830903  0.07530996  0.13104321  0.98237334]
# Accuracy:  78.16091954022988 %
# Error Rate:  21.839080459770116 %
# Precision:  81.00840336134453 %
# Recall:  89.25925925925927 %
#
# Number of Iterations = 29999
# Minimum Cost (J) = 0.5038253277436875
# Weights of Model:  [ 0.83875848 -0.04650559 -0.63383586  0.03589952  0.46995166 -0.01798791
#   0.16960373 -0.11535951 -0.28805543  0.07478341  0.17824923  1.0198039 ]
# Accuracy:  73.05236270753512 %
# Error Rate:  26.947637292464876 %
# Precision:  77.50865051903114 %
# Recall:  84.68809073724007 %
#
# Number of Iterations = 29999
# Minimum Cost (J) = 0.5018304946276806
# Weights of Model:  [ 0.8607119  -0.07175542 -0.62169459  0.02419808  0.48658289 -0.01805207
#   0.13094806 -0.07282233 -0.30245141  0.07997644  0.16719577  1.03541569]
# Accuracy:  75.35121328224777 %
# Error Rate:  24.648786717752238 %
# Precision:  77.94871794871796 %
# Recall:  87.6923076923077 %
#
# average cross validation model accuracy = 74.68710089399744%
#
# Number of Iterations = 29999
# Minimum Cost (J) = 0.5111320557392719
# Weights of Model:  [ 0.77923848 -0.0352105  -0.53604038  0.02020103  0.2884564  -0.1062726
#   0.1505322  -0.08756876 -0.25920332  0.10596426  0.14454581  0.75593696]
# Accuracy:  72.54150702426566 %
# Error Rate:  27.458492975734355 %
# Precision:  74.16666666666667 %
# Recall:  88.11881188118812 %
#
# Number of Iterations = 29999
# Minimum Cost (J) = 0.5042305611480424
# Weights of Model:  [ 0.78313519 -0.08222114 -0.56307638  0.02188418  0.2912363  -0.08393011
#   0.19455648 -0.06975066 -0.25707801  0.0456449   0.15253102  0.79380437]
# Accuracy:  73.9463601532567 %
# Error Rate:  26.053639846743295 %
# Precision:  74.83552631578947 %
# Recall:  89.9209486166008 %
#
# Number of Iterations = 29999
# Minimum Cost (J) = 0.5208986142802611
# Weights of Model:  [ 0.73456294 -0.07347283 -0.50607669  0.06032741  0.26648357 -0.09410054
#   0.17131334 -0.08653949 -0.2572914   0.07008794  0.11154442  0.76923824]
# Accuracy:  78.03320561941251 %
# Error Rate:  21.966794380587483 %
# Precision:  80.56478405315615 %
# Recall:  89.81481481481481 %
#
# Number of Iterations = 29999
# Minimum Cost (J) = 0.5113417761194002
# Weights of Model:  [ 0.74483223 -0.05511939 -0.53738522  0.04997513  0.31191408 -0.09349113
#   0.15307551 -0.12421429 -0.24396837  0.0691455   0.14136621  0.79172082]
# Accuracy:  72.66922094508301 %
# Error Rate:  27.330779054916988 %
# Precision:  77.29636048526864 %
# Recall:  84.31001890359168 %
#
# Number of Iterations = 29999
# Minimum Cost (J) = 0.5096180822143067
# Weights of Model:  [ 0.76187843 -0.07689709 -0.51857363  0.04047724  0.3236413  -0.08852679
#   0.12629533 -0.09257764 -0.2519222   0.07467969  0.13857657  0.80613851]
# Accuracy:  74.45721583652617 %
# Error Rate:  25.54278416347382 %
# Precision:  77.02702702702703 %
# Recall:  87.6923076923077 %
#
# average cross validation model accuracy = 74.32950191570882%
#
# Number of Iterations = 29999
# Minimum Cost (J) = 0.5673277238548241
# Weights of Model:  [ 0.36110671 -0.03745978 -0.23537487  0.01294668  0.01848769 -0.11739111
#   0.04207317 -0.08175151 -0.15998531  0.06527429  0.06379451  0.31349208]
# Accuracy:  71.26436781609196 %
# Error Rate:  28.735632183908045 %
# Precision:  75.83025830258303 %
# Recall:  81.38613861386138 %
#
# Number of Iterations = 29999
# Minimum Cost (J) = 0.5643321412937928
# Weights of Model:  [ 0.36109106 -0.05875128 -0.24488659  0.01706188  0.02297777 -0.10513388
#   0.06493389 -0.07050595 -0.1625916   0.04880546  0.06388115  0.32266231]
# Accuracy:  72.2860791826309 %
# Error Rate:  27.713920817369093 %
# Precision:  75.75757575757575 %
# Recall:  83.99209486166008 %
#
# Number of Iterations = 29999
# Minimum Cost (J) = 0.5740410293457384
# Weights of Model:  [ 0.33946479 -0.05135336 -0.22429832  0.03161873  0.01171368 -0.10709301
#   0.04887622 -0.08073414 -0.16470995  0.05151625  0.0477873   0.3175659 ]
# Accuracy:  75.35121328224777 %
# Error Rate:  24.648786717752238 %
# Precision:  81.71846435100548 %
# Recall:  82.77777777777777 %
# Number of Iterations = 29999
# Minimum Cost (J) = 0.5685198614362068
# Weights of Model:  [ 0.34543516 -0.0431096  -0.23906013  0.02820439  0.02873414 -0.11403581
#   0.04113181 -0.09718529 -0.15816754  0.05095472  0.05169822  0.32353787]
# Accuracy:  70.11494252873564 %
# Error Rate:  29.88505747126437 %
# Precision:  78.3109404990403 %
# Recall:  77.12665406427222 %
#
# Number of Iterations = 29999
# Minimum Cost (J) = 0.5680402956006024
# Weights of Model:  [ 0.35187043 -0.05731834 -0.21949144  0.02373279  0.03187746 -0.11018442
#   0.03410606 -0.08520612 -0.16148722  0.05607436  0.05942657  0.33020111]
# Accuracy:  72.15836526181354 %
# Error Rate:  27.84163473818646 %
# Precision:  78.17164179104478 %
# Recall:  80.57692307692308 %
#
# average cross validation model accuracy = 72.23499361430397%
#
# Number of Iterations = 29999
# Minimum Cost (J) = 0.6031700391110364
# Weights of Model:  [ 0.2113213  -0.02883672 -0.13733454  0.00402738 -0.01394238 -0.08197674
#   0.01237018 -0.06414669 -0.11434703  0.04437842  0.03684901  0.19470411]
# Accuracy:  69.8595146871009 %
# Error Rate:  30.140485312899106 %
# Precision:  76.32093933463796 %
# Recall:  77.22772277227723 %
#
# Number of Iterations = 29999
# Minimum Cost (J) = 0.6016622483959232
# Weights of Model:  [ 0.21116851 -0.04217038 -0.14306695  0.00701667 -0.01093968 -0.07398373
#   0.02679875 -0.0568445  -0.11600684  0.03641938  0.03707747  0.19907791]
# Accuracy:  71.26436781609196 %
# Error Rate:  28.735632183908045 %
# Precision:  76.45951035781545 %
# Recall:  80.23715415019763 %
#
# Number of Iterations = 29999
# Minimum Cost (J) = 0.6077336948720661
# Weights of Model:  [ 0.19824789 -0.0365873  -0.13114544  0.01498424 -0.01808873 -0.07528143
#   0.01570128 -0.063832   -0.11775736  0.03648188  0.0270238   0.19671758]
# Accuracy:  72.79693486590038 %
# Error Rate:  27.203065134099617 %
# Precision:  81.26195028680688 %
# Recall:  78.70370370370371 %
#
# Number of Iterations = 29999
# Minimum Cost (J) = 0.6041394697537439
# Weights of Model:  [ 0.20207925 -0.03153214 -0.14056566  0.01315521 -0.00821939 -0.07944764
#   0.01171321 -0.07298004 -0.11363797  0.03613249  0.02808223  0.19966891]
# Accuracy:  68.5823754789272 %
# Error Rate:  31.417624521072796 %
# Precision:  78.4708249496982 %
# Recall:  73.72400756143668 %
#
# Number of Iterations = 29999
# Minimum Cost (J) = 0.6036684739543122
# Weights of Model:  [ 0.20572489 -0.04127742 -0.12705923  0.01010705 -0.00722007 -0.07761032
#   0.00790863 -0.06634412 -0.11645602  0.04001177  0.03461976  0.20422623]
# Accuracy:  70.62579821200511 %
# Error Rate:  29.374201787994892 %
# Precision:  78.3203125 %
# Recall:  77.11538461538461 %
#
# average cross validation model accuracy = 70.62579821200511%
#
# Number of Iterations = 29999
# Minimum Cost (J) = 0.6654356265220326
# Weights of Model:  [ 0.04870212 -0.00892062 -0.03163321 -0.00054885 -0.01047099 -0.02282203
#  -0.00133688 -0.02031744 -0.03335184  0.01219358  0.00823412  0.04968469]
# Accuracy:  68.71008939974456 %
# Error Rate:  31.28991060025543 %
# Precision:  76.10441767068274 %
# Recall:  75.04950495049505 %
#
# Number of Iterations = 29999
# Minimum Cost (J) = 0.6652164171745143
# Weights of Model:  [ 0.04862525 -0.01231653 -0.033085    0.00026047 -0.00979736 -0.02068854
#   0.00225549 -0.01847349 -0.03388639  0.01075919  0.00838685  0.05045047]
# Accuracy:  70.49808429118774 %
# Error Rate:  29.50191570881226 %
# Precision:  77.33598409542743 %
# Recall:  76.87747035573122 %
#
# Number of Iterations = 29999
# Minimum Cost (J) = 0.6665931367176735
# Weights of Model:  [ 0.04553473 -0.01066672 -0.03032889  0.0019347  -0.01165659 -0.0211361
#  -0.00071512 -0.02037033 -0.03446385  0.01040683  0.00583234  0.05008125]
# Accuracy:  70.49808429118774 %
# Error Rate:  29.50191570881226 %
# Precision:  80.83832335329342 %
# Recall:  75.0 %
#
# Number of Iterations = 29999
# Minimum Cost (J) = 0.6657630317353618
# Weights of Model:  [ 0.04651572 -0.00938936 -0.03274033  0.00157541 -0.00928017 -0.02197293
#  -0.00144637 -0.02227084 -0.03331095  0.01029918  0.00576881  0.05054319]
# Accuracy:  68.83780332056195 %
# Error Rate:  31.162196679438058 %
# Precision:  79.62577962577963 %
# Recall:  72.4007561436673 %
#
# Number of Iterations = 29999
# Minimum Cost (J) = 0.6653730408183597
# Weights of Model:  [ 0.04734532 -0.01209148 -0.02909821  0.00070083 -0.00939614 -0.02176053
#  -0.0023473  -0.02092624 -0.03437096  0.01148481  0.0078824   0.05192914]
# Accuracy:  69.60408684546616 %
# Error Rate:  30.395913154533844 %
# Precision:  78.3132530120482 %
# Recall:  75.0 %
#
# average cross validation model accuracy = 69.62962962962963%
# Text(0, 0.5, 'Model Accuracy (%)')

# %%
#Threshold of change in value of cost function as termination criteria
#Test Logisitc Regression over different thresholds of cost function improvement

#Initialize
termination_thresholds = [0.66, 0.33, 0.1, 0.066, 0.033, 0.01, 0.0066, 0.005, 0.0033, 0.001] 
termination_accuracy = []

for threshold in termination_thresholds:
    
    average_cross_validation_accuracy = cross_validation_LR(Model_Logistic_Regression, x_train, y_train, K = 5, num_steps = 30000, learning_rate = 0.01, min_error = threshold, random_shuffle = False)
    termination_accuracy.append(average_cross_validation_accuracy)

#Plot
plt.plot(termination_thresholds, termination_accuracy)
plt.title("Threshold for Termination vs Model Accuracy (Wine Dataset)")
plt.xlabel("Termination Threshold Value")
plt.ylabel("Model Accuracy (%)")
# Out:
# Number of Iterations = 0
# Minimum Cost (J) = 0.6931471805599451
# Weights of Model:  [ 1.68580542e-03 -3.36001835e-04 -1.09513621e-03 -3.83979927e-05
#  -4.45431430e-04 -8.35294626e-04 -9.74495550e-05 -7.70703959e-04
#  -1.23918587e-03  4.45279083e-04  2.81086343e-04  1.78257776e-03]
# Accuracy:  68.07151979565774 %
# Error Rate:  31.928480204342275 %
# Precision:  75.86206896551724 %
# Recall:  74.05940594059406 %
#
# Number of Iterations = 0
# Minimum Cost (J) = 0.6931471805599451
# Weights of Model:  [ 1.68261563e-03 -4.57632326e-04 -1.14757898e-03 -9.42011470e-06
#  -4.23759742e-04 -7.57958271e-04  2.95245041e-05 -7.05578689e-04
#  -1.26094508e-03  3.99636608e-04  2.87628443e-04  1.80672211e-03]
# Accuracy:  70.62579821200511 %
# Error Rate:  29.374201787994892 %
# Precision:  77.60000000000001 %
# Recall:  76.6798418972332 %
#
# Number of Iterations = 0
# Minimum Cost (J) = 0.6931471805599451
# Weights of Model:  [ 1.57416268e-03 -3.96576442e-04 -1.05199192e-03  4.66058443e-05
#  -4.90959928e-04 -7.75811615e-04 -7.74348118e-05 -7.74497863e-04
#  -1.28327333e-03  3.83849833e-04  1.96374353e-04  1.79609295e-03]
# Accuracy:  70.62579821200511 %
# Error Rate:  29.374201787994892 %
# Precision:  81.37651821862349 %
# Recall:  74.44444444444444 %
#
# Number of Iterations = 0
# Minimum Cost (J) = 0.6931471805599451
# Weights of Model:  [ 1.60925040e-03 -3.50694240e-04 -1.13809168e-03  3.50655857e-05
#  -4.06481294e-04 -8.02334564e-04 -1.00262984e-04 -8.37254707e-04
#  -1.23994274e-03  3.79596414e-04  1.90920963e-04  1.80892031e-03]
# Accuracy:  68.32694763729246 %
# Error Rate:  31.673052362707537 %
# Precision:  79.33194154488518 %
# Recall:  71.83364839319471 %
#
# Number of Iterations = 0
# Minimum Cost (J) = 0.6931471805599451
# Weights of Model:  [ 1.63795853e-03 -4.49716996e-04 -1.00646916e-03  2.49004114e-06
#  -4.15293948e-04 -7.98046255e-04 -1.32566284e-04 -7.93568898e-04
#  -1.28250598e-03  4.24198483e-04  2.71069703e-04  1.86180662e-03]
# Accuracy:  68.83780332056195 %
# Error Rate:  31.162196679438058 %
# Precision:  77.93522267206477 %
# Recall:  74.03846153846155 %
#
# average cross validation model accuracy = 69.29757343550446%
#
# Number of Iterations = 0
# Minimum Cost (J) = 0.6931471805599451
# Weights of Model:  [ 1.68580542e-03 -3.36001835e-04 -1.09513621e-03 -3.83979927e-05
#  -4.45431430e-04 -8.35294626e-04 -9.74495550e-05 -7.70703959e-04
#  -1.23918587e-03  4.45279083e-04  2.81086343e-04  1.78257776e-03]
# Accuracy:  68.07151979565774 %
# Error Rate:  31.928480204342275 %
# Precision:  75.86206896551724 %
# Recall:  74.05940594059406 %
#
# Number of Iterations = 0
# Minimum Cost (J) = 0.6931471805599451
# Weights of Model:  [ 1.68261563e-03 -4.57632326e-04 -1.14757898e-03 -9.42011470e-06
#  -4.23759742e-04 -7.57958271e-04  2.95245041e-05 -7.05578689e-04
#  -1.26094508e-03  3.99636608e-04  2.87628443e-04  1.80672211e-03]
# Accuracy:  70.62579821200511 %
# Error Rate:  29.374201787994892 %
# Precision:  77.60000000000001 %
# Recall:  76.6798418972332 %
#
# Number of Iterations = 0
# Minimum Cost (J) = 0.6931471805599451
# Weights of Model:  [ 1.57416268e-03 -3.96576442e-04 -1.05199192e-03  4.66058443e-05
#  -4.90959928e-04 -7.75811615e-04 -7.74348118e-05 -7.74497863e-04
#  -1.28327333e-03  3.83849833e-04  1.96374353e-04  1.79609295e-03]
# Accuracy:  70.62579821200511 %
# Error Rate:  29.374201787994892 %
# Precision:  81.37651821862349 %
# Recall:  74.44444444444444 %
#
# Number of Iterations = 0
# Minimum Cost (J) = 0.6931471805599451
# Weights of Model:  [ 1.60925040e-03 -3.50694240e-04 -1.13809168e-03  3.50655857e-05
#  -4.06481294e-04 -8.02334564e-04 -1.00262984e-04 -8.37254707e-04
#  -1.23994274e-03  3.79596414e-04  1.90920963e-04  1.80892031e-03]
# Accuracy:  68.32694763729246 %
# Error Rate:  31.673052362707537 %
# Precision:  79.33194154488518 %
# Recall:  71.83364839319471 %
#
# Number of Iterations = 0
# Minimum Cost (J) = 0.6931471805599451
# Weights of Model:  [ 1.63795853e-03 -4.49716996e-04 -1.00646916e-03  2.49004114e-06
#  -4.15293948e-04 -7.98046255e-04 -1.32566284e-04 -7.93568898e-04
#  -1.28250598e-03  4.24198483e-04  2.71069703e-04  1.86180662e-03]
# Accuracy:  68.83780332056195 %
# Error Rate:  31.162196679438058 %
# Precision:  77.93522267206477 %
# Recall:  74.03846153846155 %
#
# average cross validation model accuracy = 69.29757343550446%
#
# Number of Iterations = 449
# Minimum Cost (J) = 0.5478475508770723
# Weights of Model:  [ 0.47106014 -0.0401241  -0.30856106  0.01967487  0.06043402 -0.13331568
#   0.06945544 -0.0870219  -0.1841759   0.07716666  0.08366155  0.40205577]
# Accuracy:  72.15836526181354 %
# Error Rate:  27.84163473818646 %
# Precision:  75.30864197530865 %
# Recall:  84.55445544554455 %
#
# Number of Iterations = 468
# Minimum Cost (J) = 0.5418434638846497
# Weights of Model:  [ 0.48309038 -0.06780275 -0.32935586  0.02464651  0.07091604 -0.11914225
#   0.10140713 -0.07360676 -0.18975024  0.05294726  0.08611322  0.42621258]
# Accuracy:  72.03065134099617 %
# Error Rate:  27.969348659003828 %
# Precision:  74.69879518072288 %
# Recall:  85.7707509881423 %
#
# Number of Iterations = 432
# Minimum Cost (J) = 0.5573160757415112
# Weights of Model:  [ 0.43301498 -0.0584101  -0.28667642  0.04271573  0.0468025  -0.12006777
#   0.07628314 -0.0851576  -0.18719299  0.058226    0.06182388  0.39875234]
# Accuracy:  74.71264367816092 %
# Error Rate:  25.287356321839084 %
# Precision:  80.42704626334519 %
# Recall:  83.7037037037037 %
#
# Number of Iterations = 451
# Minimum Cost (J) = 0.548836758185114
# Weights of Model:  [ 0.45176643 -0.04856564 -0.31276145  0.0392644   0.0748408  -0.129356
#   0.06899162 -0.10750563 -0.18119687  0.05816784  0.07092547  0.41767257]
# Accuracy:  71.64750957854406 %
# Error Rate:  28.35249042145594 %
# Precision:  78.26887661141805 %
# Recall:  80.34026465028356 %
#
# Number of Iterations = 456
# Minimum Cost (J) = 0.5476448316126886
# Weights of Model:  [ 0.46351036 -0.06539529 -0.2925791   0.0340879   0.08142965 -0.12433583
#   0.05953606 -0.09151983 -0.18545477  0.06387842  0.07861575  0.42876216]
# Accuracy:  73.69093231162196 %
# Error Rate:  26.309067688378036 %
# Precision:  77.93594306049823 %
# Recall:  84.23076923076923 %
#
# average cross validation model accuracy = 72.84802043422732%
#
# Number of Iterations = 750
# Minimum Cost (J) = 0.5278031328531241
# Weights of Model:  [ 0.61616943 -0.0404915  -0.40911802  0.02535794  0.14087435 -0.13885194
#   0.10844175 -0.08942483 -0.21339144  0.09045376  0.11049131  0.53710354]
# Accuracy:  72.2860791826309 %
# Error Rate:  27.713920817369093 %
# Precision:  74.24242424242425 %
# Recall:  87.32673267326733 %
#
# Number of Iterations = 783
# Minimum Cost (J) = 0.5209132302359065
# Weights of Model:  [ 0.6291539  -0.07599016 -0.43562718  0.02916176  0.15395654 -0.11945994
#   0.14734464 -0.07342712 -0.21888296  0.05230099  0.1147254   0.57224687]
# Accuracy:  72.66922094508301 %
# Error Rate:  27.330779054916988 %
# Precision:  74.57912457912458 %
# Recall:  87.54940711462451 %
#
# Number of Iterations = 729
# Minimum Cost (J) = 0.5375640938141928
# Weights of Model:  [ 0.57290091 -0.0668488  -0.38291811  0.05620528  0.12286135 -0.12558346
#   0.12097202 -0.08734069 -0.21643654  0.06499014  0.08341442  0.53771438]
# Accuracy:  77.13920817369093 %
# Error Rate:  22.860791826309068 %
# Precision:  80.5414551607445 %
# Recall:  88.14814814814815 %
#
# Number of Iterations = 761
# Minimum Cost (J) = 0.5282480732591465
# Weights of Model:  [ 0.59287743 -0.05350603 -0.41426024  0.05014275  0.16248736 -0.13253216
#   0.10960471 -0.1169645  -0.20756737  0.06446576  0.09993923  0.56350999]
# Accuracy:  71.51979565772669 %
# Error Rate:  28.480204342273307 %
# Precision:  76.93661971830986 %
# Recall:  82.6086956521739 %
#
# Number of Iterations = 774
# Minimum Cost (J) = 0.5265204670580729
# Weights of Model:  [ 0.60951544 -0.07280391 -0.39463329  0.04336283  0.17364778 -0.12569362
#   0.09455806 -0.09485296 -0.21320854  0.07028579  0.10515862  0.57974025]
# Accuracy:  75.09578544061303 %
# Error Rate:  24.904214559386972 %
# Precision:  77.58913412563668 %
# Recall:  87.88461538461539 %
#
# average cross validation model accuracy = 73.74201787994892%
#
# Number of Iterations = 1493
# Minimum Cost (J) = 0.5111994635082541
# Weights of Model:  [ 0.77862943 -0.03527636 -0.53548852  0.02028512  0.28759928 -0.10660002
#   0.15041175 -0.08761652 -0.25893226  0.10588298  0.14439784  0.75476723]
# Accuracy:  72.54150702426566 %
# Error Rate:  27.458492975734355 %
# Precision:  74.16666666666667 %
# Recall:  88.11881188118812 %
# Number of Iterations = 1560
# Minimum Cost (J) = 0.5035381527446162
# Weights of Model:  [ 0.79086421 -0.08238474 -0.57025078  0.02098986  0.30042078 -0.08046008
#   0.19673436 -0.06927993 -0.25950907  0.04516199  0.15483943  0.80826166]
# Accuracy:  73.81864623243933 %
# Error Rate:  26.181353767560665 %
# Precision:  74.79406919275124 %
# Recall:  89.72332015810277 %
#
# Number of Iterations = 1451
# Minimum Cost (J) = 0.5214042396542634
# Weights of Model:  [ 0.72881827 -0.07339803 -0.50125406  0.06057123  0.25951963 -0.09655623
#   0.16974692 -0.08675305 -0.25543891  0.06990306  0.11041739  0.75846716]
# Accuracy:  78.03320561941251 %
# Error Rate:  21.966794380587483 %
# Precision:  80.56478405315615 %
# Recall:  89.81481481481481 %
#
# Number of Iterations = 1538
# Minimum Cost (J) = 0.5109077922996349
# Weights of Model:  [ 0.749553   -0.05501846 -0.54165987  0.0496367   0.31808853 -0.09102574
#   0.15431043 -0.12428521 -0.24548559  0.06929529  0.1429565   0.80095204]
# Accuracy:  72.66922094508301 %
# Error Rate:  27.330779054916988 %
# Precision:  77.29636048526864 %
# Recall:  84.31001890359168 %
#
# Number of Iterations = 1562
# Minimum Cost (J) = 0.5089026954231819
# Weights of Model:  [ 0.76962884 -0.07689942 -0.52573148  0.03975264  0.33375434 -0.08478679
#   0.12750375 -0.09202638 -0.25462324  0.07491053  0.14058079  0.82101194]
# Accuracy:  74.71264367816092 %
# Error Rate:  25.287356321839084 %
# Precision:  77.28813559322035 %
# Recall:  87.6923076923077 %
#
# average cross validation model accuracy = 74.3550446998723%
#
# Number of Iterations = 3493
# Minimum Cost (J) = 0.5035090920498545
# Weights of Model:  [ 8.88477454e-01 -1.52867219e-02 -6.44382864e-01 -3.14644349e-04
#   4.82093766e-01 -2.83321359e-02  1.60975125e-01 -6.58939681e-02
#  -3.33587118e-01  1.26109016e-01  1.72962839e-01  9.99720090e-01]
# Accuracy:  73.30779054916987 %
# Error Rate:  26.69220945083014 %
# Precision:  74.91582491582491 %
# Recall:  88.11881188118812 %
#
# Number of Iterations = 3554
# Minimum Cost (J) = 0.4957516372631763
# Weights of Model:  [ 8.99371393e-01 -7.80997570e-02 -6.87406853e-01 -6.31601393e-04
#   4.75619134e-01 -1.05265205e-03  2.14528230e-01 -4.69058665e-02
#  -3.08766772e-01  3.99333317e-02  1.93673818e-01  1.07347537e+00]
# Accuracy:  74.20178799489145 %
# Error Rate:  25.798212005108557 %
# Precision:  75.33333333333333 %
# Recall:  89.32806324110672 %
#
# Number of Iterations = 3315
# Minimum Cost (J) = 0.5141407712174669
# Weights of Model:  [ 0.83536962 -0.06835817 -0.60077227  0.04860629  0.42828347 -0.02457528
#   0.18619243 -0.07032095 -0.30458568  0.07637353  0.13288546  1.00681224]
# Accuracy:  78.16091954022988 %
# Error Rate:  21.839080459770116 %
# Precision:  81.00840336134453 %
# Recall:  89.25925925925927 %
#
# Number of Iterations = 3540
# Minimum Cost (J) = 0.5030933189686911
# Weights of Model:  [ 0.85337897 -0.04317915 -0.6515717   0.03234606  0.50244694 -0.00176601
#   0.1689311  -0.10980298 -0.30021661  0.0768146   0.18456266  1.0628086 ]
# Accuracy:  73.18007662835248 %
# Error Rate:  26.81992337164751 %
# Precision:  77.64298093587522 %
# Recall:  84.68809073724007 %
#
# Number of Iterations = 3591
# Minimum Cost (J) = 0.5010115354111666
# Weights of Model:  [ 0.87754626 -0.06903197 -0.64224721  0.02007144  0.52323965 -0.00163339
#   0.12746085 -0.06429923 -0.31803113  0.08210082  0.17237787  1.08144219]
# Accuracy:  75.98978288633461 %
# Error Rate:  24.010217113665387 %
# Precision:  78.62068965517241 %
# Recall:  87.6923076923077 %
#
# average cross validation model accuracy = 74.96807151979564%
#
# Number of Iterations = 4400
# Minimum Cost (J) = 0.5029009449995785
# Weights of Model:  [ 0.90435319 -0.00814309 -0.66321588 -0.00479946  0.52634045 -0.01200625
#   0.15631693 -0.05580849 -0.35968907  0.13242703  0.17709593  1.04041041]
# Accuracy:  73.5632183908046 %
# Error Rate:  26.436781609195403 %
# Precision:  75.08417508417509 %
# Recall:  88.31683168316832 %
#
# Number of Iterations = 4367
# Minimum Cost (J) = 0.4952021828669911
# Weights of Model:  [ 0.91473712 -0.07567608 -0.70724285 -0.00483484  0.50900846  0.01438126
#   0.21223995 -0.03794414 -0.32139797  0.04049223  0.19954509  1.11943129]
# Accuracy:  74.32950191570882 %
# Error Rate:  25.67049808429119 %
# Precision:  75.63025210084034 %
# Recall:  88.93280632411067 %
#
# Number of Iterations = 4082
# Minimum Cost (J) = 0.5136226067042767
# Weights of Model:  [ 0.8503875  -0.0655418  -0.61727524  0.04556417  0.46138839 -0.00973445
#   0.18345795 -0.0625258  -0.31816874  0.07876805  0.13584691  1.04939436]
# Accuracy:  78.28863346104725 %
# Error Rate:  21.711366538952745 %
# Precision:  81.04026845637584 %
# Recall:  89.44444444444444 %
#
# Number of Iterations = 4374
# Minimum Cost (J) = 0.5025306649222984
# Weights of Model:  [ 0.86837189 -0.0387507  -0.67068323  0.02852752  0.53901284  0.01537291
#   0.16607192 -0.10133918 -0.31696189  0.07973875  0.19083393  1.10701626]
# Accuracy:  73.43550446998724 %
# Error Rate:  26.56449553001277 %
# Precision:  77.81629116117851 %
# Recall:  84.87712665406427 %
#
# Number of Iterations = 4458
# Minimum Cost (J) = 0.500427517696399
# Weights of Model:  [ 0.89365918 -0.06536304 -0.66278802  0.01606772  0.56222305  0.0145744
#   0.12163594 -0.0531761  -0.33843957  0.08510294  0.17714528  1.12481587]
# Accuracy:  76.37292464878672 %
# Error Rate:  23.627075351213282 %
# Precision:  78.82960413080895 %
# Recall:  88.07692307692308 %
#
# average cross validation model accuracy = 75.19795657726692%
#
# Number of Iterations = 5145
# Minimum Cost (J) = 0.502654514119217
# Weights of Model:  [ 0.91248047 -0.00319605 -0.67323526 -0.00704446  0.55318044 -0.00343231
#   0.15229037 -0.04870556 -0.37954852  0.13681832  0.1791707   1.05896323]
# Accuracy:  73.5632183908046 %
# Error Rate:  26.436781609195403 %
# Precision:  75.0 %
# Recall:  88.51485148514851 %
#
# Number of Iterations = 4941
# Minimum Cost (J) = 0.49501080177179957
# Weights of Model:  [ 0.92208898 -0.07418698 -0.71710639 -0.00683593  0.52617543  0.02190962
#   0.21012803 -0.03241722 -0.32916624  0.04111609  0.20223596  1.14130426]
# Accuracy:  74.20178799489145 %
# Error Rate:  25.798212005108557 %
# Precision:  75.67567567567568 %
# Recall:  88.53754940711462 %
#
# Number of Iterations = 4632
# Minimum Cost (J) = 0.5134393147926497
# Weights of Model:  [ 0.85761041 -0.06377485 -0.62552599  0.0440695   0.47880252 -0.00238189
#   0.18106452 -0.05750283 -0.3268761   0.08029869  0.13714335  1.06955938]
# Accuracy:  78.544061302682 %
# Error Rate:  21.455938697318008 %
# Precision:  81.31313131313132 %
# Recall:  89.44444444444444 %
#
# Number of Iterations = 4984
# Minimum Cost (J) = 0.5023276379962681
# Weights of Model:  [ 0.87571094 -0.0360184  -0.68037351  0.02668395  0.55878096  0.0237984
#   0.1634996  -0.09573279 -0.32807528  0.08168778  0.19377877  1.12785609]
# Accuracy:  73.69093231162196 %
# Error Rate:  26.309067688378036 %
# Precision:  77.9896013864818 %
# Recall:  85.06616257088847 %
#
# Number of Iterations = 5110
# Minimum Cost (J) = 0.5002108168543944
# Weights of Model:  [ 0.90166004 -0.06287218 -0.67327055  0.01417766  0.58398176  0.02267051
#   0.11744579 -0.04614635 -0.35237936  0.08724687  0.17942487  1.14500468]
# Accuracy:  76.24521072796935 %
# Error Rate:  23.754789272030653 %
# Precision:  78.69415807560138 %
# Recall:  88.07692307692308 %
#
# average cross validation model accuracy = 75.24904214559388%
#
# Number of Iterations = 7006
# Minimum Cost (J) = 0.502357524921286
# Weights of Model:  [ 0.92301463  0.00703541 -0.68662827 -0.00964184  0.59998149  0.00801537
#   0.1440296  -0.03570677 -0.42516326  0.14580436  0.18223296  1.07412372]
# Accuracy:  73.43550446998724 %
# Error Rate:  26.56449553001277 %
# Precision:  74.87437185929649 %
# Recall:  88.51485148514851 %
#
# Number of Iterations = 5864
# Minimum Cost (J) = 0.4948551636956392
# Weights of Model:  [ 0.93011681 -0.07211447 -0.72820395 -0.00895462  0.54654674  0.03019947
#   0.20670909 -0.02502638 -0.34026181  0.04227294  0.20506496  1.16442107]
# Accuracy:  74.20178799489145 %
# Error Rate:  25.798212005108557 %
# Precision:  75.67567567567568 %
# Recall:  88.53754940711462 %
#
# Number of Iterations = 5544
# Minimum Cost (J) = 0.5132860800179053
# Weights of Model:  [ 0.86558616 -0.06123175 -0.63491238  0.04246474  0.50019094  0.00586108
#   0.17719399 -0.05048591 -0.33996812  0.08253872  0.13847832  1.09065224]
# Accuracy:  78.67177522349937 %
# Error Rate:  21.328224776500637 %
# Precision:  81.45025295109612 %
# Recall:  89.44444444444444 %
# Number of Iterations = 6041
# Minimum Cost (J) = 0.5021508593977273
# Weights of Model:  [ 0.8840114  -0.03202483 -0.69158802  0.02472602  0.58424668  0.03332778
#   0.15911622 -0.08761201 -0.3456398   0.08474042  0.19704045  1.14946704]
# Accuracy:  73.9463601532567 %
# Error Rate:  26.053639846743295 %
# Precision:  78.45884413309983 %
# Recall:  84.68809073724007 %
#
# Number of Iterations = 6313
# Minimum Cost (J) = 0.5000110764255775
# Weights of Model:  [ 0.91093741 -0.05869249 -0.68559259  0.01222107  0.61372798  0.03211012
#   0.11087285 -0.03608617 -0.37573875  0.09098254  0.18209522  1.16526296]
# Accuracy:  76.50063856960408 %
# Error Rate:  23.49936143039591 %
# Precision:  78.8659793814433 %
# Recall:  88.26923076923077 %
#
# average cross validation model accuracy = 75.35121328224776%
#
# Number of Iterations = 29999
# Minimum Cost (J) = 0.501208277242112
# Weights of Model:  [ 0.93037105  0.09075805 -0.69065483 -0.0079891   0.84896987  0.02436603
#   0.12426053 -0.00496911 -0.81239234  0.2143667   0.20149151  0.91220797]
# Accuracy:  73.5632183908046 %
# Error Rate:  26.436781609195403 %
# Precision:  75.08417508417509 %
# Recall:  88.31683168316832 %
#
# Number of Iterations = 10992
# Minimum Cost (J) = 0.4946977734783972
# Weights of Model:  [ 0.94269606 -0.06332847 -0.7463793  -0.01167584  0.59667169  0.04404115
#   0.19595306 -0.00699255 -0.38620762  0.04921902  0.21008307  1.18876584]
# Accuracy:  74.20178799489145 %
# Error Rate:  25.798212005108557 %
# Precision:  75.76271186440678 %
# Recall:  88.3399209486166 %
#
# Number of Iterations = 16188
# Minimum Cost (J) = 0.5130380661348
# Weights of Model:  [ 0.87826877 -0.0399871  -0.64898138  0.04141097  0.58698282  0.02167981
#   0.16248449 -0.02943977 -0.44407691  0.1007846   0.1439261   1.08633975]
# Accuracy:  78.9272030651341 %
# Error Rate:  21.0727969348659 %
# Precision:  81.5126050420168 %
# Recall:  89.81481481481481 %
#
# Number of Iterations = 20324
# Minimum Cost (J) = 0.5017976521673287
# Weights of Model:  [ 8.96046302e-01  8.16843498e-04 -7.05481498e-01  2.42415657e-02
#   7.02819804e-01  5.10383667e-02  1.41992490e-01 -6.37494964e-02
#  -4.97452718e-01  1.12603538e-01  2.07602122e-01  1.12294945e+00]
# Accuracy:  73.69093231162196 %
# Error Rate:  26.309067688378036 %
# Precision:  78.38312829525483 %
# Recall:  84.31001890359168 %
#
# Number of Iterations = 25826
# Minimum Cost (J) = 0.4994906504030446
# Weights of Model:  [ 0.92340313 -0.01108307 -0.69616906  0.01292875  0.77724308  0.05036083
#   0.08987405 -0.01055024 -0.59981121  0.13248649  0.1955113   1.09888801]
# Accuracy:  76.11749680715198 %
# Error Rate:  23.88250319284802 %
# Precision:  78.55917667238423 %
# Recall:  88.07692307692308 %
#
# average cross validation model accuracy = 75.30012771392083%
# Text(0, 0.5, 'Model Accuracy (%)')

# %%
#Plot Accuracy of Train/Validation Set as a Function of Iterations of Gradient Descent
#Limit number of steps

#Initialize
number_of_iterations = [100, 500, 1000, 2000, 2500, 5000, 7500, 10000, 15000, 20000, 30000, 50000]
iter_accuracy = []

for num_steps in number_of_iterations:
    
    average_cross_validation_accuracy = cross_validation_LR(Model_Logistic_Regression, x_train, y_train, K = 5, num_steps = num_steps, learning_rate = 0.01, min_error = 1e-2, random_shuffle = False)
    iter_accuracy.append(average_cross_validation_accuracy)

#Plot
plt.plot(number_of_iterations, iter_accuracy)
plt.title("Number of Iterations vs Model Accuracy (Wine Dataset)")
plt.xlabel("Number of Iterations")
plt.ylabel("Model Accuracy (%)")
# Out:
# Number of Iterations = 99
# Minimum Cost (J) = 0.623297400289454
# Weights of Model:  [ 0.14933555 -0.02287309 -0.09700601  0.00131971 -0.01805629 -0.06234716
#   0.0041984  -0.05134494 -0.08843712  0.03353794  0.02579808  0.14257253]
# Accuracy:  68.96551724137932 %
# Error Rate:  31.03448275862069 %
# Precision:  75.8893280632411 %
# Recall:  76.03960396039604 %
#
# Number of Iterations = 99
# Minimum Cost (J) = 0.6223730657983334
# Weights of Model:  [ 0.1491826  -0.03263926 -0.10117033  0.00358896 -0.01588919 -0.05638394
#   0.01471668 -0.04597848 -0.08971475  0.02839733  0.02606283  0.14537173]
# Accuracy:  70.242656449553 %
# Error Rate:  29.757343550446997 %
# Precision:  76.30057803468208 %
# Recall:  78.26086956521739 %
#
# Number of Iterations = 99
# Minimum Cost (J) = 0.6266696752886253
# Weights of Model:  [ 0.13993515 -0.02827604 -0.09274388  0.00903873 -0.02116065 -0.05743136
#   0.00637414 -0.0512426  -0.09113431  0.02799609  0.0186999   0.14389724]
# Accuracy:  72.41379310344827 %
# Error Rate:  27.586206896551722 %
# Precision:  81.3953488372093 %
# Recall:  77.77777777777779 %
#
# Number of Iterations = 99
# Minimum Cost (J) = 0.6240842938142155
# Weights of Model:  [ 0.14275355 -0.02459539 -0.09967554  0.00780877 -0.01412296 -0.06029194
#   0.00375397 -0.05750298 -0.0880454   0.0277287   0.01908573  0.14576646]
# Accuracy:  68.83780332056195 %
# Error Rate:  31.162196679438058 %
# Precision:  78.90466531440163 %
# Recall:  73.53497164461248 %
#
# Number of Iterations = 99
# Minimum Cost (J) = 0.6235589117193927
# Weights of Model:  [ 0.14530979 -0.0319834  -0.08950608  0.00547725 -0.01376688 -0.05919766
#   0.00108104 -0.05298696 -0.09044081  0.03078733  0.02438651  0.14931039]
# Accuracy:  69.98722860791827 %
# Error Rate:  30.01277139208174 %
# Precision:  77.99607072691552 %
# Recall:  76.34615384615384 %
#
# average cross validation model accuracy = 70.08939974457215%
#
# Number of Iterations = 499
# Minimum Cost (J) = 0.5432197336214313
# Weights of Model:  [ 0.5010156  -0.04045906 -0.32883845  0.02126466  0.07453841 -0.13606247
#   0.07736064 -0.08780482 -0.19014523  0.0800623   0.08910709  0.4276052 ]
# Accuracy:  72.66922094508301 %
# Error Rate:  27.330779054916988 %
# Precision:  75.4816112084063 %
# Recall:  85.34653465346534 %
#
# Number of Iterations = 499
# Minimum Cost (J) = 0.5388885195021259
# Weights of Model:  [ 0.50140133 -0.06894403 -0.3422795   0.02556843  0.07968532 -0.12028349
#   0.1070961  -0.073732   -0.19342064  0.05317803  0.08953189  0.44275065]
# Accuracy:  72.03065134099617 %
# Error Rate:  27.969348659003828 %
# Precision:  74.69879518072288 %
# Recall:  85.7707509881423 %
#
# Number of Iterations = 499
# Minimum Cost (J) = 0.551286756906573
# Weights of Model:  [ 0.47155043 -0.06092347 -0.31271593  0.04694263  0.0647767  -0.1234208
#   0.08831978 -0.08608869 -0.19541875  0.06041762  0.0676728   0.43413607]
# Accuracy:  75.09578544061303 %
# Error Rate:  24.904214559386972 %
# Precision:  80.21015761821366 %
# Recall:  84.81481481481481 %
#
# Number of Iterations = 499
# Minimum Cost (J) = 0.5443812712207199
# Weights of Model:  [ 0.47918501 -0.04969091 -0.33203066  0.04183726  0.08934278 -0.13170775
#   0.0766723  -0.10957406 -0.18641546  0.05963379  0.07618279  0.44347062]
# Accuracy:  71.51979565772669 %
# Error Rate:  28.480204342273307 %
# Precision:  78.02197802197803 %
# Recall:  80.52930056710775 %
#
# Number of Iterations = 499
# Minimum Cost (J) = 0.5436151900492237
# Weights of Model:  [ 0.48850722 -0.06686749 -0.30940827  0.03614122  0.09486149 -0.12611469
#   0.06552321 -0.0923721  -0.19021955  0.0652274   0.08299367  0.45221197]
# Accuracy:  73.81864623243933 %
# Error Rate:  26.181353767560665 %
# Precision:  77.77777777777779 %
# Recall:  84.8076923076923 %
#
# average cross validation model accuracy = 73.02681992337165%
#
# Number of Iterations = 999
# Minimum Cost (J) = 0.5194974422071809
# Weights of Model:  [ 0.69105215 -0.03927806 -0.46454958  0.02527361  0.19765143 -0.13145175
#   0.12854634 -0.08957085 -0.2310657   0.09710235  0.12524647  0.62405684]
# Accuracy:  71.9029374201788 %
# Error Rate:  28.097062579821202 %
# Precision:  73.78964941569282 %
# Recall:  87.52475247524752 %
#
# Number of Iterations = 999
# Minimum Cost (J) = 0.5134066522825768
# Weights of Model:  [ 0.69307965 -0.07902972 -0.48563467  0.02824346  0.20223416 -0.11114275
#   0.1674421  -0.07267405 -0.23295759  0.05027741  0.12890599  0.65163726]
# Accuracy:  72.92464878671775 %
# Error Rate:  27.07535121328225 %
# Precision:  74.4186046511628 %
# Recall:  88.53754940711462 %
#
# Number of Iterations = 999
# Minimum Cost (J) = 0.5287934376860898
# Weights of Model:  [ 0.65101328 -0.07076886 -0.4398955   0.06046767  0.18154114 -0.11798852
#   0.14619286 -0.08767057 -0.23404487  0.06762639  0.09627304  0.63486939]
# Accuracy:  77.01149425287356 %
# Error Rate:  22.988505747126435 %
# Precision:  80.3030303030303 %
# Recall:  88.33333333333333 %
#
# Number of Iterations = 999
# Minimum Cost (J) = 0.5201575134480658
# Weights of Model:  [ 0.66048719 -0.05505037 -0.4662173   0.05230157  0.21894259 -0.12329531
#   0.12942885 -0.1208465  -0.22157063  0.06664369  0.11639104  0.65112907]
# Accuracy:  71.77522349936143 %
# Error Rate:  28.22477650063857 %
# Precision:  77.11267605633803 %
# Recall:  82.79773156899812 %
#
# Number of Iterations = 999
# Minimum Cost (J) = 0.5187457740441999
# Weights of Model:  [ 0.6745434  -0.07522293 -0.44430252  0.04439682  0.22821004 -0.11685864
#   0.10936404 -0.09513117 -0.22730836  0.07227339  0.11828235  0.66353485]
# Accuracy:  75.47892720306514 %
# Error Rate:  24.521072796934863 %
# Precision:  77.79661016949152 %
# Recall:  88.26923076923077 %
#
# average cross validation model accuracy = 73.81864623243935%
#
# Number of Iterations = 1999
# Minimum Cost (J) = 0.5072760094596558
# Weights of Model:  [ 0.82712367 -0.03012776 -0.57969689  0.01376241  0.35676486 -0.08027226
#   0.15982588 -0.08333523 -0.28176362  0.11230809  0.1564364   0.8493358 ]
# Accuracy:  73.43550446998724 %
# Error Rate:  26.56449553001277 %
# Precision:  74.95798319327731 %
# Recall:  88.31683168316832 %
#
# Number of Iterations = 1999
# Minimum Cost (J) = 0.4999631495239871
# Weights of Model:  [ 0.832752   -0.08250771 -0.61147946  0.01467211  0.35703342 -0.05677612
#   0.20733997 -0.06519175 -0.27438208  0.0424741   0.16847783  0.89629093]
# Accuracy:  74.07407407407408 %
# Error Rate:  25.925925925925924 %
# Precision:  75.04132231404958 %
# Recall:  89.72332015810277 %
#
# Number of Iterations = 1999
# Minimum Cost (J) = 0.5173191944513836
# Weights of Model:  [ 0.78027184 -0.07316658 -0.54618169  0.05702142  0.32892093 -0.06958237
#   0.18219271 -0.08335952 -0.27406755  0.07184523  0.12094496  0.86430087]
# Accuracy:  77.77777777777779 %
# Error Rate:  22.22222222222222 %
# Precision:  80.39867109634552 %
# Recall:  89.62962962962962 %
#
# Number of Iterations = 1999
# Minimum Cost (J) = 0.5071996810832258
# Weights of Model:  [ 0.79114861 -0.05290427 -0.58168489  0.04499748  0.3800964  -0.06318279
#   0.16394664 -0.12334185 -0.26123276  0.07100242  0.15827691  0.89244343]
# Accuracy:  73.69093231162196 %
# Error Rate:  26.309067688378036 %
# Precision:  77.70154373927959 %
# Recall:  85.63327032136105 %
#
# Number of Iterations = 1999
# Minimum Cost (J) = 0.5053296919510337
# Weights of Model:  [ 0.8103231  -0.07601922 -0.56570493  0.03441431  0.39373798 -0.0601899
#   0.13211313 -0.08712309 -0.27139905  0.07643335  0.151842    0.90781801]
# Accuracy:  74.71264367816092 %
# Error Rate:  25.287356321839084 %
# Precision:  77.38095238095238 %
# Recall:  87.5 %
#
# average cross validation model accuracy = 74.73818646232439%
#
# Number of Iterations = 2499
# Minimum Cost (J) = 0.5052676280398912
# Weights of Model:  [ 0.85608632 -0.02483964 -0.60875745  0.00797404  0.40909619 -0.0584222
#   0.16283806 -0.07783299 -0.30097166  0.11753611  0.16417098  0.91636689]
# Accuracy:  73.30779054916987 %
# Error Rate:  26.69220945083014 %
# Precision:  74.91582491582491 %
# Recall:  88.11881188118812 %
#
# Number of Iterations = 2499
# Minimum Cost (J) = 0.49773842900506216
# Weights of Model:  [ 0.86321036 -0.08145218 -0.64434499  0.0084643   0.4063631  -0.03405746
#   0.21292436 -0.05958249 -0.28769418  0.0407488   0.17959735  0.9715188 ]
# Accuracy:  73.9463601532567 %
# Error Rate:  26.053639846743295 %
# Precision:  75.0 %
# Recall:  89.52569169960475 %
#
# Number of Iterations = 2499
# Minimum Cost (J) = 0.5154998940616733
# Weights of Model:  [ 0.80815105 -0.07158413 -0.5727668   0.0533978   0.37537214 -0.04896205
#   0.18617265 -0.07882563 -0.28725115  0.07357561  0.12702179  0.93267116]
# Accuracy:  78.03320561941251 %
# Error Rate:  21.966794380587483 %
# Precision:  80.76923076923077 %
# Recall:  89.44444444444444 %
# Number of Iterations = 2499
# Minimum Cost (J) = 0.5050274721816086
# Weights of Model:  [ 0.81964069 -0.04978011 -0.6119143   0.04006456  0.43108467 -0.0378023
#   0.16843737 -0.11998667 -0.27555799  0.07287067  0.17000199  0.96580641]
# Accuracy:  73.05236270753512 %
# Error Rate:  26.947637292464876 %
# Precision:  77.41379310344828 %
# Recall:  84.87712665406427 %
#
# Number of Iterations = 2499
# Minimum Cost (J) = 0.5030800146730587
# Weights of Model:  [ 0.84039488 -0.0740581  -0.59813618  0.02878789  0.44631789 -0.03654645
#   0.13275248 -0.08020001 -0.28788053  0.0781798   0.16088592  0.98148987]
# Accuracy:  75.35121328224777 %
# Error Rate:  24.648786717752238 %
# Precision:  77.8534923339012 %
# Recall:  87.88461538461539 %
#
# average cross validation model accuracy = 74.73818646232439%
#
# Number of Iterations = 3493
# Minimum Cost (J) = 0.5035090920498545
# Weights of Model:  [ 8.88477454e-01 -1.52867219e-02 -6.44382864e-01 -3.14644349e-04
#   4.82093766e-01 -2.83321359e-02  1.60975125e-01 -6.58939681e-02
#  -3.33587118e-01  1.26109016e-01  1.72962839e-01  9.99720090e-01]
# Accuracy:  73.30779054916987 %
# Error Rate:  26.69220945083014 %
# Precision:  74.91582491582491 %
# Recall:  88.11881188118812 %
#
# Number of Iterations = 3554
# Minimum Cost (J) = 0.4957516372631763
# Weights of Model:  [ 8.99371393e-01 -7.80997570e-02 -6.87406853e-01 -6.31601393e-04
#   4.75619134e-01 -1.05265205e-03  2.14528230e-01 -4.69058665e-02
#  -3.08766772e-01  3.99333317e-02  1.93673818e-01  1.07347537e+00]
# Accuracy:  74.20178799489145 %
# Error Rate:  25.798212005108557 %
# Precision:  75.33333333333333 %
# Recall:  89.32806324110672 %
#
# Number of Iterations = 3315
# Minimum Cost (J) = 0.5141407712174669
# Weights of Model:  [ 0.83536962 -0.06835817 -0.60077227  0.04860629  0.42828347 -0.02457528
#   0.18619243 -0.07032095 -0.30458568  0.07637353  0.13288546  1.00681224]
# Accuracy:  78.16091954022988 %
# Error Rate:  21.839080459770116 %
# Precision:  81.00840336134453 %
# Recall:  89.25925925925927 %
#
# Number of Iterations = 3540
# Minimum Cost (J) = 0.5030933189686911
# Weights of Model:  [ 0.85337897 -0.04317915 -0.6515717   0.03234606  0.50244694 -0.00176601
#   0.1689311  -0.10980298 -0.30021661  0.0768146   0.18456266  1.0628086 ]
# Accuracy:  73.18007662835248 %
# Error Rate:  26.81992337164751 %
# Precision:  77.64298093587522 %
# Recall:  84.68809073724007 %
#
# Number of Iterations = 3591
# Minimum Cost (J) = 0.5010115354111666
# Weights of Model:  [ 0.87754626 -0.06903197 -0.64224721  0.02007144  0.52323965 -0.00163339
#   0.12746085 -0.06429923 -0.31803113  0.08210082  0.17237787  1.08144219]
# Accuracy:  75.98978288633461 %
# Error Rate:  24.010217113665387 %
# Precision:  78.62068965517241 %
# Recall:  87.6923076923077 %
#
# average cross validation model accuracy = 74.96807151979564%
#
# Number of Iterations = 3493
# Minimum Cost (J) = 0.5035090920498545
# Weights of Model:  [ 8.88477454e-01 -1.52867219e-02 -6.44382864e-01 -3.14644349e-04
#   4.82093766e-01 -2.83321359e-02  1.60975125e-01 -6.58939681e-02
#  -3.33587118e-01  1.26109016e-01  1.72962839e-01  9.99720090e-01]
# Accuracy:  73.30779054916987 %
# Error Rate:  26.69220945083014 %
# Precision:  74.91582491582491 %
# Recall:  88.11881188118812 %
#
# Number of Iterations = 3554
# Minimum Cost (J) = 0.4957516372631763
# Weights of Model:  [ 8.99371393e-01 -7.80997570e-02 -6.87406853e-01 -6.31601393e-04
#   4.75619134e-01 -1.05265205e-03  2.14528230e-01 -4.69058665e-02
#  -3.08766772e-01  3.99333317e-02  1.93673818e-01  1.07347537e+00]
# Accuracy:  74.20178799489145 %
# Error Rate:  25.798212005108557 %
# Precision:  75.33333333333333 %
# Recall:  89.32806324110672 %
#
# Number of Iterations = 3315
# Minimum Cost (J) = 0.5141407712174669
# Weights of Model:  [ 0.83536962 -0.06835817 -0.60077227  0.04860629  0.42828347 -0.02457528
#   0.18619243 -0.07032095 -0.30458568  0.07637353  0.13288546  1.00681224]
# Accuracy:  78.16091954022988 %
# Error Rate:  21.839080459770116 %
# Precision:  81.00840336134453 %
# Recall:  89.25925925925927 %
#
# Number of Iterations = 3540
# Minimum Cost (J) = 0.5030933189686911
# Weights of Model:  [ 0.85337897 -0.04317915 -0.6515717   0.03234606  0.50244694 -0.00176601
#   0.1689311  -0.10980298 -0.30021661  0.0768146   0.18456266  1.0628086 ]
# Accuracy:  73.18007662835248 %
# Error Rate:  26.81992337164751 %
# Precision:  77.64298093587522 %
# Recall:  84.68809073724007 %
#
# Number of Iterations = 3591
# Minimum Cost (J) = 0.5010115354111666
# Weights of Model:  [ 0.87754626 -0.06903197 -0.64224721  0.02007144  0.52323965 -0.00163339
#   0.12746085 -0.06429923 -0.31803113  0.08210082  0.17237787  1.08144219]
# Accuracy:  75.98978288633461 %
# Error Rate:  24.010217113665387 %
# Precision:  78.62068965517241 %
# Recall:  87.6923076923077 %
#
# average cross validation model accuracy = 74.96807151979564%
#
# Number of Iterations = 3493
# Minimum Cost (J) = 0.5035090920498545
# Weights of Model:  [ 8.88477454e-01 -1.52867219e-02 -6.44382864e-01 -3.14644349e-04
#   4.82093766e-01 -2.83321359e-02  1.60975125e-01 -6.58939681e-02
#  -3.33587118e-01  1.26109016e-01  1.72962839e-01  9.99720090e-01]
# Accuracy:  73.30779054916987 %
# Error Rate:  26.69220945083014 %
# Precision:  74.91582491582491 %
# Recall:  88.11881188118812 %
#
# Number of Iterations = 3554
# Minimum Cost (J) = 0.4957516372631763
# Weights of Model:  [ 8.99371393e-01 -7.80997570e-02 -6.87406853e-01 -6.31601393e-04
#   4.75619134e-01 -1.05265205e-03  2.14528230e-01 -4.69058665e-02
#  -3.08766772e-01  3.99333317e-02  1.93673818e-01  1.07347537e+00]
# Accuracy:  74.20178799489145 %
# Error Rate:  25.798212005108557 %
# Precision:  75.33333333333333 %
# Recall:  89.32806324110672 %
#
# Number of Iterations = 3315
# Minimum Cost (J) = 0.5141407712174669
# Weights of Model:  [ 0.83536962 -0.06835817 -0.60077227  0.04860629  0.42828347 -0.02457528
#   0.18619243 -0.07032095 -0.30458568  0.07637353  0.13288546  1.00681224]
# Accuracy:  78.16091954022988 %
# Error Rate:  21.839080459770116 %
# Precision:  81.00840336134453 %
# Recall:  89.25925925925927 %
#
# Number of Iterations = 3540
# Minimum Cost (J) = 0.5030933189686911
# Weights of Model:  [ 0.85337897 -0.04317915 -0.6515717   0.03234606  0.50244694 -0.00176601
#   0.1689311  -0.10980298 -0.30021661  0.0768146   0.18456266  1.0628086 ]
# Accuracy:  73.18007662835248 %
# Error Rate:  26.81992337164751 %
# Precision:  77.64298093587522 %
# Recall:  84.68809073724007 %
#
# Number of Iterations = 3591
# Minimum Cost (J) = 0.5010115354111666
# Weights of Model:  [ 0.87754626 -0.06903197 -0.64224721  0.02007144  0.52323965 -0.00163339
#   0.12746085 -0.06429923 -0.31803113  0.08210082  0.17237787  1.08144219]
# Accuracy:  75.98978288633461 %
# Error Rate:  24.010217113665387 %
# Precision:  78.62068965517241 %
# Recall:  87.6923076923077 %
#
# average cross validation model accuracy = 74.96807151979564%
#
# Number of Iterations = 3493
# Minimum Cost (J) = 0.5035090920498545
# Weights of Model:  [ 8.88477454e-01 -1.52867219e-02 -6.44382864e-01 -3.14644349e-04
#   4.82093766e-01 -2.83321359e-02  1.60975125e-01 -6.58939681e-02
#  -3.33587118e-01  1.26109016e-01  1.72962839e-01  9.99720090e-01]
# Accuracy:  73.30779054916987 %
# Error Rate:  26.69220945083014 %
# Precision:  74.91582491582491 %
# Recall:  88.11881188118812 %
#
# Number of Iterations = 3554
# Minimum Cost (J) = 0.4957516372631763
# Weights of Model:  [ 8.99371393e-01 -7.80997570e-02 -6.87406853e-01 -6.31601393e-04
#   4.75619134e-01 -1.05265205e-03  2.14528230e-01 -4.69058665e-02
#  -3.08766772e-01  3.99333317e-02  1.93673818e-01  1.07347537e+00]
# Accuracy:  74.20178799489145 %
# Error Rate:  25.798212005108557 %
# Precision:  75.33333333333333 %
# Recall:  89.32806324110672 %
#
# Number of Iterations = 3315
# Minimum Cost (J) = 0.5141407712174669
# Weights of Model:  [ 0.83536962 -0.06835817 -0.60077227  0.04860629  0.42828347 -0.02457528
#   0.18619243 -0.07032095 -0.30458568  0.07637353  0.13288546  1.00681224]
# Accuracy:  78.16091954022988 %
# Error Rate:  21.839080459770116 %
# Precision:  81.00840336134453 %
# Recall:  89.25925925925927 %
#
# Number of Iterations = 3540
# Minimum Cost (J) = 0.5030933189686911
# Weights of Model:  [ 0.85337897 -0.04317915 -0.6515717   0.03234606  0.50244694 -0.00176601
#   0.1689311  -0.10980298 -0.30021661  0.0768146   0.18456266  1.0628086 ]
# Accuracy:  73.18007662835248 %
# Error Rate:  26.81992337164751 %
# Precision:  77.64298093587522 %
# Recall:  84.68809073724007 %
#
# Number of Iterations = 3591
# Minimum Cost (J) = 0.5010115354111666
# Weights of Model:  [ 0.87754626 -0.06903197 -0.64224721  0.02007144  0.52323965 -0.00163339
#   0.12746085 -0.06429923 -0.31803113  0.08210082  0.17237787  1.08144219]
# Accuracy:  75.98978288633461 %
# Error Rate:  24.010217113665387 %
# Precision:  78.62068965517241 %
# Recall:  87.6923076923077 %
#
# average cross validation model accuracy = 74.96807151979564%
# Number of Iterations = 3493
# Minimum Cost (J) = 0.5035090920498545
# Weights of Model:  [ 8.88477454e-01 -1.52867219e-02 -6.44382864e-01 -3.14644349e-04
#   4.82093766e-01 -2.83321359e-02  1.60975125e-01 -6.58939681e-02
#  -3.33587118e-01  1.26109016e-01  1.72962839e-01  9.99720090e-01]
# Accuracy:  73.30779054916987 %
# Error Rate:  26.69220945083014 %
# Precision:  74.91582491582491 %
# Recall:  88.11881188118812 %
#
# Number of Iterations = 3554
# Minimum Cost (J) = 0.4957516372631763
# Weights of Model:  [ 8.99371393e-01 -7.80997570e-02 -6.87406853e-01 -6.31601393e-04
#   4.75619134e-01 -1.05265205e-03  2.14528230e-01 -4.69058665e-02
#  -3.08766772e-01  3.99333317e-02  1.93673818e-01  1.07347537e+00]
# Accuracy:  74.20178799489145 %
# Error Rate:  25.798212005108557 %
# Precision:  75.33333333333333 %
# Recall:  89.32806324110672 %
#
# Number of Iterations = 3315
# Minimum Cost (J) = 0.5141407712174669
# Weights of Model:  [ 0.83536962 -0.06835817 -0.60077227  0.04860629  0.42828347 -0.02457528
#   0.18619243 -0.07032095 -0.30458568  0.07637353  0.13288546  1.00681224]
# Accuracy:  78.16091954022988 %
# Error Rate:  21.839080459770116 %
# Precision:  81.00840336134453 %
# Recall:  89.25925925925927 %
#
# Number of Iterations = 3540
# Minimum Cost (J) = 0.5030933189686911
# Weights of Model:  [ 0.85337897 -0.04317915 -0.6515717   0.03234606  0.50244694 -0.00176601
#   0.1689311  -0.10980298 -0.30021661  0.0768146   0.18456266  1.0628086 ]
# Accuracy:  73.18007662835248 %
# Error Rate:  26.81992337164751 %
# Precision:  77.64298093587522 %
# Recall:  84.68809073724007 %
#
# Number of Iterations = 3591
# Minimum Cost (J) = 0.5010115354111666
# Weights of Model:  [ 0.87754626 -0.06903197 -0.64224721  0.02007144  0.52323965 -0.00163339
#   0.12746085 -0.06429923 -0.31803113  0.08210082  0.17237787  1.08144219]
# Accuracy:  75.98978288633461 %
# Error Rate:  24.010217113665387 %
# Precision:  78.62068965517241 %
# Recall:  87.6923076923077 %
#
# average cross validation model accuracy = 74.96807151979564%
#
# Number of Iterations = 3493
# Minimum Cost (J) = 0.5035090920498545
# Weights of Model:  [ 8.88477454e-01 -1.52867219e-02 -6.44382864e-01 -3.14644349e-04
#   4.82093766e-01 -2.83321359e-02  1.60975125e-01 -6.58939681e-02
#  -3.33587118e-01  1.26109016e-01  1.72962839e-01  9.99720090e-01]
# Accuracy:  73.30779054916987 %
# Error Rate:  26.69220945083014 %
# Precision:  74.91582491582491 %
# Recall:  88.11881188118812 %
#
# Number of Iterations = 3554
# Minimum Cost (J) = 0.4957516372631763
# Weights of Model:  [ 8.99371393e-01 -7.80997570e-02 -6.87406853e-01 -6.31601393e-04
#   4.75619134e-01 -1.05265205e-03  2.14528230e-01 -4.69058665e-02
#  -3.08766772e-01  3.99333317e-02  1.93673818e-01  1.07347537e+00]
# Accuracy:  74.20178799489145 %
# Error Rate:  25.798212005108557 %
# Precision:  75.33333333333333 %
# Recall:  89.32806324110672 %
#
# Number of Iterations = 3315
# Minimum Cost (J) = 0.5141407712174669
# Weights of Model:  [ 0.83536962 -0.06835817 -0.60077227  0.04860629  0.42828347 -0.02457528
#   0.18619243 -0.07032095 -0.30458568  0.07637353  0.13288546  1.00681224]
# Accuracy:  78.16091954022988 %
# Error Rate:  21.839080459770116 %
# Precision:  81.00840336134453 %
# Recall:  89.25925925925927 %
#
# Number of Iterations = 3540
# Minimum Cost (J) = 0.5030933189686911
# Weights of Model:  [ 0.85337897 -0.04317915 -0.6515717   0.03234606  0.50244694 -0.00176601
#   0.1689311  -0.10980298 -0.30021661  0.0768146   0.18456266  1.0628086 ]
# Accuracy:  73.18007662835248 %
# Error Rate:  26.81992337164751 %
# Precision:  77.64298093587522 %
# Recall:  84.68809073724007 %
#
# Number of Iterations = 3591
# Minimum Cost (J) = 0.5010115354111666
# Weights of Model:  [ 0.87754626 -0.06903197 -0.64224721  0.02007144  0.52323965 -0.00163339
#   0.12746085 -0.06429923 -0.31803113  0.08210082  0.17237787  1.08144219]
# Accuracy:  75.98978288633461 %
# Error Rate:  24.010217113665387 %
# Precision:  78.62068965517241 %
# Recall:  87.6923076923077 %
#
# average cross validation model accuracy = 74.96807151979564%
#
# Number of Iterations = 3493
# Minimum Cost (J) = 0.5035090920498545
# Weights of Model:  [ 8.88477454e-01 -1.52867219e-02 -6.44382864e-01 -3.14644349e-04
#   4.82093766e-01 -2.83321359e-02  1.60975125e-01 -6.58939681e-02
#  -3.33587118e-01  1.26109016e-01  1.72962839e-01  9.99720090e-01]
# Accuracy:  73.30779054916987 %
# Error Rate:  26.69220945083014 %
# Precision:  74.91582491582491 %
# Recall:  88.11881188118812 %
#
# Number of Iterations = 3554
# Minimum Cost (J) = 0.4957516372631763
# Weights of Model:  [ 8.99371393e-01 -7.80997570e-02 -6.87406853e-01 -6.31601393e-04
#   4.75619134e-01 -1.05265205e-03  2.14528230e-01 -4.69058665e-02
#  -3.08766772e-01  3.99333317e-02  1.93673818e-01  1.07347537e+00]
# Accuracy:  74.20178799489145 %
# Error Rate:  25.798212005108557 %
# Precision:  75.33333333333333 %
# Recall:  89.32806324110672 %
#
# Number of Iterations = 3315
# Minimum Cost (J) = 0.5141407712174669
# Weights of Model:  [ 0.83536962 -0.06835817 -0.60077227  0.04860629  0.42828347 -0.02457528
#   0.18619243 -0.07032095 -0.30458568  0.07637353  0.13288546  1.00681224]
# Accuracy:  78.16091954022988 %
# Error Rate:  21.839080459770116 %
# Precision:  81.00840336134453 %
# Recall:  89.25925925925927 %
#
# Number of Iterations = 3540
# Minimum Cost (J) = 0.5030933189686911
# Weights of Model:  [ 0.85337897 -0.04317915 -0.6515717   0.03234606  0.50244694 -0.00176601
#   0.1689311  -0.10980298 -0.30021661  0.0768146   0.18456266  1.0628086 ]
# Accuracy:  73.18007662835248 %
# Error Rate:  26.81992337164751 %
# Precision:  77.64298093587522 %
# Recall:  84.68809073724007 %
#
# Number of Iterations = 3591
# Minimum Cost (J) = 0.5010115354111666
# Weights of Model:  [ 0.87754626 -0.06903197 -0.64224721  0.02007144  0.52323965 -0.00163339
#   0.12746085 -0.06429923 -0.31803113  0.08210082  0.17237787  1.08144219]
# Accuracy:  75.98978288633461 %
# Error Rate:  24.010217113665387 %
# Precision:  78.62068965517241 %
# Recall:  87.6923076923077 %
#
# average cross validation model accuracy = 74.96807151979564%
# Text(0, 0.5, 'Model Accuracy (%)')

# %%
#Adjust size of datasets and compare accuracy
#Compare 5 different sizes

length = int(len(x_train))
length90 = int(length*0.9)
length75 = int(length*0.75)
length50 = int(length*0.5)
length25 = int(length*0.25)
length10 = int(length*0.1)

x_train_reduced = [x_train[:length90,:], x_train[:length75,:], x_train[:length50,:], x_train[:length25,:], x_train[:length10,:]] 
y_train_reduced = [y_train[:length90], y_train[:length75], y_train[:length50], y_train[:length25], y_train[:length10]]
percentage_of_original = [100, 90, 75, 50, 25]
lr_accuracy = []
nb_accuracy = []

lr_average_cross_validation_accuracy = cross_validation_LR(Model_Logistic_Regression, x_train, y_train, K = 5, num_steps = 5000, learning_rate = 0.01, min_error = 1e-2, random_shuffle = False)
nb_average_cross_validation_accuracy = cross_validation_NB(Model_Naive_Bayes, x_train, y_train, K = 5, random_shuffle = False)
lr_accuracy.append(lr_average_cross_validation_accuracy)
nb_accuracy.append(nb_average_cross_validation_accuracy)


lr_average_cross_validation_accuracy = cross_validation_LR(Model_Logistic_Regression, x_train[:length90,:], y_train[:length90], K = 5, num_steps = 5000, learning_rate = 0.01, min_error = 1e-2, random_shuffle = False)
nb_average_cross_validation_accuracy = cross_validation_NB(Model_Naive_Bayes, x_train[:length90,:], y_train[:length90], K = 5, random_shuffle = False)
lr_accuracy.append(lr_average_cross_validation_accuracy)
nb_accuracy.append(nb_average_cross_validation_accuracy)

lr_average_cross_validation_accuracy = cross_validation_LR(Model_Logistic_Regression, x_train[:length75,:], y_train[:length75], K = 5, num_steps = 5000, learning_rate = 0.01, min_error = 1e-2, random_shuffle = False)
nb_average_cross_validation_accuracy = cross_validation_NB(Model_Naive_Bayes, x_train[:length75,:], y_train[:length75], K = 5, random_shuffle = False)
lr_accuracy.append(lr_average_cross_validation_accuracy)
nb_accuracy.append(nb_average_cross_validation_accuracy)

lr_average_cross_validation_accuracy = cross_validation_LR(Model_Logistic_Regression, x_train[:length50,:], y_train[:length50], K = 5, num_steps = 5000, learning_rate = 0.01, min_error = 1e-2, random_shuffle = False)
nb_average_cross_validation_accuracy = cross_validation_NB(Model_Naive_Bayes, x_train[:length50,:], y_train[:length50], K = 5, random_shuffle = False)
lr_accuracy.append(lr_average_cross_validation_accuracy)
nb_accuracy.append(nb_average_cross_validation_accuracy)

lr_average_cross_validation_accuracy = cross_validation_LR(Model_Logistic_Regression, x_train[:length25,:], y_train[:length25], K = 5, num_steps = 5000, learning_rate = 0.01, min_error = 1e-2, random_shuffle = False)
nb_average_cross_validation_accuracy = cross_validation_NB(Model_Naive_Bayes, x_train[:length25,:], y_train[:length25], K = 5, random_shuffle = False)
lr_accuracy.append(lr_average_cross_validation_accuracy)
nb_accuracy.append(nb_average_cross_validation_accuracy)

#lr_average_cross_validation_accuracy = cross_validation_LR(Model_Logistic_Regression, x_train[:length10,:], y_train[:length10], K = 5, num_steps = 5000, learning_rate = 0.01, min_error = 1e-2, random_shuffle = False)
#nb_average_cross_validation_accuracy = cross_validation_NB(Model_Naive_Bayes, x_train[:length10,:], y_train[:length10], K = 5, random_shuffle = False)
#lr_accuracy.append(lr_average_cross_validation_accuracy)
#nb_accuracy.append(nb_average_cross_validation_accuracy)
        

#Plot
plt.plot(percentage_of_original, lr_accuracy)
plt.plot(percentage_of_original, nb_accuracy)
plt.title("Dataset Size vs Model Accuracy (White Wine)")
plt.xlabel("Percent of Original Size (%)")
plt.ylabel("Model Accuracy (%)")
plt.legend(["Logistic Regression", "Naive Bayes"])
# Out:
# Number of Iterations = 3493
# Minimum Cost (J) = 0.5035090920498545
# Weights of Model:  [ 8.88477454e-01 -1.52867219e-02 -6.44382864e-01 -3.14644349e-04
#   4.82093766e-01 -2.83321359e-02  1.60975125e-01 -6.58939681e-02
#  -3.33587118e-01  1.26109016e-01  1.72962839e-01  9.99720090e-01]
# Accuracy:  73.30779054916987 %
# Error Rate:  26.69220945083014 %
# Precision:  74.91582491582491 %
# Recall:  88.11881188118812 %
#
# Number of Iterations = 3554
# Minimum Cost (J) = 0.4957516372631763
# Weights of Model:  [ 8.99371393e-01 -7.80997570e-02 -6.87406853e-01 -6.31601393e-04
#   4.75619134e-01 -1.05265205e-03  2.14528230e-01 -4.69058665e-02
#  -3.08766772e-01  3.99333317e-02  1.93673818e-01  1.07347537e+00]
# Accuracy:  74.20178799489145 %
# Error Rate:  25.798212005108557 %
# Precision:  75.33333333333333 %
# Recall:  89.32806324110672 %
#
# Number of Iterations = 3315
# Minimum Cost (J) = 0.5141407712174669
# Weights of Model:  [ 0.83536962 -0.06835817 -0.60077227  0.04860629  0.42828347 -0.02457528
#   0.18619243 -0.07032095 -0.30458568  0.07637353  0.13288546  1.00681224]
# Accuracy:  78.16091954022988 %
# Error Rate:  21.839080459770116 %
# Precision:  81.00840336134453 %
# Recall:  89.25925925925927 %
#
# Number of Iterations = 3540
# Minimum Cost (J) = 0.5030933189686911
# Weights of Model:  [ 0.85337897 -0.04317915 -0.6515717   0.03234606  0.50244694 -0.00176601
#   0.1689311  -0.10980298 -0.30021661  0.0768146   0.18456266  1.0628086 ]
# Accuracy:  73.18007662835248 %
# Error Rate:  26.81992337164751 %
# Precision:  77.64298093587522 %
# Recall:  84.68809073724007 %
#
# Number of Iterations = 3591
# Minimum Cost (J) = 0.5010115354111666
# Weights of Model:  [ 0.87754626 -0.06903197 -0.64224721  0.02007144  0.52323965 -0.00163339
#   0.12746085 -0.06429923 -0.31803113  0.08210082  0.17237787  1.08144219]
# Accuracy:  75.98978288633461 %
# Error Rate:  24.010217113665387 %
# Precision:  78.62068965517241 %
# Recall:  87.6923076923077 %
#
# average cross validation model accuracy = 74.96807151979564%
#
# Accuracy:  69.47637292464879 %
# Error Rate:  30.52362707535121 %
# Precision:  76.18110236220473 %
# Recall:  76.63366336633663 %
#
# Accuracy:  69.09323116219667 %
# Error Rate:  30.906768837803323 %
# Precision:  74.08759124087592 %
# Recall:  80.23715415019763 %
#
# Accuracy:  73.43550446998724 %
# Error Rate:  26.56449553001277 %
# Precision:  81.08614232209737 %
# Recall:  80.18518518518518 %
#
# Accuracy:  68.45466155810983 %
# Error Rate:  31.545338441890163 %
# Precision:  77.32558139534885 %
# Recall:  75.42533081285444 %
#
# Accuracy:  70.75351213282248 %
# Error Rate:  29.246487867177525 %
# Precision:  78.92644135188867 %
# Recall:  76.34615384615384 %
#
# average cross validation model accuracy = 70.242656449553%
#
# Number of Iterations = 3589
# Minimum Cost (J) = 0.49910594178160933
# Weights of Model:  [ 0.88614438 -0.01764357 -0.62392447 -0.0094247   0.5158379  -0.01330998
#   0.18397042 -0.08873826 -0.33378078  0.13036699  0.16551195  1.06313426]
# Accuracy:  72.4822695035461 %
# Error Rate:  27.5177304964539 %
# Precision:  74.85822306238185 %
# Recall:  86.65207877461707 %
#
# Number of Iterations = 3606
# Minimum Cost (J) = 0.4946486980581738
# Weights of Model:  [ 0.90393601 -0.09373091 -0.66160371 -0.03068696  0.50608937 -0.00685105
#   0.23148149 -0.07951613 -0.29932823  0.03204882  0.16958772  1.1037521 ]
# Accuracy:  73.75886524822694 %
# Error Rate:  26.24113475177305 %
# Precision:  74.76459510357816 %
# Recall:  88.61607142857143 %
#
# Number of Iterations = 3480
# Minimum Cost (J) = 0.5054058159213303
# Weights of Model:  [ 0.83705383 -0.0734663  -0.61510329  0.03591465  0.46749126  0.00950954
#   0.19930753 -0.07138333 -0.28668582  0.10383506  0.16057746  1.09978271]
# Accuracy:  77.58865248226951 %
# Error Rate:  22.411347517730494 %
# Precision:  81.43133462282398 %
# Recall:  87.16356107660455 %
#
# Number of Iterations = 3547
# Minimum Cost (J) = 0.504071369221367
# Weights of Model:  [ 0.85619665 -0.05035975 -0.61709292  0.010901    0.50560109  0.01943358
#   0.15492218 -0.09821138 -0.30433787  0.07137941  0.16025045  1.09482804]
# Accuracy:  74.32624113475177 %
# Error Rate:  25.673758865248224 %
# Precision:  78.21969696969697 %
# Recall:  86.22129436325679 %
#
# Number of Iterations = 3614
# Minimum Cost (J) = 0.5003873260207838
# Weights of Model:  [ 0.86684153 -0.06788939 -0.63627354  0.0338233   0.54058352 -0.00949846
#   0.13205356 -0.092328   -0.30745342  0.09174521  0.18035258  1.09307714]
# Accuracy:  75.60283687943262 %
# Error Rate:  24.397163120567374 %
# Precision:  78.48837209302324 %
# Recall:  86.9098712446352 %
#
# average cross validation model accuracy = 74.75177304964538%
#
# Accuracy:  69.50354609929079 %
# Error Rate:  30.49645390070922 %
# Precision:  76.76991150442478 %
# Recall:  75.92997811816193 %
#
# Accuracy:  68.65248226950355 %
# Error Rate:  31.347517730496456 %
# Precision:  73.21063394683026 %
# Recall:  79.91071428571429 %
#
# Accuracy:  72.3404255319149 %
# Error Rate:  27.659574468085108 %
# Precision:  81.71806167400881 %
# Recall:  76.81159420289855 %
#
# Accuracy:  70.35460992907801 %
# Error Rate:  29.645390070921984 %
# Precision:  78.72340425531915 %
# Recall:  77.24425887265136 %
#
# Accuracy:  69.64539007092199 %
# Error Rate:  30.354609929078013 %
# Precision:  77.03862660944206 %
# Recall:  77.03862660944206 %
#
# average cross validation model accuracy = 70.09929078014184%
#
# Number of Iterations = 3675
# Minimum Cost (J) = 0.5012915097429842
# Weights of Model:  [ 0.86909746 -0.03099843 -0.64220709  0.02235336  0.53808137 -0.01572101
#   0.1079291  -0.0739055  -0.3495883   0.14818873  0.20498987  1.05921647]
# Accuracy:  73.08347529812606 %
# Error Rate:  26.916524701873932 %
# Precision:  76.08200455580865 %
# Recall:  86.30490956072352 %
#
# Number of Iterations = 3611
# Minimum Cost (J) = 0.4925635781335972
# Weights of Model:  [ 0.9267421  -0.06995312 -0.66513741 -0.01218686  0.53704109 -0.00819023
#   0.15442805 -0.09347971 -0.29866991  0.0904182   0.1463636   1.09223969]
# Accuracy:  72.7427597955707 %
# Error Rate:  27.2572402044293 %
# Precision:  72.06208425720621 %
# Recall:  90.5292479108635 %
#
# Number of Iterations = 3563
# Minimum Cost (J) = 0.507140912100899
# Weights of Model:  [ 0.82562796 -0.08587111 -0.64743406  0.06756302  0.50850922  0.01265305
#   0.12892145 -0.04771779 -0.30449227  0.1018985   0.19679198  1.0835679 ]
# Accuracy:  78.87563884156728 %
# Error Rate:  21.12436115843271 %
# Precision:  82.15962441314554 %
# Recall:  87.93969849246231 %
#
# Number of Iterations = 3472
# Minimum Cost (J) = 0.5081350004323024
# Weights of Model:  [ 0.83251509 -0.07959845 -0.60796544  0.06678716  0.49560425 -0.0126403
#   0.16283984 -0.10513069 -0.30116089  0.11095085  0.13116887  1.07920026]
# Accuracy:  77.17206132879046 %
# Error Rate:  22.82793867120954 %
# Precision:  80.9090909090909 %
# Recall:  87.68472906403942 %
#
# Number of Iterations = 3727
# Minimum Cost (J) = 0.49761145574302906
# Weights of Model:  [ 0.86082717 -0.05681684 -0.65797921  0.03033898  0.56995694  0.01343871
#   0.11357887 -0.10830474 -0.31405552  0.0756251   0.19622279  1.12220232]
# Accuracy:  72.40204429301534 %
# Error Rate:  27.597955706984667 %
# Precision:  76.66666666666667 %
# Recall:  83.41968911917098 %
#
# average cross validation model accuracy = 74.85519591141397%
#
# Accuracy:  68.14310051107326 %
# Error Rate:  31.85689948892675 %
# Precision:  76.04166666666666 %
# Recall:  75.45219638242894 %
#
# Accuracy:  67.29131175468484 %
# Error Rate:  32.70868824531516 %
# Precision:  70.92731829573935 %
# Recall:  78.8300835654596 %
#
# Accuracy:  73.25383304940375 %
# Error Rate:  26.74616695059625 %
# Precision:  80.35264483627203 %
# Recall:  80.15075376884423 %
#
# Accuracy:  73.42419080068143 %
# Error Rate:  26.575809199318567 %
# Precision:  81.7258883248731 %
# Recall:  79.3103448275862 %
#
# Accuracy:  69.16524701873935 %
# Error Rate:  30.83475298126065 %
# Precision:  77.18832891246684 %
# Recall:  75.38860103626943 %
#
# average cross validation model accuracy = 70.25553662691652%
#
# Number of Iterations = 3579
# Minimum Cost (J) = 0.5142873392155838
# Weights of Model:  [ 0.7988291  -0.00225841 -0.63750761  0.0313039   0.53587952  0.03736986
#   0.07377461 -0.13347975 -0.35237283  0.11691251  0.19327611  1.03247427]
# Accuracy:  75.44757033248082 %
# Error Rate:  24.55242966751918 %
# Precision:  78.15699658703072 %
# Recall:  87.73946360153256 %
#
# Number of Iterations = 3670
# Minimum Cost (J) = 0.4999243671415629
# Weights of Model:  [ 0.83089622 -0.02364923 -0.65767907  0.05550511  0.57350983  0.01577534
#   0.02517902 -0.12867783 -0.27860322  0.08362834  0.13497611  1.12471414]
# Accuracy:  71.61125319693095 %
# Error Rate:  28.388746803069054 %
# Precision:  73.7410071942446 %
# Recall:  84.36213991769547 %
# Number of Iterations = 3687
# Minimum Cost (J) = 0.4944597829662489
# Weights of Model:  [ 0.8718183  -0.07662779 -0.67579982 -0.01731592  0.54227653  0.04054644
#   0.10639885 -0.12987976 -0.28619894 -0.02198297  0.16564019  1.15942713]
# Accuracy:  72.37851662404093 %
# Error Rate:  27.621483375959077 %
# Precision:  72.6962457337884 %
# Recall:  88.38174273858921 %
#
# Number of Iterations = 3695
# Minimum Cost (J) = 0.5049692871091045
# Weights of Model:  [ 0.76929434 -0.06459767 -0.69299147  0.07155395  0.56088297  0.07723276
#   0.09694409 -0.09820255 -0.29001814  0.05647755  0.21228604  1.15875095]
# Accuracy:  75.44757033248082 %
# Error Rate:  24.55242966751918 %
# Precision:  80.50541516245488 %
# Recall:  84.15094339622642 %
#
# Number of Iterations = 3455
# Minimum Cost (J) = 0.5146678286165254
# Weights of Model:  [ 0.79008396 -0.09521774 -0.57741333  0.10297368  0.50218655 -0.00244617
#   0.11605071 -0.12914665 -0.2933644   0.06429283  0.12581526  1.08207021]
# Accuracy:  78.26086956521739 %
# Error Rate:  21.73913043478261 %
# Precision:  80.55555555555556 %
# Recall:  88.88888888888889 %
#
# average cross validation model accuracy = 74.62915601023018%
#
# Accuracy:  69.82097186700767 %
# Error Rate:  30.179028132992325 %
# Precision:  77.82101167315176 %
# Recall:  76.62835249042146 %
#
# Accuracy:  66.24040920716112 %
# Error Rate:  33.75959079283887 %
# Precision:  72.11155378486056 %
# Recall:  74.48559670781893 %
#
# Accuracy:  65.98465473145781 %
# Error Rate:  34.015345268542205 %
# Precision:  70.93023255813954 %
# Recall:  75.93360995850622 %
#
# Accuracy:  72.63427109974424 %
# Error Rate:  27.365728900255753 %
# Precision:  80.859375 %
# Recall:  78.11320754716982 %
#
# Accuracy:  72.63427109974424 %
# Error Rate:  27.365728900255753 %
# Precision:  80.80000000000001 %
# Recall:  77.39463601532567 %
#
# average cross validation model accuracy = 69.46291560102301%
#
# Number of Iterations = 3663
# Minimum Cost (J) = 0.5228189268394879
# Weights of Model:  [ 0.73172503 -0.07742135 -0.5861104   0.15114921  0.53729735  0.10091945
#   0.14435408 -0.01081795 -0.44524754  0.01716146  0.23699355  1.05973399]
# Accuracy:  79.48717948717949 %
# Error Rate:  20.51282051282051 %
# Precision:  80.98591549295774 %
# Recall:  89.84375 %
#
# Number of Iterations = 3561
# Minimum Cost (J) = 0.5097283304587448
# Weights of Model:  [ 0.7272573  -0.07286274 -0.60298574  0.16667497  0.4580685   0.12595546
#   0.30972919 -0.2210693  -0.26759425  0.10667787  0.24846712  1.18508723]
# Accuracy:  72.3076923076923 %
# Error Rate:  27.692307692307693 %
# Precision:  78.67647058823529 %
# Recall:  81.06060606060606 %
#
# Number of Iterations = 3860
# Minimum Cost (J) = 0.4951435194196824
# Weights of Model:  [ 0.7503548  -0.11106836 -0.62377572  0.19368316  0.5396671   0.09004974
#   0.16073656 -0.07760409 -0.30028457 -0.00856962  0.24632353  1.29911214]
# Accuracy:  67.6923076923077 %
# Error Rate:  32.30769230769231 %
# Precision:  74.60317460317461 %
# Recall:  75.2 %
#
# Number of Iterations = 3439
# Minimum Cost (J) = 0.5132099046824058
# Weights of Model:  [ 0.76420168 -0.07273887 -0.58421544  0.16848811  0.50827257  0.10497741
#   0.22298331 -0.13982654 -0.28580252  0.07704186  0.12818987  1.12421263]
# Accuracy:  75.8974358974359 %
# Error Rate:  24.102564102564102 %
# Precision:  75.71428571428571 %
# Recall:  89.07563025210085 %
#
# Number of Iterations = 3820
# Minimum Cost (J) = 0.4968382030496897
# Weights of Model:  [ 0.81699709 -0.21027342 -0.66995021  0.07766378  0.49631468  0.07117346
#   0.19623138 -0.07121214 -0.24124124 -0.10192501  0.19251693  1.25578632]
# Accuracy:  71.7948717948718 %
# Error Rate:  28.205128205128204 %
# Precision:  73.33333333333333 %
# Recall:  83.89830508474576 %
#
# average cross validation model accuracy = 73.43589743589743%
#
# Accuracy:  74.35897435897436 %
# Error Rate:  25.64102564102564 %
# Precision:  79.54545454545455 %
# Recall:  82.03125 %
#
# Accuracy:  66.15384615384615 %
# Error Rate:  33.84615384615385 %
# Precision:  79.46428571428571 %
# Recall:  67.42424242424242 %
#
# Accuracy:  67.17948717948717 %
# Error Rate:  32.82051282051282 %
# Precision:  77.98165137614679 %
# Recall:  68.0 %
#
# Accuracy:  70.76923076923077 %
# Error Rate:  29.230769230769234 %
# Precision:  78.18181818181819 %
# Recall:  72.26890756302521 %
#
# Accuracy:  66.15384615384615 %
# Error Rate:  33.84615384615385 %
# Precision:  72.41379310344827 %
# Recall:  71.1864406779661 %
#
# average cross validation model accuracy = 68.92307692307692%

# %%
#The Accuracy of the Test set based on different sizes of the training set
#Need to choose optimum hyper-parameters on Logistic Regression

length = int(len(x_train))
length90 = int(length*0.90)
length80 = int(length*0.80)
length70 = int(length*0.70)
length60 = int(length*0.60)
length50 = int(length*0.50)
length40 = int(length*0.40)
length30 = int(length*0.30)
length20 = int(length*0.20)
length10 = int(length*0.10)

x_train_reduced = [x_train, x_train[:length90,:], x_train[:length80,:], x_train[:length70,:],x_train[:length60,:], x_train[:length50,:], x_train[:length40,:],x_train[:length30,:], x_train[:length20,:], x_train[:length10,:]] 
y_train_reduced = [y_train, y_train[:length90], y_train[:length80], y_train[:length70], y_train[:length60], y_train[:length50], y_train[:length40], y_train[:length30], y_train[:length20], y_train[:length10]]
percentage_of_original = [100, 90, 80, 70, 60, 50, 40, 30, 20, 10]
LR_accuracy = []
NB_accuracy = []


model_LR = LogisticRegression(intercept = True)
for i in range(len(x_train_reduced)):
    w = model_LR.fit(x_train_reduced[i], y_train_reduced[i], num_steps = 30000, learning_rate = 0.01, min_error = 1e-3)            
    
    y_pred = model_LR.predict(x_test, w)
    
    accuracy = model_LR.evaluate_acc(y_test, y_pred)
    LR_accuracy.append(accuracy)


model_NB = NaiveBayes()
for i in range(len(x_train_reduced)):
    model_NB.fit(x_train_reduced[i], y_train_reduced[i])
    
    y_pred = model_NB.predict(x_test)
    
    accuracy = model_NB.evaluate_acc(y_test,y_pred)
    NB_accuracy.append(accuracy)
    

#Plot
plt.plot(percentage_of_original, LR_accuracy)
plt.plot(percentage_of_original, NB_accuracy)
plt.title("Training Set Size vs Model Accuracy (Wine Dataset)")
plt.xlabel("Percent of Original Training Size (%)")
plt.ylabel("Model Accuracy on Test Set(%)")
plt.legend(["Logistic Regression", "Naive Bayes"])
# Out:
# Number of Iterations = 24408
# Minimum Cost (J) = 0.50241403776151
# Weights of Model:  [ 9.13670414e-01 -1.07308573e-03 -6.96819344e-01  1.13747002e-02
#   7.10239710e-01  3.93145761e-02  1.42815974e-01 -2.32713467e-02
#  -5.57631380e-01  1.25357101e-01  1.91748426e-01  1.07767872e+00]
# Accuracy:  74.08163265306122 %
# Error Rate:  25.918367346938776 %
# Precision:  77.64060356652949 %
# Recall:  86.14916286149162 %
#
# Number of Iterations = 19152
# Minimum Cost (J) = 0.49991024779308235
# Weights of Model:  [ 9.15444432e-01 -2.39733321e-02 -6.84216168e-01 -5.43075097e-04
#   6.95976052e-01  5.03140031e-02  1.53719882e-01 -4.35416836e-02
#  -4.83963230e-01  1.17822051e-01  1.85495861e-01  1.15862231e+00]
# Accuracy:  75.20408163265306 %
# Error Rate:  24.79591836734694 %
# Precision:  78.8300835654596 %
# Recall:  86.14916286149162 %
#
# Number of Iterations = 25757
# Minimum Cost (J) = 0.4986537088671427
# Weights of Model:  [ 0.92437623 -0.00836698 -0.70116648  0.00869377  0.78091391  0.05197635
#   0.09658493 -0.01626095 -0.59808131  0.13496766  0.19813809  1.10419196]
# Accuracy:  74.89795918367346 %
# Error Rate:  25.102040816326532 %
# Precision:  78.2668500687758 %
# Recall:  86.60578386605783 %
#
# Number of Iterations = 23390
# Minimum Cost (J) = 0.49892520303783683
# Weights of Model:  [ 0.91285737 -0.01665523 -0.68816202  0.02007087  0.78998644  0.06717869
#   0.09270939 -0.04484851 -0.56859988  0.13096566  0.22692694  1.13458967]
# Accuracy:  75.51020408163265 %
# Error Rate:  24.489795918367346 %
# Precision:  79.07949790794979 %
# Recall:  86.3013698630137 %
#
# Number of Iterations = 22367
# Minimum Cost (J) = 0.4961046635603865
# Weights of Model:  [ 0.90538107 -0.00440977 -0.71532828  0.02370573  0.80625722  0.07085235
#   0.07823446 -0.06136068 -0.55721665  0.12375862  0.22502126  1.16336599]
# Accuracy:  75.40816326530613 %
# Error Rate:  24.591836734693878 %
# Precision:  79.05027932960894 %
# Recall:  86.14916286149162 %
#
# Number of Iterations = 19166
# Minimum Cost (J) = 0.505289666300203
# Weights of Model:  [ 0.85305988 -0.01136961 -0.7003984   0.04347215  0.74343028  0.09091967
#   0.04973822 -0.07730673 -0.49810785  0.09778123  0.19001103  1.16736038]
# Accuracy:  74.59183673469387 %
# Error Rate:  25.408163265306122 %
# Precision:  79.22636103151862 %
# Recall:  84.17047184170472 %
#
# Number of Iterations = 15786
# Minimum Cost (J) = 0.5140802452297547
# Weights of Model:  [ 0.82945793 -0.06153938 -0.62164474  0.09589719  0.67080686  0.05148738
#   0.08239989 -0.08899385 -0.44803406  0.09802304  0.13554535  1.15575939]
# Accuracy:  74.18367346938776 %
# Error Rate:  25.816326530612244 %
# Precision:  79.36046511627907 %
# Recall:  83.10502283105022 %
#
# Number of Iterations = 10745
# Minimum Cost (J) = 0.5145696922401108
# Weights of Model:  [ 0.7683812  -0.1052467  -0.66300369  0.14362995  0.62385921  0.08841718
#   0.12809292 -0.05968259 -0.36266807  0.07334996  0.1905532   1.24177944]
# Accuracy:  73.67346938775509 %
# Error Rate:  26.3265306122449 %
# Precision:  79.64338781575037 %
# Recall:  81.58295281582953 %
#
# Number of Iterations = 9426
# Minimum Cost (J) = 0.4951834667989309
# Weights of Model:  [ 0.85524186 -0.23991182 -0.73605364  0.08412663  0.54179514  0.13118157
#   0.20216822 -0.05837128 -0.23170244 -0.13316991  0.19275474  1.40935777]
# Accuracy:  76.0204081632653 %
# Error Rate:  23.97959183673469 %
# Precision:  80.22922636103151 %
# Recall:  85.2359208523592 %
#
# Number of Iterations = 10472
# Minimum Cost (J) = 0.46128375784458964
# Weights of Model:  [ 0.93366501 -0.28127955 -0.84550243  0.06955568  0.61972105  0.08157365
#   0.08817051 -0.00515539 -0.1590526  -0.24068989  0.06385119  1.5670317 ]
# Accuracy:  73.26530612244898 %
# Error Rate:  26.73469387755102 %
# Precision:  78.33572453371592 %
# Recall:  83.10502283105022 %
#
# Accuracy:  70.71428571428572 %
# Error Rate:  29.28571428571429 %
# Precision:  79.36507936507937 %
# Recall:  76.10350076103501 %
#
# Accuracy:  71.53061224489797 %
# Error Rate:  28.469387755102044 %
# Precision:  80.58252427184466 %
# Recall:  75.79908675799086 %
#
# Accuracy:  71.73469387755102 %
# Error Rate:  28.26530612244898 %
# Precision:  80.54662379421221 %
# Recall:  76.25570776255708 %
#
# Accuracy:  71.93877551020408 %
# Error Rate:  28.061224489795915 %
# Precision:  80.90614886731392 %
# Recall:  76.10350076103501 %
#
# Accuracy:  71.93877551020408 %
# Error Rate:  28.061224489795915 %
# Precision:  80.5111821086262 %
# Recall:  76.71232876712328 %
#
# Accuracy:  71.42857142857143 %
# Error Rate:  28.57142857142857 %
# Precision:  80.65040650406505 %
# Recall:  75.49467275494672 %
#
# Accuracy:  71.22448979591837 %
# Error Rate:  28.775510204081634 %
# Precision:  80.6873977086743 %
# Recall:  75.03805175038052 %
#
# Accuracy:  71.63265306122449 %
# Error Rate:  28.367346938775512 %
# Precision:  82.72884283246978 %
# Recall:  72.90715372907154 %
#
# Accuracy:  71.12244897959184 %
# Error Rate:  28.877551020408166 %
# Precision:  81.27090301003345 %
# Recall:  73.97260273972603 %
#
# Accuracy:  73.16326530612245 %
# Error Rate:  26.836734693877553 %
# Precision:  82.72425249169434 %
# Recall:  75.79908675799086 %

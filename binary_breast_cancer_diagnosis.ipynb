# %% [markdown]
# # Task 1: Acquire, Preprocess, and Analyze the Data
#
#
# ## DataSet Analysis - Breast Cancer Diagnosis
#
#
# Link: http://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+%28Diagnostic%29
#
# Note: The dataset used is the breast-cancer-wisconsin.data
#
# The DataSet has 11 features, including the diagnosis class (Benign or Malignant). One of the features (ID) can definitely be removed for the Classification

# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
# Load the Breast Cancer Diagnosis dataset
URL = "http://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/breast-cancer-wisconsin.data"
data = pd.read_csv(URL, sep =',',names = ['ID','Clump Thickness','Uniformity of Cell Size','Uniformity of Cell Shape','Marginal Adhesion','Single Epithelia Cell Size','Bare Nuclei','Bland Chromatin','Normal Nucleoli','Mitoses','Class'])

# Remove any rows that have a ? (missing data) anywhere
data = data[~data.apply(lambda x: x.str.contains('\?'), axis=1).any(1)]
data.dropna(how = 'any')

# Display first twenty records to get a picture of the data
data.head(20)
# Out:
#          ID  Clump Thickness  Uniformity of Cell Size  \
# 0   1000025                5                        1
# 1   1002945                5                        4
# 2   1015425                3                        1
# 3   1016277                6                        8
# 4   1017023                4                        1
# 5   1017122                8                       10
# 6   1018099                1                        1
# 7   1018561                2                        1
# 8   1033078                2                        1
# 9   1033078                4                        2
# 10  1035283                1                        1
# 11  1036172                2                        1
# 12  1041801                5                        3
# 13  1043999                1                        1
# 14  1044572                8                        7
# 15  1047630                7                        4
# 16  1048672                4                        1
# 17  1049815                4                        1
# 18  1050670               10                        7
# 19  1050718                6                        1
#
#     Uniformity of Cell Shape  Marginal Adhesion  Single Epithelia Cell Size  \
# 0                          1                  1                           2
# 1                          4                  5                           7
# 2                          1                  1                           2
# 3                          8                  1                           3
# 4                          1                  3                           2
# 5                         10                  8                           7
# 6                          1                  1                           2
# 7                          2                  1                           2
# 8                          1                  1                           2
# 9                          1                  1                           2
# 10                         1                  1                           1
# 11                         1                  1                           2
# 12                         3                  3                           2
# 13                         1                  1                           2
# 14                         5                 10                           7
# 15                         6                  4                           6
# 16                         1                  1                           2
# 17                         1                  1                           2
# 18                         7                  6                           4
# 19                         1                  1                           2
#
#    Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses  Class
# 0            1                3                1        1      2
# 1           10                3                2        1      2
# 2            2                3                1        1      2
# 3            4                3                7        1      2
# 4            1                3                1        1      2
# 5           10                9                7        1      4
# 6           10                3                1        1      2
# 7            1                3                1        1      2
# 8            1                1                1        5      2
# 9            1                2                1        1      2
# 10           1                3                1        1      2
# 11           1                2                1        1      2
# 12           3                4                4        1      4
# 13           3                3                1        1      2
# 14           9                5                5        4      4
# 15           1                4                3        1      4
# 16           1                2                1        1      2
# 17           1                3                1        1      2
# 18          10                4                1        2      4
# 19           1                3                1        1      2

# %%
#Remove ID value as it is not required for the Model
del data['ID']

# %%
# Change class values from 2 (benign) to 0 and 4 (malignant) to 1
data["Class"] = 1*(data["Class"]>3)

print(data["Class"])
data.head(20)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 694    0
# 695    0
# 696    1
# 697    1
# 698    1
# Name: Class, Length: 683, dtype: int32
#     Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# 0                 5                        1                         1
# 1                 5                        4                         4
# 2                 3                        1                         1
# 3                 6                        8                         8
# 4                 4                        1                         1
# 5                 8                       10                        10
# 6                 1                        1                         1
# 7                 2                        1                         2
# 8                 2                        1                         1
# 9                 4                        2                         1
# 10                1                        1                         1
# 11                2                        1                         1
# 12                5                        3                         3
# 13                1                        1                         1
# 14                8                        7                         5
# 15                7                        4                         6
# 16                4                        1                         1
# 17                4                        1                         1
# 18               10                        7                         7
# 19                6                        1                         1
#
#     Marginal Adhesion  Single Epithelia Cell Size Bare Nuclei  \
# 0                   1                           2           1
# 1                   5                           7          10
# 2                   1                           2           2
# 3                   1                           3           4
# 4                   3                           2           1
# 5                   8                           7          10
# 6                   1                           2          10
# 7                   1                           2           1
# 8                   1                           2           1
# 9                   1                           2           1
# 10                  1                           1           1
# 11                  1                           2           1
# 12                  3                           2           3
# 13                  1                           2           3
# 14                 10                           7           9
# 15                  4                           6           1
# 16                  1                           2           1
# 17                  1                           2           1
# 18                  6                           4          10
# 19                  1                           2           1
#
#     Bland Chromatin  Normal Nucleoli  Mitoses  Class
# 0                 3                1        1      0
# 1                 3                2        1      0
# 2                 3                1        1      0
# 3                 3                7        1      0
# 4                 3                1        1      0
# 5                 9                7        1      1
# 6                 3                1        1      0
# 7                 3                1        1      0
# 8                 1                1        5      0
# 9                 2                1        1      0
# 10                3                1        1      0
# 11                2                1        1      0
# 12                4                4        1      1
# 13                3                1        1      0
# 14                5                5        4      1
# 15                4                3        1      1
# 16                2                1        1      0
# 17                3                1        1      0
# 18                4                1        2      1
# 19                3                1        1      0

# %%
# Get some basic statistics from the data
data.describe()
# Out:
#        Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# count       683.000000               683.000000                683.000000
# mean          4.442167                 3.150805                  3.215227
# std           2.820761                 3.065145                  2.988581
# min           1.000000                 1.000000                  1.000000
# 25%           2.000000                 1.000000                  1.000000
# 50%           4.000000                 1.000000                  1.000000
# 75%           6.000000                 5.000000                  5.000000
# max          10.000000                10.000000                 10.000000
#
#        Marginal Adhesion  Single Epithelia Cell Size  Bland Chromatin  \
# count         683.000000                  683.000000       683.000000
# mean            2.830161                    3.234261         3.445095
# std             2.864562                    2.223085         2.449697
# min             1.000000                    1.000000         1.000000
# 25%             1.000000                    2.000000         2.000000
# 50%             1.000000                    2.000000         3.000000
# 75%             4.000000                    4.000000         5.000000
# max            10.000000                   10.000000        10.000000
#
#        Normal Nucleoli     Mitoses       Class
# count       683.000000  683.000000  683.000000
# mean          2.869693    1.603221    0.349927
# std           3.052666    1.732674    0.477296
# min           1.000000    1.000000    0.000000
# 25%           1.000000    1.000000    0.000000
# 50%           1.000000    1.000000    0.000000
# 75%           4.000000    1.000000    1.000000
# max          10.000000   10.000000    1.000000

# %%
 #Number benign (0) and malignant (1) results
    
malignant = data.loc[(data['Class'] == 1)] 
number_of_malignant = malignant.shape[0]

benign = data.loc[(data['Class'] == 0)]
number_of_benign = benign.shape[0]

print("Total Number of Patients: " + str(number_of_malignant + number_of_benign))
print("Number of Malignant = " + str(number_of_malignant))
print("Number of Benign = " + str(number_of_benign))

#Percentage of Malignant
Percentage_of_malignant = (number_of_malignant/(number_of_benign+number_of_malignant))*100

print("Percentage of Malignant = " + str(int(Percentage_of_malignant)) + '%')
# Out:
# Total Number of Patients: 683
# Number of Malignant = 239
# Number of Benign = 444
# Percentage of Malignant = 34%

# %%
#Plot the Distributions of the features
sns.histplot(data['Clump Thickness'], bins = 20, kde = False)
# Out:
# <AxesSubplot:xlabel='Clump Thickness', ylabel='Count'>

# %%
sns.histplot(data['Uniformity of Cell Size'],bins = 20, kde = False)
# Out:
# <AxesSubplot:xlabel='Uniformity of Cell Size', ylabel='Count'>

# %%
sns.histplot(data['Uniformity of Cell Shape'],bins = 20, kde = False)
# Out:
# <AxesSubplot:xlabel='Uniformity of Cell Shape', ylabel='Count'>

# %%
sns.histplot(data['Marginal Adhesion'],bins = 20, kde = False)
# Out:
# <AxesSubplot:xlabel='Marginal Adhesion', ylabel='Count'>

# %%
sns.histplot(data['Single Epithelia Cell Size'],bins = 20, kde = False)
# Out:
# <AxesSubplot:xlabel='Single Epithelia Cell Size', ylabel='Count'>

# %%
sns.histplot(data['Bare Nuclei'],bins = 20, kde = False)
# Out:
# <AxesSubplot:xlabel='Bare Nuclei', ylabel='Count'>

# %%
sns.histplot(data['Bland Chromatin'],bins = 20, kde = False)
# Out:
# <AxesSubplot:xlabel='Bland Chromatin', ylabel='Count'>

# %%
sns.histplot(data['Normal Nucleoli'],bins = 20, kde = False)
# Out:
# <AxesSubplot:xlabel='Normal Nucleoli', ylabel='Count'>

# %%
sns.histplot(data['Mitoses'],bins = 20, kde = False)
#plt.hist(data['Mitoses'])
# Out:
# <AxesSubplot:xlabel='Mitoses', ylabel='Count'>

# %%
#Correlation between Features
corr = data.corr()

plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, xticklabels=corr.columns,yticklabels=corr.columns, linewidths=0.5, linecolor="white")
# Out:
# <AxesSubplot:>

# %%
#Scatter Plot of Pair Wise Features

Scatter = sns.pairplot(data , hue = "Class", kind = 'scatter', diag_kind = 'hist')

#Need to reduce this to smaller subsets as the number of features make this plot difficult to understand

# %%
#Split Data between Positive and Negative Results
positive = data['Class'] == 1
pos_data = data[positive]
negative = data['Class'] == 0
neg_data = data[negative]

# %%
#Correlation for positive results
pos_corr = pos_data.corr()

plt.figure(figsize=(10,8))
sns.heatmap(pos_corr, annot=True,xticklabels=pos_corr.columns,yticklabels=pos_corr.columns, linewidths=0.5, linecolor="white")
# Out:
# <AxesSubplot:>

# %%
#Correlation for negative results
neg_corr = neg_data.corr()

plt.figure(figsize=(10,8))
ax = sns.heatmap(neg_corr, annot=True, xticklabels=neg_corr.columns,yticklabels=neg_corr.columns, linewidths=0.5, linecolor="white")

# %%
#Distribution of Positive vs Negative Results
sns.histplot(pos_data['Clump Thickness'], bins = 10, color = 'b', kde = False)
sns.histplot(neg_data['Clump Thickness'], bins = 10, color = 'r', kde = False)
# Out:
# <AxesSubplot:xlabel='Clump Thickness', ylabel='Count'>

# %%
sns.histplot(pos_data['Uniformity of Cell Size'], bins = 10, color = 'b', kde = False)
sns.histplot(neg_data['Uniformity of Cell Size'], bins = 10, color = 'r', kde = False)
# Out:
# <AxesSubplot:xlabel='Uniformity of Cell Size', ylabel='Count'>

# %%
sns.histplot(pos_data['Uniformity of Cell Shape'], bins = 10, color = 'b', kde = False)
sns.histplot(neg_data['Uniformity of Cell Shape'], bins = 10, color = 'r', kde = False)
# Out:
# <AxesSubplot:xlabel='Uniformity of Cell Shape', ylabel='Count'>

# %%
sns.histplot(pos_data['Marginal Adhesion'],bins = 10, color = 'b', kde = False)
sns.histplot(neg_data['Marginal Adhesion'],bins = 10, color = 'r', kde = False)
# Out:
# <AxesSubplot:xlabel='Marginal Adhesion', ylabel='Count'>

# %%
sns.histplot(pos_data['Single Epithelia Cell Size'],bins = 10, color = 'b', kde = False)
sns.histplot(neg_data['Single Epithelia Cell Size'],bins = 10, color = 'r', kde = False)
# Out:
# <AxesSubplot:xlabel='Single Epithelia Cell Size', ylabel='Count'>

# %%
sns.histplot(pos_data['Bare Nuclei'],bins = 10, color = 'b', kde = False)
sns.histplot(neg_data['Bare Nuclei'],bins = 10, color = 'r', kde = False)
# Out:
# <AxesSubplot:xlabel='Bare Nuclei', ylabel='Count'>

# %%
sns.histplot(pos_data['Bland Chromatin'],bins = 10, color = 'b', kde = False)
sns.histplot(neg_data['Bland Chromatin'],bins = 10, color = 'r', kde = False)
# Out:
# <AxesSubplot:xlabel='Bland Chromatin', ylabel='Count'>

# %%
sns.histplot(pos_data['Normal Nucleoli'],bins = 10, color = 'b', kde = False)
sns.histplot(neg_data['Normal Nucleoli'],bins = 10, color = 'r', kde = False)
# Out:
# <AxesSubplot:xlabel='Normal Nucleoli', ylabel='Count'>

# %%
sns.histplot(pos_data['Mitoses'],bins = 10, color = 'b', kde = False)
sns.histplot(neg_data['Mitoses'],bins = 10, color = 'r', kde = False)
# Out:
# <AxesSubplot:xlabel='Mitoses', ylabel='Count'>

# %%
# Split Data between Training and Test Data (80/20 split)
# Needs to be randomly split

#Create Copy of Data Set and Then create training set and test set
data_copy = data.copy()
train_set = data_copy.sample(frac=0.80, random_state=0) #random state = 0 means the split will be zero each run
test_set = data_copy.drop(train_set.index)
          
x_train = np.array(train_set.iloc[:, :-1], dtype = int)
y_train = np.array(train_set["Class"], dtype = int)
          
x_test = np.array(test_set.iloc[:, :-1], dtype = int)
y_test = np.array(test_set["Class"], dtype = int)

print("x_train size: ", x_train.shape)
print("y_train size: ", y_train.shape)
print("x_test size: ", x_test.shape)
print("y_test size: ", y_test.shape)
# Out:
# x_train size:  (546, 9)
# y_train size:  (546,)
# x_test size:  (137, 9)
# y_test size:  (137,)

# %% [markdown]
# # Task 2 - Implement the Models
#
# ### Logistic Regression from Scratch

# %%
class LogisticRegression:

    def __init__(self, intercept = True): 
        #self.num_steps = num_steps
        #self.leaning_rate = learning_rate
        #self.error_rate = error_rate
        self.intercept = intercept

    
    def add_intercept(self, X):
        intercept = np.ones((X.shape[0],1))
        return np.concatenate((intercept,X), axis = 1)
    
    def sigmoid(self, z):
        return 1/(1 + np.exp(-z))
                  
                  
    def cost_function(self, X, y, w): #Cross Entropy Loss Function
        N,D = X.shape
        z = np.dot(X, w)
        
        J = np.mean(y * np.log1p(np.exp(-z)) + (1-y) * np.log1p(np.exp(z)))
        grad = np.dot(X.T,(self.sigmoid(z) - y)) / N
        
        return grad, J
    
                  
    def gradient_descent(self, X, y, num_steps, learning_rate, min_error):
        # Min error is just the early termination requirement (Set up as Small change is objective right now)
        N,D = X.shape
        w = np.zeros(D)
        grad, J_previous = self.cost_function(X, y, w)
        
        for i in range(num_steps):
                grad, J = self.cost_function(X, y, w)
                w = w - (learning_rate * grad)
                
                if np.linalg.norm(grad) < min_error:
                #if np.abs(J - J_previous) < min_error: # Need to determine the best way to determine the early stopping point
                    break
                else:
                    J_previous = J
                  
        print("Number of Iterations = " + str(i))
        print("Minimum Cost (J) = " + str(J))          
        return w, J

    
    def fit(self, X, y, num_steps, learning_rate, min_error): #Logistic regression and Gradient Descent (Input is X and y, outputs weights of model)
        if self.intercept == True:
            X = self.add_intercept(X)
            
        
        #Gradient function
        w, J = self.gradient_descent(X, y, num_steps, learning_rate, min_error)
        
        print("Weights of Model: ", w)
        return w
    
    def predict(self, X, w): #Ouput is the predicted values for y
        if self.intercept == True:
            X = self.add_intercept(X)
        
        y_pred = self.sigmoid(np.dot(X, w))
        y_pred = y_pred.round() #Rounds the value to 1 or 0
        
        #print("y_pred Shape")
        #print(y_pred.shape)
        return y_pred
    
    def evaluate_acc(self, y, y_pred):
        #Accuracy = (TP + TN)/ P + N
        #Error Rate = (FP + FN)/P + N
        #Precision = TP/RP
        #Recall = TP/P
        
        A = (np.mean(y_pred == y))*100
        #print(A)
        
        #Alternatively
        TP, TN, FN, FP = 0,0,0,0
        for i in range(len(y_pred)):
            if (y[i] == y_pred[i]) & (y_pred[i] == 1):
                TP = TP + 1
            if (y[i] != y_pred[i]) & (y_pred[i] == 1):
                FP = FP + 1
            if (y[i] == y_pred[i]) & (y_pred[i] == 0):
                TN = TN + 1
            if (y[i] != y_pred[i]) & (y_pred[i] == 0):
                FN = FN + 1
            
        N = TN + FP
        RP = TP + FP
        P = TP + FN
        
        accuracy = ((TP + TN) / (P + N))*100
        errorRate = ((FP + FN) / (P + N))*100
        precision = (TP / (RP))*100
        recall = (TP / (P))*100

        print("Accuracy: ", accuracy, "%")
        print("Error Rate: ", errorRate, "%")
        print("Precision: ", precision, "%")
        print("Recall: ", recall, "% \n")
        
        return A

# %% [markdown]
# ### Multinomial Naive Bayes from Scratch

# %%
import numpy as np
from collections import Counter

class MultinomialNaiveBayes:
    
    def fit(self, x_train, y_train):

        ### Compute Priors
        neg_count = np.count_nonzero(y_train == 0)
        pos_count = np.count_nonzero(y_train == 1)
        total_count = neg_count + pos_count
        neg_prior = neg_count/total_count
        pos_prior = pos_count/total_count

        ### Compute likelihoods
        list_feature_class = []

        # Create a tuple that contains (column/feature #, value, class) and add it to a list
        for (row,col), value in np.ndenumerate(x_train):
            feature_class = (col, value, y_train[row])
            list_feature_class.append(feature_class)

        # Get the counts for each feature-value-class tuple
        dict_counts = Counter(list_feature_class)

        # Convert to data frame to make accessing elements easier 
        df_counts = pd.DataFrame(dict_counts.items())
        df_keys = pd.DataFrame(list(dict_counts))

        # Concat the keys and values into one dataframe
        df = pd.concat([df_keys,df_counts[1]], axis = 1)
        df.columns = [ 'featureNum', 'value', 'class','counts' ]


        # Loop through each row and compute the likelihood and store in another array
        likelihoods = []
        for row in df.itertuples(index=False):
            # row[0] Column #
            # row[1] Value 
            # row[2] Class
            # row[3] Count 

            # If class is 0, divide count by neg class count 
            if row[2] == 0:
                likelihoods.append(row[3]/neg_count)
            # If class is 1, divide count by pos class count 
            elif row[2] == 1:
                likelihoods.append(row[3]/pos_count)

        # Add likelihoods column to dataframe 
        df['likelihoods'] = likelihoods 

        return df, neg_prior, pos_prior
        
    def predict(self, x_test, df_likelihoods, neg_prior, pos_prior):

        df_xtest = pd.DataFrame(x_test)
        df_xtest.head(10)

        neg_likelihoods = []
        pos_likelihoods = []

        for (row,col), value in np.ndenumerate(x_test):

            #### Compute negative posterior prob
            filt1 = df_likelihoods["featureNum"] == col
            filt2 = df_likelihoods["value"] == value
            filt3 = df_likelihoods["class"] == 0

            # Find the row where the filters hold true
            neg_likelihood_row = df_likelihoods.where(filt1 & filt2 & filt3)

            # Select only the likelihood from the row
            neg_likelihood = neg_likelihood_row["likelihoods"]

            # Remove the other NaN values 
            neg_likelihood.dropna(axis=0, inplace=True)

            # If the likelihood value is not empty, then add to the likelihoods array
            if neg_likelihood.values.size > 0:
                neg_likelihoods.append(neg_likelihood.values[0])
            # If the likelihood value is empty, add a 1 to the array --> log(1) = 0
            elif neg_likelihood.values.size == 0:
                neg_likelihoods.append(1)

            #### Compute positive posterior prob
            filt4 = df_likelihoods["class"] == 1

            pos_likelihood_row = df_likelihoods.where(filt1 & filt2 & filt4)
            pos_likelihood = pos_likelihood_row["likelihoods"]
            pos_likelihood.dropna(axis=0, inplace=True)

            # If the likelihood value is not empty, then add to the likelihoods array
            if pos_likelihood.values.size > 0:
                pos_likelihoods.append(pos_likelihood.values[0])
            # If the likelihood value is empty, add a 1 to the array --> log(1) = 0
            elif pos_likelihood.values.size == 0:
                pos_likelihoods.append(1)

        # Reshape the likelihood array into the same size as x_test
        pos_likelihoods = np.reshape(pos_likelihoods, x_test.shape)
        neg_likelihoods = np.reshape(neg_likelihoods, x_test.shape)

        #lambda func to take log of each element
        log_likelihood = lambda x: np.log(x)

        # negative and positive log likelihoods
        neg_log_likelihoods = log_likelihood(neg_likelihoods)
        pos_log_likelihoods = log_likelihood(pos_likelihoods)
        sum_neg_loglike = np.sum(neg_log_likelihoods,axis=1)
        sum_pos_loglike = np.sum(pos_log_likelihoods,axis=1)

        # Compute neg and pos log posteriors
        compute_neg_posterior = lambda x: (x + np.log(neg_prior))
        compute_pos_posterior = lambda x: (x + np.log(pos_prior))

        log_neg_posterior = compute_neg_posterior(sum_neg_loglike)
        log_pos_posterior = compute_pos_posterior(sum_pos_loglike)

        # Get the posteriors
        neg_posterior = np.exp(log_neg_posterior)
        pos_posterior = np.exp(log_pos_posterior)

        y_pred = []

        for i in range(len(neg_posterior)):
            if neg_posterior[i]>pos_posterior[i]:
                y_pred.append(0)
            else:
                y_pred.append(1)


        return y_pred
    
    def evaluate_acc(self, y, y_pred):
        #Accuracy = (TP + TN)/ P + N
        #Error Rate = (FP + FN)/P + N
        #Precision = TP/RP
        #Recall = TP/P
        
        A = (np.mean(y_pred == y))*100
        #print(A)
        
        #Alternatively
        TP, TN, FN, FP = 0,0,0,0
        for i in range(len(y_pred)):
            if (y[i] == y_pred[i]) & (y_pred[i] == 1):
                TP = TP + 1
            if (y[i] != y_pred[i]) & (y_pred[i] == 1):
                FP = FP + 1
            if (y[i] == y_pred[i]) & (y_pred[i] == 0):
                TN = TN + 1
            if (y[i] != y_pred[i]) & (y_pred[i] == 0):
                FN = FN + 1
            
        N = TN + FP
        RP = TP + FP
        RN = TN + FN
        P = TP + FN
        
        accuracy = ((TP + TN) / (P + N))*100
        errorRate = ((FP + FN) / (P + N))*100
        precision = (TP / (RP))*100
        recall = (TP / (P))*100

        print("Accuracy: ", accuracy, "%")
        print("Error Rate: ", errorRate, "%")
        print("Precision: ", precision, "%")
        print("Recall: ", recall, "% \n")
        
        return A

# %% [markdown]
# ### K-Fold Cross Validation

# %%
# Implement a K-Fold Validation for Logistic Regression
# Split the training set into K folds and determine the average accuracy

def cross_validation_LR(model, x_train, y_train, K, num_steps = 5000, learning_rate = 0.01, min_error = 1e-2, random_shuffle = True):
    # Model: Logistic Regression Class (Initialize Model and if add_intercept = True)
    # x_train: input data
    # y_train: target data
    # K: Number of Folds to split the data
    # num_steps: Number of steps of Gradient Descent before termination
    # learning_rate: learning Rate of Gradient Descent
    # min_error: Early Termination Requirement (Min imrovement in Cost Function)
    # random_shuffle: True if you want the data to be randomly shuffled before cross validation
    
    
    #Ramdomly shuffle the data
    if random_shuffle:
        data = np.concatenate((x_train, y_train), axis = 1)
        data = np.random.shuffle(data)
        x_train = np.array(data.iloc[:, :-1])
        y_train = np.array(data.iloc[:, -1])
    
    #Split into K folds
    data_length = x_train.shape[0]
    #print(data_length)
    fold_size = int(math.floor(data_length/K))
    #print(fold_size)
    
    accuracy = 0
    
    for i in range(K):
        #Run through an iteration for a specific k-fold combination
        Val_fold_start = i * fold_size
        Val_fold_end = Val_fold_start + fold_size
        
        x_val = x_train[Val_fold_start:Val_fold_end,:]
        y_val = y_train[Val_fold_start:Val_fold_end]
        #print("Validation Size")
        #print(x_val.shape)
        #print(y_val.shape)
            
        x_training = np.concatenate((x_train[:Val_fold_start,:],x_train[Val_fold_end:,:]),axis = 0)
        y_training = np.concatenate((y_train[:Val_fold_start],y_train[Val_fold_end:]))
        
        
        #Training data for K Folds (Fit Function)
        w = model.fit(x_training, y_training, num_steps, learning_rate, min_error)
        
        
        #Cross Validation Fold (Predict Function)
        y_pred = model.predict(x_val, w)
        
        #print(y_val)
        #print(y_pred)
    
    
        #Average Cross Validation Error over all instances
        accuracy = accuracy + model.evaluate_acc(y_val, y_pred)

    
    avg_cross_validation_accuracy = accuracy / K
    
    print("average cross validation model accuracy = " + str(avg_cross_validation_accuracy) + "% \n")
    
    return avg_cross_validation_accuracy

# %%
# Implement a K-Fold Validation for Naive Bayes
# Split the training set into K folds and determine the average accuracy

def cross_validation_NB(model, x_train, y_train, K, random_shuffle = True):
    # Model: Logistic Regression Class (Initialize Model and if add_intercept = True)
    # x_train: input data
    # y_train: target data
    # K: Number of Folds to split the data
    # num_steps: Number of steps of Gradient Descent before termination
    # learning_rate: learning Rate of Gradient Descent
    # min_error: Early Termination Requirement (Min imrovement in Cost Function)
    # random_shuffle: True if you want the data to be randomly shuffled before cross validation
    
    
    #Ramdomly shuffle the data
    if random_shuffle:
        data = np.concatenate((x_train, y_train), axis = 1)
        data = np.random.shuffle(data)
        x_train = np.array(data.iloc[:, :-1])
        y_train = np.array(data.iloc[:, -1])
    
    #Split into K folds
    data_length = x_train.shape[0]
    #print(data_length)
    fold_size = int(math.floor(data_length/K))
    #print(fold_size)
    
    accuracy = 0
    
    for i in range(K):
        #Run through an iteration for a specific k-fold combination
        Val_fold_start = i * fold_size
        Val_fold_end = Val_fold_start + fold_size
        
        x_val = x_train[Val_fold_start:Val_fold_end,:]
        y_val = y_train[Val_fold_start:Val_fold_end]
        #print("Validation Size")
        #print(x_val.shape)
        #print(y_val.shape)
            
        x_training = np.concatenate((x_train[:Val_fold_start,:],x_train[Val_fold_end:,:]),axis = 0)
        y_training = np.concatenate((y_train[:Val_fold_start],y_train[Val_fold_end:]))
        
        
        #Training data for K Folds (Fit Function)
        likelihoods, neg_prior,pos_prior = model.fit(x_training, y_training)
        
        
        #Cross Validation Fold (Predict Function)
        y_pred = model.predict(x_val,likelihoods,neg_prior,pos_prior)
        
        #print(y_val)
        #print(y_pred)
    
    
        #Average Cross Validation Error over all instances
        accuracy = accuracy + model.evaluate_acc(y_val, y_pred)

    
    avg_cross_validation_accuracy = accuracy / K
    
    print("average cross validation model accuracy = " + str(avg_cross_validation_accuracy) + "% \n")
    
    return avg_cross_validation_accuracy

# %% [markdown]
# # Task 3 - Run Experiments
#
# Run Models and Test Accuracy for varying parameters

# %% [markdown]
# ### Cross Validation of Logistic Regression

# %%
Model_Logistic_Regression = LogisticRegression(intercept = True)

# %%
cross_validation_LR(Model_Logistic_Regression, x_train, y_train, K = 5, num_steps = 25000, learning_rate = 0.01, min_error = 1e-2, random_shuffle = False)
# Out:
# Number of Iterations = 20997
# Minimum Cost (J) = 0.08739515055256551
# Weights of Model:  [-6.17947023  0.20685025  0.05125276  0.22346239  0.20209678  0.03789129
#   0.36276059  0.21756921  0.23018577  0.17097108]
# Accuracy:  94.4954128440367 %
# Error Rate:  5.5045871559633035 %
# Precision:  92.5 %
# Recall:  92.5 %
#
# Number of Iterations = 21954
# Minimum Cost (J) = 0.07180229648341453
# Weights of Model:  [-6.34542075  0.236988    0.1265213   0.23451444  0.13859    -0.18174008
#   0.45603545  0.23587591  0.25120414  0.30675855]
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  92.10526315789474 %
# Recall:  87.5 %
#
# Number of Iterations = 20661
# Minimum Cost (J) = 0.09468421497102301
# Weights of Model:  [-6.12374907  0.29175125  0.03197742  0.36804639  0.23418487 -0.18747258
#   0.3374256   0.1645894   0.21225639  0.29162774]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  94.73684210526315 %
# Recall:  100.0 %
#
# Number of Iterations = 21352
# Minimum Cost (J) = 0.08898153884768215
# Weights of Model:  [-6.07067495  0.23673066  0.05479911  0.40941002  0.17723015 -0.16930605
#   0.38310616  0.17505109  0.15060769  0.31293567]
# Accuracy:  97.24770642201835 %
# Error Rate:  2.7522935779816518 %
# Precision:  96.875 %
# Recall:  93.93939393939394 %
#
# Number of Iterations = 21210
# Minimum Cost (J) = 0.0900886288745109
# Weights of Model:  [-6.33609369  0.29795495  0.06921551  0.29958507  0.18399374 -0.07048449
#   0.29671178  0.28043035  0.09365527  0.30076848]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  100.0 %
# Recall:  95.0 %
#
# average cross validation model accuracy = 96.14678899082568%
# 96.14678899082568

# %% [markdown]
# ### Cross Validation of Naive Bayes

# %%
Model_Naive_Bayes = MultinomialNaiveBayes()

# %%
cross_validation_NB(Model_Naive_Bayes, x_train, y_train, K = 5, random_shuffle = False)
# Out:
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  94.44444444444444 %
# Recall:  85.0 %
#
# Accuracy:  81.65137614678899 %
# Error Rate:  18.34862385321101 %
# Precision:  91.66666666666666 %
# Recall:  55.00000000000001 %
#
# Accuracy:  84.40366972477065 %
# Error Rate:  15.59633027522936 %
# Precision:  100.0 %
# Recall:  52.77777777777778 %
#
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  96.29629629629629 %
# Recall:  78.78787878787878 %
#
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  100.0 %
# Recall:  80.0 %
#
# average cross validation model accuracy = 88.80733944954129%
# 88.80733944954129

# %% [markdown]
# ### Test Accuracy of Models with Varying Parameters

# %%
#Test Logisitc Regression over different learning rates

#May need to play around with num_steps and min_error (stopping requirement)

#Initialize
learning_rates = [1, 0.5, 0.1, 0.05, 0.01, 0.005, 0.001, 0.0005, 0.0001, 0.00005, 0.00001]
lr_accuracy = []

for learning_rate in learning_rates:
    
    average_cross_validation_accuracy = cross_validation_LR(Model_Logistic_Regression, x_train, y_train, K = 5, num_steps = 25000, learning_rate = learning_rate, min_error = 1e-2, random_shuffle = False)
    lr_accuracy.append(average_cross_validation_accuracy)

#Plot
plt.plot(np.log10(learning_rates), lr_accuracy)
plt.title("Learning Rate vs Model Accuracy (Breast Cancer)")
plt.xlabel("Learning Rate (Logarithmic Scale)")
plt.ylabel("Model Accuracy (%)")
# Out:
# Number of Iterations = 219
# Minimum Cost (J) = 0.07450303648679871
# Weights of Model:  [-8.76822903e+00  4.48370042e-01 -5.90677438e-03  2.20530941e-01
#   3.20350857e-01  2.95296344e-03  4.17451193e-01  3.75010913e-01
#   2.79662065e-01  3.84838630e-01]
# Accuracy:  96.3302752293578 %
# Error Rate:  3.669724770642202 %
# Precision:  95.0 %
# Recall:  95.0 %
#
# Number of Iterations = 223
# Minimum Cost (J) = 0.05830291165013088
# Weights of Model:  [-8.56987983  0.43610094  0.14075201  0.14930878  0.21577933 -0.26398578
#   0.54931359  0.39090347  0.33894405  0.50527724]
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  92.10526315789474 %
# Recall:  87.5 %
#
# Number of Iterations = 234
# Minimum Cost (J) = 0.08106660739017256
# Weights of Model:  [-9.31759297  0.56951953  0.02700583  0.42222873  0.36186795 -0.25672402
#   0.36079454  0.40750012  0.24411239  0.56394488]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  94.73684210526315 %
# Recall:  100.0 %
#
# Number of Iterations = 240
# Minimum Cost (J) = 0.07492200524195977
# Weights of Model:  [-8.8085385   0.4760213  -0.08056568  0.56353611  0.28339486 -0.25113342
#   0.44444436  0.33482458  0.15481865  0.66062583]
# Accuracy:  96.3302752293578 %
# Error Rate:  3.669724770642202 %
# Precision:  96.7741935483871 %
# Recall:  90.9090909090909 %
#
# Number of Iterations = 256
# Minimum Cost (J) = 0.07449011224499799
# Weights of Model:  [-10.16258485   0.61137737  -0.05131756   0.40604743   0.34641493
#   -0.11280675   0.35409306   0.58138627   0.08133256   0.67865225]
# Accuracy:  97.24770642201835 %
# Error Rate:  2.7522935779816518 %
# Precision:  97.43589743589743 %
# Recall:  95.0 %
#
# average cross validation model accuracy = 96.14678899082568%
#
# Number of Iterations = 387
# Minimum Cost (J) = 0.08532990268619828
# Weights of Model:  [-6.39993853  0.22305667  0.0397638   0.22256878  0.20875571  0.05155634
#   0.36388511  0.23489192  0.23185409  0.18390728]
# Accuracy:  95.41284403669725 %
# Error Rate:  4.587155963302752 %
# Precision:  92.6829268292683 %
# Recall:  95.0 %
#
# Number of Iterations = 382
# Minimum Cost (J) = 0.0717781828642377
# Weights of Model:  [-6.35305499  0.23842893  0.13223562  0.22793705  0.13811727 -0.18212282
#   0.45680972  0.23633042  0.25173737  0.30662746]
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  92.10526315789474 %
# Recall:  87.5 %
#
# Number of Iterations = 396
# Minimum Cost (J) = 0.09126806825550868
# Weights of Model:  [-6.49902347  0.3249173   0.01169137  0.37251361  0.25173458 -0.1771088
#   0.34204113  0.19485596  0.21266769  0.3201065 ]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  94.73684210526315 %
# Recall:  100.0 %
#
# Number of Iterations = 420
# Minimum Cost (J) = 0.08580681032536862
# Weights of Model:  [-6.41439804  0.26750375  0.03755765  0.41358077  0.18634914 -0.1539265
#   0.38504928  0.19983735  0.14872712  0.34977412]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  96.96969696969697 %
# Recall:  96.96969696969697 %
#
# Number of Iterations = 516
# Minimum Cost (J) = 0.08282669660164176
# Weights of Model:  [-7.22199797  0.37007464  0.03516918  0.30290288  0.21509356 -0.03734819
#   0.30279451  0.35711734  0.08522908  0.37995225]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  100.0 %
# Recall:  95.0 %
#
# average cross validation model accuracy = 96.5137614678899%
#
# Number of Iterations = 2099
# Minimum Cost (J) = 0.08739010001158325
# Weights of Model:  [-6.1808543   0.20694872  0.05113694  0.22350295  0.20214076  0.03798736
#   0.3627658   0.21768623  0.23019623  0.17106192]
# Accuracy:  94.4954128440367 %
# Error Rate:  5.5045871559633035 %
# Precision:  92.5 %
# Recall:  92.5 %
#
# Number of Iterations = 2195
# Minimum Cost (J) = 0.0717935729712235
# Weights of Model:  [-6.34716897  0.23713894  0.12641631  0.23450256  0.13863729 -0.18165764
#   0.45605153  0.2360428   0.25121379  0.30687277]
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  92.10526315789474 %
# Recall:  87.5 %
#
# Number of Iterations = 2065
# Minimum Cost (J) = 0.0946830158276569
# Weights of Model:  [-6.12475184  0.29183467  0.03188163  0.3680892   0.23423616 -0.18743782
#   0.33743643  0.16466844  0.21225446  0.29170757]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  94.73684210526315 %
# Recall:  100.0 %
#
# Number of Iterations = 2135
# Minimum Cost (J) = 0.08897262229095036
# Weights of Model:  [-6.07243467  0.23687736  0.05465362  0.40948344  0.17727573 -0.16922333
#   0.38311063  0.1751815   0.15059221  0.31313148]
# Accuracy:  97.24770642201835 %
# Error Rate:  2.7522935779816518 %
# Precision:  96.875 %
# Recall:  93.93939393939394 %
#
# Number of Iterations = 2120
# Minimum Cost (J) = 0.09008539115018457
# Weights of Model:  [-6.337301    0.29805178  0.06915279  0.29959868  0.18403498 -0.07043126
#   0.29671639  0.28053716  0.09364068  0.30086867]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  100.0 %
# Recall:  95.0 %
#
# average cross validation model accuracy = 96.14678899082568%
#
# Number of Iterations = 4199
# Minimum Cost (J) = 0.08739259739994724
# Weights of Model:  [-6.18011578  0.20689615  0.05119858  0.2234815   0.20211731  0.03793606
#   0.36276302  0.21762379  0.23019066  0.17101354]
# Accuracy:  94.4954128440367 %
# Error Rate:  5.5045871559633035 %
# Precision:  92.5 %
# Recall:  92.5 %
#
# Number of Iterations = 4390
# Minimum Cost (J) = 0.0718016117350809
# Weights of Model:  [-6.34588284  0.23702783  0.12649286  0.23451193  0.13860252 -0.18171795
#   0.45603955  0.23592006  0.25120656  0.3067887 ]
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  92.10526315789474 %
# Recall:  87.5 %
#
# Number of Iterations = 4132
# Minimum Cost (J) = 0.09468063187801973
# Weights of Model:  [-6.12449465  0.29181327  0.03190643  0.36807819  0.2342231  -0.18744716
#   0.33743371  0.1646481   0.21225507  0.29168733]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  94.73684210526315 %
# Recall:  100.0 %
#
# Number of Iterations = 4270
# Minimum Cost (J) = 0.08897921489120196
# Weights of Model:  [-6.07129608  0.23678242  0.05474744  0.40943619  0.17724623 -0.16927672
#   0.38310769  0.17509719  0.15060219  0.31300464]
# Accuracy:  97.24770642201835 %
# Error Rate:  2.7522935779816518 %
# Precision:  96.875 %
# Recall:  93.93939393939394 %
#
# Number of Iterations = 4241
# Minimum Cost (J) = 0.09008878174953255
# Weights of Model:  [-6.33647325  0.29798538  0.06919545  0.29958966  0.18400671 -0.07046763
#   0.29671319  0.28046396  0.09365066  0.30079985]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  100.0 %
# Recall:  95.0 %
#
# average cross validation model accuracy = 96.14678899082568%
#
# Number of Iterations = 20997
# Minimum Cost (J) = 0.08739515055256551
# Weights of Model:  [-6.17947023  0.20685025  0.05125276  0.22346239  0.20209678  0.03789129
#   0.36276059  0.21756921  0.23018577  0.17097108]
# Accuracy:  94.4954128440367 %
# Error Rate:  5.5045871559633035 %
# Precision:  92.5 %
# Recall:  92.5 %
#
# Number of Iterations = 21954
# Minimum Cost (J) = 0.07180229648341453
# Weights of Model:  [-6.34542075  0.236988    0.1265213   0.23451444  0.13859    -0.18174008
#   0.45603545  0.23587591  0.25120414  0.30675855]
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  92.10526315789474 %
# Recall:  87.5 %
#
# Number of Iterations = 20661
# Minimum Cost (J) = 0.09468421497102301
# Weights of Model:  [-6.12374907  0.29175125  0.03197742  0.36804639  0.23418487 -0.18747258
#   0.3374256   0.1645894   0.21225639  0.29162774]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  94.73684210526315 %
# Recall:  100.0 %
#
# Number of Iterations = 21352
# Minimum Cost (J) = 0.08898153884768215
# Weights of Model:  [-6.07067495  0.23673066  0.05479911  0.40941002  0.17723015 -0.16930605
#   0.38310616  0.17505109  0.15060769  0.31293567]
# Accuracy:  97.24770642201835 %
# Error Rate:  2.7522935779816518 %
# Precision:  96.875 %
# Recall:  93.93939393939394 %
#
# Number of Iterations = 21210
# Minimum Cost (J) = 0.0900886288745109
# Weights of Model:  [-6.33609369  0.29795495  0.06921551  0.29958507  0.18399374 -0.07048449
#   0.29671178  0.28043035  0.09365527  0.30076848]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  100.0 %
# Recall:  95.0 %
#
# average cross validation model accuracy = 96.14678899082568%
# Number of Iterations = 24999
# Minimum Cost (J) = 0.10168514395232761
# Weights of Model:  [-5.10744731  0.12862944  0.1500501   0.1915157   0.17232557 -0.04696879
#   0.36263546  0.12006977  0.22667968  0.10435124]
# Accuracy:  94.4954128440367 %
# Error Rate:  5.5045871559633035 %
# Precision:  92.5 %
# Recall:  92.5 %
#
# Number of Iterations = 24999
# Minimum Cost (J) = 0.08765560009306651
# Weights of Model:  [-5.15265379  0.13381145  0.21454683  0.23299503  0.10793087 -0.25209673
#   0.45141168  0.1214654   0.24776227  0.23107927]
# Accuracy:  91.74311926605505 %
# Error Rate:  8.256880733944955 %
# Precision:  89.74358974358975 %
# Recall:  87.5 %
#
# Number of Iterations = 24999
# Minimum Cost (J) = 0.10817596671490921
# Weights of Model:  [-5.10373872  0.20664446  0.13832863  0.32095544  0.18543343 -0.23154133
#   0.33018076  0.0807891   0.21645196  0.21281288]
# Accuracy:  99.08256880733946 %
# Error Rate:  0.9174311926605505 %
# Precision:  97.2972972972973 %
# Recall:  100.0 %
#
# Number of Iterations = 24999
# Minimum Cost (J) = 0.10379812546078042
# Weights of Model:  [-4.95988468  0.14210186  0.16115655  0.35860943  0.15381014 -0.23324461
#   0.38568364  0.08489629  0.16418706  0.19492028]
# Accuracy:  97.24770642201835 %
# Error Rate:  2.7522935779816518 %
# Precision:  96.875 %
# Recall:  93.93939393939394 %
#
# Number of Iterations = 24999
# Minimum Cost (J) = 0.10465729337102735
# Weights of Model:  [-5.23746297  0.20932292  0.13592707  0.28486085  0.14840585 -0.1289649
#   0.29592497  0.17990318  0.10900407  0.21482012]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  100.0 %
# Recall:  95.0 %
#
# average cross validation model accuracy = 96.14678899082568%
#
# Number of Iterations = 24999
# Minimum Cost (J) = 0.197381699097204
# Weights of Model:  [-2.2684396  -0.13714751  0.46199448  0.18518725  0.16108841 -0.37486262
#   0.42502514 -0.21923201  0.27378278 -0.0499211 ]
# Accuracy:  93.57798165137615 %
# Error Rate:  6.422018348623854 %
# Precision:  94.5945945945946 %
# Recall:  87.5 %
#
# Number of Iterations = 24999
# Minimum Cost (J) = 0.18403307140295114
# Weights of Model:  [-2.29159114 -0.14825493  0.47295396  0.26834326  0.09437782 -0.51314564
#   0.48673632 -0.16375213  0.24921096  0.05478226]
# Accuracy:  93.57798165137615 %
# Error Rate:  6.422018348623854 %
# Precision:  92.3076923076923 %
# Recall:  90.0 %
#
# Number of Iterations = 24999
# Minimum Cost (J) = 0.20474852774261082
# Weights of Model:  [-2.25572543 -0.0525756   0.48683804  0.21989468  0.12368691 -0.46243029
#   0.37638693 -0.21105587  0.2550375  -0.00470464]
# Accuracy:  97.24770642201835 %
# Error Rate:  2.7522935779816518 %
# Precision:  94.5945945945946 %
# Recall:  97.22222222222221 %
#
# Number of Iterations = 24999
# Minimum Cost (J) = 0.195298818857224
# Weights of Model:  [-2.17805301 -0.13991135  0.47153855  0.31430993  0.159409   -0.50801093
#   0.45721945 -0.21717222  0.2342594  -0.04844064]
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  90.32258064516128 %
# Recall:  84.84848484848484 %
#
# Number of Iterations = 24999
# Minimum Cost (J) = 0.20373870618363182
# Weights of Model:  [-2.34981726 -0.05270741  0.39637246  0.28647672  0.10448533 -0.41050478
#   0.35280204 -0.12743501  0.16769435  0.0107875 ]
# Accuracy:  96.3302752293578 %
# Error Rate:  3.669724770642202 %
# Precision:  97.36842105263158 %
# Recall:  92.5 %
#
# average cross validation model accuracy = 94.67889908256882%
#
# Number of Iterations = 24999
# Minimum Cost (J) = 0.2517114157241845
# Weights of Model:  [-1.4611566  -0.22628104  0.46390173  0.23153284  0.15498035 -0.41417146
#   0.43055539 -0.28527715  0.27988026 -0.0986898 ]
# Accuracy:  90.82568807339449 %
# Error Rate:  9.174311926605505 %
# Precision:  87.5 %
# Recall:  87.5 %
#
# Number of Iterations = 24999
# Minimum Cost (J) = 0.24058725093695574
# Weights of Model:  [-1.46811744 -0.23349273  0.45713187  0.31275709  0.1015991  -0.51674672
#   0.47441624 -0.22774581  0.24095903 -0.02022674]
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  90.0 %
# Recall:  90.0 %
#
# Number of Iterations = 24999
# Minimum Cost (J) = 0.26030835278427367
# Weights of Model:  [-1.43805106 -0.13489211  0.47972387  0.24234042  0.11704582 -0.48925899
#   0.39430913 -0.28087698  0.25792188 -0.06737042]
# Accuracy:  97.24770642201835 %
# Error Rate:  2.7522935779816518 %
# Precision:  94.5945945945946 %
# Recall:  97.22222222222221 %
#
# Number of Iterations = 24999
# Minimum Cost (J) = 0.24572116390062465
# Weights of Model:  [-1.39843641 -0.22137329  0.45885022  0.33628369  0.15656074 -0.5173637
#   0.46070036 -0.27778842  0.2371069  -0.10324826]
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  90.32258064516128 %
# Recall:  84.84848484848484 %
#
# Number of Iterations = 24999
# Minimum Cost (J) = 0.26310774587651725
# Weights of Model:  [-1.50743064 -0.14379987  0.41819733  0.31927963  0.10430153 -0.46139255
#   0.36906044 -0.21062396  0.18399137 -0.05042208]
# Accuracy:  97.24770642201835 %
# Error Rate:  2.7522935779816518 %
# Precision:  97.43589743589743 %
# Recall:  95.0 %
#
# average cross validation model accuracy = 94.12844036697247%
#
# Number of Iterations = 24999
# Minimum Cost (J) = 0.37647292879429745
# Weights of Model:  [-0.45382263 -0.24842907  0.25844634  0.19008984  0.07264107 -0.23969264
#   0.31109722 -0.18053418  0.17739765 -0.09972794]
# Accuracy:  87.1559633027523 %
# Error Rate:  12.844036697247708 %
# Precision:  80.95238095238095 %
# Recall:  85.0 %
#
# Number of Iterations = 24999
# Minimum Cost (J) = 0.3708901570997401
# Weights of Model:  [-0.452553   -0.25249399  0.250435    0.22991049  0.05268206 -0.26649246
#   0.33322153 -0.15396037  0.14208902 -0.07536829]
# Accuracy:  89.90825688073394 %
# Error Rate:  10.091743119266056 %
# Precision:  83.72093023255815 %
# Recall:  90.0 %
#
# Number of Iterations = 24999
# Minimum Cost (J) = 0.3835093647436624
# Weights of Model:  [-0.44163448 -0.19352301  0.25520237  0.18442914  0.07159696 -0.28761339
#   0.31446168 -0.18327305  0.14612313 -0.08725994]
# Accuracy:  91.74311926605505 %
# Error Rate:  8.256880733944955 %
# Precision:  81.3953488372093 %
# Recall:  97.22222222222221 %
#
# Number of Iterations = 24999
# Minimum Cost (J) = 0.36541830105286643
# Weights of Model:  [-0.43637266 -0.23517783  0.25764539  0.22367185  0.07929386 -0.27801313
#   0.33013478 -0.17837972  0.14359506 -0.10593484]
# Accuracy:  88.07339449541286 %
# Error Rate:  11.926605504587156 %
# Precision:  79.41176470588235 %
# Recall:  81.81818181818183 %
#
# Number of Iterations = 24999
# Minimum Cost (J) = 0.3929357513502426
# Weights of Model:  [-0.46182719 -0.20471916  0.25029767  0.2278165   0.06205491 -0.26888997
#   0.28232792 -0.16197624  0.12652819 -0.07238898]
# Accuracy:  94.4954128440367 %
# Error Rate:  5.5045871559633035 %
# Precision:  92.5 %
# Recall:  92.5 %
#
# average cross validation model accuracy = 90.27522935779817%
#
# Number of Iterations = 24999
# Minimum Cost (J) = 0.43782715469893035
# Weights of Model:  [-0.25801392 -0.19007911  0.17183033  0.13627528  0.04929709 -0.15463944
#   0.22811578 -0.11182456  0.1221593  -0.07300168]
# Accuracy:  86.23853211009175 %
# Error Rate:  13.761467889908257 %
# Precision:  79.06976744186046 %
# Recall:  85.0 %
#
# Number of Iterations = 24999
# Minimum Cost (J) = 0.4344365295453903
# Weights of Model:  [-0.25685662 -0.19427566  0.16678198  0.16088063  0.03760603 -0.16474329
#   0.24444114 -0.09462618  0.0934617  -0.06019669]
# Accuracy:  89.90825688073394 %
# Error Rate:  10.091743119266056 %
# Precision:  83.72093023255815 %
# Recall:  90.0 %
#
# Number of Iterations = 24999
# Minimum Cost (J) = 0.44273968424629095
# Weights of Model:  [-0.25104931 -0.15799211  0.16951448  0.13184305  0.05454492 -0.18522266
#   0.23595536 -0.11301316  0.09487115 -0.06498656]
# Accuracy:  89.90825688073394 %
# Error Rate:  10.091743119266056 %
# Precision:  77.77777777777779 %
# Recall:  97.22222222222221 %
#
# Number of Iterations = 24999
# Minimum Cost (J) = 0.42759368571295464
# Weights of Model:  [-0.24875821 -0.17960756  0.1734314   0.15383115  0.05411183 -0.17713195
#   0.24260467 -0.11026343  0.09741758 -0.07751629]
# Accuracy:  86.23853211009175 %
# Error Rate:  13.761467889908257 %
# Precision:  73.68421052631578 %
# Recall:  84.84848484848484 %
#
# Number of Iterations = 24999
# Minimum Cost (J) = 0.4530497682806463
# Weights of Model:  [-0.26110332 -0.16217307  0.16936949  0.15883202  0.04504182 -0.17103792
#   0.20968971 -0.10255976  0.08831682 -0.05567912]
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  88.09523809523809 %
# Recall:  92.5 %
#
# average cross validation model accuracy = 88.99082568807339%
# Number of Iterations = 24999
# Minimum Cost (J) = 0.5770967025471352
# Weights of Model:  [-0.05870417 -0.05189298  0.05747668  0.05012277  0.02378943 -0.03407078
#   0.08123269 -0.01868885  0.04383675 -0.01890904]
# Accuracy:  72.47706422018348 %
# Error Rate:  27.522935779816514 %
# Precision:  57.35294117647059 %
# Recall:  97.5 %
#
# Number of Iterations = 24999
# Minimum Cost (J) = 0.5765904587919961
# Weights of Model:  [-0.05835115 -0.05390048  0.05569552  0.05617788  0.02075263 -0.03424766
#   0.08717062 -0.01405811  0.03267616 -0.01653901]
# Accuracy:  65.13761467889908 %
# Error Rate:  34.862385321100916 %
# Precision:  51.31578947368421 %
# Recall:  97.5 %
#
# Number of Iterations = 24999
# Minimum Cost (J) = 0.5770056150417182
# Weights of Model:  [-0.0571341  -0.04528423  0.05732496  0.04910479  0.02722173 -0.04148487
#   0.08593935 -0.01837158  0.03376336 -0.01649709]
# Accuracy:  77.06422018348624 %
# Error Rate:  22.93577981651376 %
# Precision:  59.01639344262295 %
# Recall:  100.0 %
#
# Number of Iterations = 24999
# Minimum Cost (J) = 0.5699764990603315
# Weights of Model:  [-0.05660357 -0.047877    0.05931745  0.05435469  0.02554776 -0.03924213
#   0.08724797 -0.01760599  0.03617812 -0.01977704]
# Accuracy:  59.63302752293578 %
# Error Rate:  40.36697247706422 %
# Precision:  42.66666666666667 %
# Recall:  96.96969696969697 %
#
# Number of Iterations = 24999
# Minimum Cost (J) = 0.5844059222437842
# Weights of Model:  [-0.05890001 -0.04388571  0.05755366  0.05573403  0.02300414 -0.03696319
#   0.07591976 -0.0169662   0.03365043 -0.01406088]
# Accuracy:  74.31192660550458 %
# Error Rate:  25.688073394495415 %
# Precision:  58.82352941176471 %
# Recall:  100.0 %
#
# average cross validation model accuracy = 69.72477064220183%
# Text(0, 0.5, 'Model Accuracy (%)')

# %%
#Threshold of change in value of cost function as termination criteria
#Test Logisitc Regression over different thresholds of cost function improvement

#Initialize
termination_thresholds = [0.2, 0.15, 0.1, 0.05, 0.01, 0.005, 0.001] 
lr_accuracy = []

for threshold in termination_thresholds:
    
    average_cross_validation_accuracy = cross_validation_LR(Model_Logistic_Regression, x_train, y_train, K = 5, num_steps = 5000, learning_rate = 0.01, min_error = threshold, random_shuffle = False)
    lr_accuracy.append(average_cross_validation_accuracy)

#Plot
plt.plot(termination_thresholds, lr_accuracy)
plt.title("Threshold for Termination vs Model Accuracy (Breast Cancer)")
plt.xlabel("Cost Function Improvement Termination Value")
plt.ylabel("Model Accuracy (%)")
# Out:
# Number of Iterations = 214
# Minimum Cost (J) = 0.3894514641914765
# Weights of Model:  [-0.40299381 -0.23836608  0.23830417  0.1787965   0.06661727 -0.22022049
#   0.29399039 -0.16491559  0.16501602 -0.09463063]
# Accuracy:  86.23853211009175 %
# Error Rate:  13.761467889908257 %
# Precision:  79.06976744186046 %
# Recall:  85.0 %
#
# Number of Iterations = 222
# Minimum Cost (J) = 0.3811488789338674
# Weights of Model:  [-0.41359009 -0.24519113  0.23573574  0.21870227  0.04969982 -0.24821834
#   0.31938698 -0.14390081  0.13360189 -0.07389305]
# Accuracy:  89.90825688073394 %
# Error Rate:  10.091743119266056 %
# Precision:  83.72093023255815 %
# Recall:  90.0 %
#
# Number of Iterations = 208
# Minimum Cost (J) = 0.39846486359122607
# Weights of Model:  [-0.38333644 -0.18760887  0.23132447  0.17102927  0.06696749 -0.2599082
#   0.29588203 -0.16434034  0.13174007 -0.08242638]
# Accuracy:  91.74311926605505 %
# Error Rate:  8.256880733944955 %
# Precision:  81.3953488372093 %
# Recall:  97.22222222222221 %
#
# Number of Iterations = 216
# Minimum Cost (J) = 0.3776701128885624
# Weights of Model:  [-0.3906177  -0.22617637  0.23943148  0.20908973  0.07334953 -0.25597906
#   0.31317898 -0.16391612  0.13371754 -0.10093258]
# Accuracy:  87.1559633027523 %
# Error Rate:  12.844036697247708 %
# Precision:  77.14285714285715 %
# Recall:  81.81818181818183 %
#
# Number of Iterations = 212
# Minimum Cost (J) = 0.4066189513626448
# Weights of Model:  [-0.40649695 -0.19795654  0.2306616   0.21180762  0.05768337 -0.24497423
#   0.2667774  -0.14814818  0.11754772 -0.06942346]
# Accuracy:  93.57798165137615 %
# Error Rate:  6.422018348623854 %
# Precision:  90.2439024390244 %
# Recall:  92.5 %
#
# average cross validation model accuracy = 89.72477064220183%
#
# Number of Iterations = 352
# Minimum Cost (J) = 0.3485945525944996
# Weights of Model:  [-0.59274601 -0.26622689  0.30788973  0.21478501  0.08920611 -0.28698726
#   0.34893775 -0.21732117  0.20669365 -0.10986373]
# Accuracy:  89.90825688073394 %
# Error Rate:  10.091743119266056 %
# Precision:  85.36585365853658 %
# Recall:  87.5 %
#
# Number of Iterations = 366
# Minimum Cost (J) = 0.3385807308676494
# Weights of Model:  [-0.60949142 -0.27132974  0.30363374  0.26724722  0.0647615  -0.33345267
#   0.37892953 -0.18797876  0.17195941 -0.07719165]
# Accuracy:  91.74311926605505 %
# Error Rate:  8.256880733944955 %
# Precision:  87.8048780487805 %
# Recall:  90.0 %
#
# Number of Iterations = 344
# Minimum Cost (J) = 0.3581358234458472
# Weights of Model:  [-0.56721753 -0.19880269  0.30200581  0.20802157  0.08089832 -0.33988958
#   0.34506208 -0.21802571  0.17387728 -0.09405425]
# Accuracy:  93.57798165137615 %
# Error Rate:  6.422018348623854 %
# Precision:  85.36585365853658 %
# Recall:  97.22222222222221 %
#
# Number of Iterations = 347
# Minimum Cost (J) = 0.33877458917374453
# Weights of Model:  [-0.56293386 -0.25208854  0.30317021  0.25860981  0.09537438 -0.33361472
#   0.36896214 -0.21303342  0.167724   -0.11594769]
# Accuracy:  89.90825688073394 %
# Error Rate:  10.091743119266056 %
# Precision:  84.375 %
# Recall:  81.81818181818183 %
#
# Number of Iterations = 356
# Minimum Cost (J) = 0.3640326358376744
# Weights of Model:  [-0.61022846 -0.21305143  0.29634983  0.26325656  0.07306967 -0.32524505
#   0.31460743 -0.191892    0.14662385 -0.07706323]
# Accuracy:  95.41284403669725 %
# Error Rate:  4.587155963302752 %
# Precision:  94.87179487179486 %
# Recall:  92.5 %
#
# average cross validation model accuracy = 92.11009174311928%
#
# Number of Iterations = 756
# Minimum Cost (J) = 0.29008360195365573
# Weights of Model:  [-1.03613701 -0.26265219  0.41457351  0.2432807   0.1327412  -0.38260401
#   0.410655   -0.28001624  0.26135383 -0.11463658]
# Accuracy:  89.90825688073394 %
# Error Rate:  10.091743119266056 %
# Precision:  85.36585365853658 %
# Recall:  87.5 %
#
# Number of Iterations = 790
# Minimum Cost (J) = 0.27720498784101527
# Weights of Model:  [-1.07045254 -0.26545459  0.40899203  0.31469476  0.0921692  -0.46499743
#   0.4490924  -0.23235483  0.2230242  -0.05484861]
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  90.0 %
# Recall:  90.0 %
#
# Number of Iterations = 751
# Minimum Cost (J) = 0.29929277254416786
# Weights of Model:  [-1.00889942 -0.17507988  0.41951385  0.24429792  0.10495922 -0.4520298
#   0.38908297 -0.28003738  0.23542137 -0.09065725]
# Accuracy:  96.3302752293578 %
# Error Rate:  3.669724770642202 %
# Precision:  94.44444444444444 %
# Recall:  94.44444444444444 %
#
# Number of Iterations = 711
# Minimum Cost (J) = 0.2857464860602367
# Weights of Model:  [-0.94984066 -0.25455341  0.40025735  0.31937942  0.13417686 -0.45319585
#   0.43396165 -0.27125938  0.2145642  -0.12098763]
# Accuracy:  90.82568807339449 %
# Error Rate:  9.174311926605505 %
# Precision:  84.84848484848484 %
# Recall:  84.84848484848484 %
#
# Number of Iterations = 805
# Minimum Cost (J) = 0.2993008153911896
# Weights of Model:  [-1.11307963 -0.18450305  0.39049023  0.31735748  0.09749885 -0.4370484
#   0.36167873 -0.22685476  0.17987015 -0.06996713]
# Accuracy:  96.3302752293578 %
# Error Rate:  3.669724770642202 %
# Precision:  97.36842105263158 %
# Recall:  92.5 %
#
# average cross validation model accuracy = 93.21100917431193%
#
# Number of Iterations = 3028
# Minimum Cost (J) = 0.18264297661919102
# Weights of Model:  [-2.54083316 -0.10651466  0.44184534  0.17293397  0.15885625 -0.34544079
#   0.4171888  -0.18620261  0.26702416 -0.03313569]
# Accuracy:  94.4954128440367 %
# Error Rate:  5.5045871559633035 %
# Precision:  94.73684210526315 %
# Recall:  90.0 %
#
# Number of Iterations = 3086
# Minimum Cost (J) = 0.16741420132575688
# Weights of Model:  [-2.59813718 -0.11496724  0.458297    0.2521034   0.08949355 -0.49031893
#   0.48430078 -0.1328988   0.24913687  0.07796411]
# Accuracy:  93.57798165137615 %
# Error Rate:  6.422018348623854 %
# Precision:  92.3076923076923 %
# Recall:  90.0 %
#
# Number of Iterations = 3097
# Minimum Cost (J) = 0.18784873921027534
# Weights of Model:  [-2.56697549 -0.02150282  0.46299596  0.21726372  0.12498601 -0.43650018
#   0.36692861 -0.17565105  0.24876854  0.02036349]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  97.22222222222221 %
# Recall:  97.22222222222221 %
#
# Number of Iterations = 2869
# Minimum Cost (J) = 0.18533671079083358
# Weights of Model:  [-2.36627913 -0.11887482  0.4618966   0.30774908  0.15721763 -0.49252271
#   0.45202855 -0.19663426  0.22950625 -0.03346797]
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  90.32258064516128 %
# Recall:  84.84848484848484 %
#
# Number of Iterations = 3201
# Minimum Cost (J) = 0.18333579953917295
# Weights of Model:  [-2.71872224 -0.01462333  0.36670073  0.27309107  0.10446125 -0.3687057
#   0.34098433 -0.08503197  0.15808912  0.0389945 ]
# Accuracy:  97.24770642201835 %
# Error Rate:  2.7522935779816518 %
# Precision:  97.43589743589743 %
# Recall:  95.0 %
#
# average cross validation model accuracy = 95.22935779816514%
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.1471907702080013
# Weights of Model:  [-3.34849658 -0.02167751  0.35371713  0.15763173  0.15353657 -0.24330546
#   0.39147366 -0.08113693  0.24709562  0.01151086]
# Accuracy:  95.41284403669725 %
# Error Rate:  4.587155963302752 %
# Precision:  94.87179487179486 %
# Recall:  92.5 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.13298408735645093
# Weights of Model:  [-3.38865801 -0.03129112  0.39181687  0.22692645  0.08357865 -0.41208718
#   0.47144344 -0.05165466  0.24828644  0.12738537]
# Accuracy:  93.57798165137615 %
# Error Rate:  6.422018348623854 %
# Precision:  92.3076923076923 %
# Recall:  90.0 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.1533610149151046
# Weights of Model:  [-3.35258543  0.05386139  0.36894127  0.23286772  0.13247204 -0.36210869
#   0.34575234 -0.08667839  0.2341755   0.08176001]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  97.22222222222221 %
# Recall:  97.22222222222221 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.14793546075333786
# Weights of Model:  [-3.22989065 -0.02377171  0.3772596   0.2966189   0.14722282 -0.39844613
#   0.42284506 -0.09563182  0.20348425  0.03673892]
# Accuracy:  93.57798165137615 %
# Error Rate:  6.422018348623854 %
# Precision:  90.625 %
# Recall:  87.87878787878788 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.15050126462495544
# Weights of Model:  [-3.46463918e+00  5.74824271e-02  2.93736243e-01  2.61909819e-01
#   1.09421849e-01 -2.81953569e-01  3.19282403e-01 -8.87811711e-04
#   1.40997669e-01  9.20592340e-02]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  100.0 %
# Recall:  95.0 %
#
# average cross validation model accuracy = 95.77981651376146%
# Number of Iterations = 4999
# Minimum Cost (J) = 0.1471907702080013
# Weights of Model:  [-3.34849658 -0.02167751  0.35371713  0.15763173  0.15353657 -0.24330546
#   0.39147366 -0.08113693  0.24709562  0.01151086]
# Accuracy:  95.41284403669725 %
# Error Rate:  4.587155963302752 %
# Precision:  94.87179487179486 %
# Recall:  92.5 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.13298408735645093
# Weights of Model:  [-3.38865801 -0.03129112  0.39181687  0.22692645  0.08357865 -0.41208718
#   0.47144344 -0.05165466  0.24828644  0.12738537]
# Accuracy:  93.57798165137615 %
# Error Rate:  6.422018348623854 %
# Precision:  92.3076923076923 %
# Recall:  90.0 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.1533610149151046
# Weights of Model:  [-3.35258543  0.05386139  0.36894127  0.23286772  0.13247204 -0.36210869
#   0.34575234 -0.08667839  0.2341755   0.08176001]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  97.22222222222221 %
# Recall:  97.22222222222221 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.14793546075333786
# Weights of Model:  [-3.22989065 -0.02377171  0.3772596   0.2966189   0.14722282 -0.39844613
#   0.42284506 -0.09563182  0.20348425  0.03673892]
# Accuracy:  93.57798165137615 %
# Error Rate:  6.422018348623854 %
# Precision:  90.625 %
# Recall:  87.87878787878788 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.15050126462495544
# Weights of Model:  [-3.46463918e+00  5.74824271e-02  2.93736243e-01  2.61909819e-01
#   1.09421849e-01 -2.81953569e-01  3.19282403e-01 -8.87811711e-04
#   1.40997669e-01  9.20592340e-02]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  100.0 %
# Recall:  95.0 %
#
# average cross validation model accuracy = 95.77981651376146%
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.1471907702080013
# Weights of Model:  [-3.34849658 -0.02167751  0.35371713  0.15763173  0.15353657 -0.24330546
#   0.39147366 -0.08113693  0.24709562  0.01151086]
# Accuracy:  95.41284403669725 %
# Error Rate:  4.587155963302752 %
# Precision:  94.87179487179486 %
# Recall:  92.5 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.13298408735645093
# Weights of Model:  [-3.38865801 -0.03129112  0.39181687  0.22692645  0.08357865 -0.41208718
#   0.47144344 -0.05165466  0.24828644  0.12738537]
# Accuracy:  93.57798165137615 %
# Error Rate:  6.422018348623854 %
# Precision:  92.3076923076923 %
# Recall:  90.0 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.1533610149151046
# Weights of Model:  [-3.35258543  0.05386139  0.36894127  0.23286772  0.13247204 -0.36210869
#   0.34575234 -0.08667839  0.2341755   0.08176001]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  97.22222222222221 %
# Recall:  97.22222222222221 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.14793546075333786
# Weights of Model:  [-3.22989065 -0.02377171  0.3772596   0.2966189   0.14722282 -0.39844613
#   0.42284506 -0.09563182  0.20348425  0.03673892]
# Accuracy:  93.57798165137615 %
# Error Rate:  6.422018348623854 %
# Precision:  90.625 %
# Recall:  87.87878787878788 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.15050126462495544
# Weights of Model:  [-3.46463918e+00  5.74824271e-02  2.93736243e-01  2.61909819e-01
#   1.09421849e-01 -2.81953569e-01  3.19282403e-01 -8.87811711e-04
#   1.40997669e-01  9.20592340e-02]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  100.0 %
# Recall:  95.0 %
#
# average cross validation model accuracy = 95.77981651376146%
# Text(0, 0.5, 'Model Accuracy (%)')

# %%
#Plot Accuracy of Train/Validation Set as a Function of Iterations of Gradient Descent
#Limit number of steps

#Initialize
number_of_iterations = [100, 500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000, 5500, 6000, 6500, 7000, 7500, 8000, 8500, 9000, 9500, 10000, 10500, 20000]
lr_accuracy = []

for num_steps in number_of_iterations:
    
    average_cross_validation_accuracy = cross_validation_LR(Model_Logistic_Regression, x_train, y_train, K = 5, num_steps = num_steps, learning_rate = 0.01, min_error = 1e-2, random_shuffle = False)
    lr_accuracy.append(average_cross_validation_accuracy)

#Plot
plt.plot(number_of_iterations, lr_accuracy)
plt.title("Number of Iterations vs Model Accuracy (Breast Cancer)")
plt.xlabel("Number of Iterations")
plt.ylabel("Model Accuracy (%)")
# Out:
# Number of Iterations = 99
# Minimum Cost (J) = 0.45943404065079385
# Weights of Model:  [-0.21346107 -0.16873176  0.14898218  0.12032873  0.04408311 -0.13156
#   0.20243585 -0.09324414  0.10696511 -0.06410924]
# Accuracy:  84.40366972477065 %
# Error Rate:  15.59633027522936 %
# Precision:  75.55555555555556 %
# Recall:  85.0 %
#
# Number of Iterations = 99
# Minimum Cost (J) = 0.45662245511460353
# Weights of Model:  [-0.21241199 -0.17279361  0.14463454  0.14107429  0.03425911 -0.13847857
#   0.21713996 -0.07843833  0.08074005 -0.05386083]
# Accuracy:  88.9908256880734 %
# Error Rate:  11.009174311926607 %
# Precision:  81.81818181818183 %
# Recall:  90.0 %
#
# Number of Iterations = 99
# Minimum Cost (J) = 0.46349165593928776
# Weights of Model:  [-0.20772534 -0.1424625   0.14715445  0.11650277  0.04987449 -0.15735465
#   0.21048291 -0.09399631  0.0819058  -0.05717901]
# Accuracy:  89.90825688073394 %
# Error Rate:  10.091743119266056 %
# Precision:  77.77777777777779 %
# Recall:  97.22222222222221 %
#
# Number of Iterations = 99
# Minimum Cost (J) = 0.4496254791806449
# Weights of Model:  [-0.20593422 -0.15937057  0.15095931  0.13450293  0.0482476  -0.15034842
#   0.21558347 -0.09177965  0.08506336 -0.06793887]
# Accuracy:  85.3211009174312 %
# Error Rate:  14.678899082568808 %
# Precision:  71.7948717948718 %
# Recall:  84.84848484848484 %
#
# Number of Iterations = 99
# Minimum Cost (J) = 0.47384641549557477
# Weights of Model:  [-0.2156526  -0.14478292  0.14749128  0.1392216   0.04084087 -0.1447989
#   0.18657806 -0.08581215  0.07765976 -0.04936106]
# Accuracy:  91.74311926605505 %
# Error Rate:  8.256880733944955 %
# Precision:  86.04651162790698 %
# Recall:  92.5 %
#
# average cross validation model accuracy = 88.07339449541284%
#
# Number of Iterations = 499
# Minimum Cost (J) = 0.3215421957436093
# Weights of Model:  [-0.7687676  -0.27231262  0.35840994  0.23353867  0.10868646 -0.33398298
#   0.38122756 -0.25107135  0.2342767  -0.1156279 ]
# Accuracy:  89.90825688073394 %
# Error Rate:  10.091743119266056 %
# Precision:  85.36585365853658 %
# Recall:  87.5 %
#
# Number of Iterations = 499
# Minimum Cost (J) = 0.3135276021164201
# Weights of Model:  [-0.7683873  -0.27619288  0.34733755  0.29222922  0.07597502 -0.38896431
#   0.41095727 -0.21141165  0.19478058 -0.07300248]
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  90.0 %
# Recall:  90.0 %
#
# Number of Iterations = 499
# Minimum Cost (J) = 0.3298593921356814
# Weights of Model:  [-0.7497577  -0.19369864  0.35847081  0.23013229  0.09238397 -0.39794651
#   0.37153802 -0.25361842  0.20543278 -0.09652352]
# Accuracy:  96.3302752293578 %
# Error Rate:  3.669724770642202 %
# Precision:  94.44444444444444 %
# Recall:  94.44444444444444 %
#
# Number of Iterations = 499
# Minimum Cost (J) = 0.31128342176745977
# Weights of Model:  [-0.73684224 -0.25946712  0.35350217  0.2931794   0.11501901 -0.3958864
#   0.40552397 -0.24706505  0.19297887 -0.12177018]
# Accuracy:  89.90825688073394 %
# Error Rate:  10.091743119266056 %
# Precision:  84.375 %
# Recall:  81.81818181818183 %
#
# Number of Iterations = 499
# Minimum Cost (J) = 0.3372512100559892
# Weights of Model:  [-0.7870049  -0.20925984  0.33884092  0.29182426  0.08398963 -0.37706942
#   0.33887504 -0.21413699  0.16334768 -0.07761683]
# Accuracy:  95.41284403669725 %
# Error Rate:  4.587155963302752 %
# Precision:  94.87179487179486 %
# Recall:  92.5 %
#
# average cross validation model accuracy = 92.8440366972477%
#
# Number of Iterations = 999
# Minimum Cost (J) = 0.2689293998317611
# Weights of Model:  [-1.2570618  -0.24570017  0.44565859  0.24003088  0.14666402 -0.40521731
#   0.42405461 -0.28792304  0.27396457 -0.10797382]
# Accuracy:  90.82568807339449 %
# Error Rate:  9.174311926605505 %
# Precision:  87.5 %
# Recall:  87.5 %
#
# Number of Iterations = 999
# Minimum Cost (J) = 0.2585817009018865
# Weights of Model:  [-1.26102468 -0.25166965  0.43620684  0.31705791  0.09831156 -0.49584885
#   0.46376549 -0.23371163  0.23365252 -0.03918829]
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  90.0 %
# Recall:  90.0 %
#
# Number of Iterations = 999
# Minimum Cost (J) = 0.27767124470783044
# Weights of Model:  [-1.23356359 -0.15472698  0.45689842  0.24592325  0.11249562 -0.47821636
#   0.39420441 -0.28576361  0.25059435 -0.08000322]
# Accuracy:  97.24770642201835 %
# Error Rate:  2.7522935779816518 %
# Precision:  94.5945945945946 %
# Recall:  97.22222222222221 %
#
# Number of Iterations = 999
# Minimum Cost (J) = 0.2616615769349629
# Weights of Model:  [-1.20283493 -0.23822167  0.43908536  0.33380106  0.14955568 -0.4978385
#   0.45315652 -0.28086704  0.2304136  -0.11298177]
# Accuracy:  91.74311926605505 %
# Error Rate:  8.256880733944955 %
# Precision:  87.5 %
# Recall:  84.84848484848484 %
#
# Number of Iterations = 999
# Minimum Cost (J) = 0.2817466255680094
# Weights of Model:  [-1.29455851 -0.16643924  0.40731978  0.32110223  0.10168423 -0.45388921
#   0.36706249 -0.22260983  0.18341721 -0.06215114]
# Accuracy:  97.24770642201835 %
# Error Rate:  2.7522935779816518 %
# Precision:  97.43589743589743 %
# Recall:  95.0 %
#
# average cross validation model accuracy = 93.94495412844037%
#
# Number of Iterations = 1499
# Minimum Cost (J) = 0.23754620277061778
# Weights of Model:  [-1.64759726 -0.20682926  0.47327231  0.22134942  0.15954972 -0.41445009
#   0.43303344 -0.27670164  0.28187763 -0.0885472 ]
# Accuracy:  90.82568807339449 %
# Error Rate:  9.174311926605505 %
# Precision:  87.5 %
# Recall:  87.5 %
#
# Number of Iterations = 1499
# Minimum Cost (J) = 0.2257839280068413
# Weights of Model:  [-1.65783983 -0.21517005  0.46972957  0.30490348  0.10217987 -0.526795
#   0.48087029 -0.21753723  0.24510155 -0.00212845]
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  90.0 %
# Recall:  90.0 %
#
# Number of Iterations = 1499
# Minimum Cost (J) = 0.24591505910208925
# Weights of Model:  [-1.62583061 -0.11621235  0.49264348  0.23702542  0.11982024 -0.49159101
#   0.39213863 -0.27051114  0.26084763 -0.05419926]
# Accuracy:  97.24770642201835 %
# Error Rate:  2.7522935779816518 %
# Precision:  94.5945945945946 %
# Recall:  97.22222222222221 %
#
# Number of Iterations = 1499
# Minimum Cost (J) = 0.2326248395802916
# Weights of Model:  [-1.57765478 -0.20416326  0.4706448   0.33435749  0.16014971 -0.52623277
#   0.46387037 -0.26944444  0.24008247 -0.09246798]
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  90.32258064516128 %
# Recall:  84.84848484848484 %
#
# Number of Iterations = 1499
# Minimum Cost (J) = 0.2476521591762488
# Weights of Model:  [-1.70207337 -0.12261246  0.42140398  0.31392489  0.10527253 -0.45932426
#   0.36804709 -0.1952074   0.18218301 -0.037857  ]
# Accuracy:  96.3302752293578 %
# Error Rate:  3.669724770642202 %
# Precision:  97.36842105263158 %
# Recall:  92.5 %
#
# average cross validation model accuracy = 93.94495412844037%
#
# Number of Iterations = 1999
# Minimum Cost (J) = 0.21490682402061062
# Weights of Model:  [-1.97893182 -0.17004253  0.47436199  0.20132341  0.16219388 -0.39950027
#   0.43111757 -0.25022266  0.27951505 -0.06827236]
# Accuracy:  91.74311926605505 %
# Error Rate:  8.256880733944955 %
# Precision:  89.74358974358975 %
# Recall:  87.5 %
#
# Number of Iterations = 1999
# Minimum Cost (J) = 0.2021864459694581
# Weights of Model:  [-1.99588709 -0.18011817  0.47802335  0.28591702  0.09910057 -0.52678093
#   0.48635047 -0.19142926  0.24847537  0.02951292]
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  90.0 %
# Recall:  90.0 %
#
# Number of Iterations = 1999
# Minimum Cost (J) = 0.22275391778407716
# Weights of Model:  [-1.96136099 -0.08232529  0.49790904  0.226602    0.12246959 -0.48141651
#   0.38477326 -0.24207081  0.25971477 -0.02837192]
# Accuracy:  97.24770642201835 %
# Error Rate:  2.7522935779816518 %
# Precision:  94.5945945945946 %
# Recall:  97.22222222222221 %
#
# Number of Iterations = 1999
# Minimum Cost (J) = 0.21163836797044508
# Weights of Model:  [-1.89746259 -0.17075927  0.47779751  0.32483324  0.16147558 -0.52392126
#   0.4627983  -0.24497049  0.23931568 -0.07005308]
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  90.32258064516128 %
# Recall:  84.84848484848484 %
#
# Number of Iterations = 1999
# Minimum Cost (J) = 0.22285786096305776
# Weights of Model:  [-2.04801416 -0.08492677  0.4136483   0.29972474  0.10511424 -0.43918645
#   0.36144742 -0.16096939  0.17537076 -0.01257026]
# Accuracy:  96.3302752293578 %
# Error Rate:  3.669724770642202 %
# Precision:  97.36842105263158 %
# Recall:  92.5 %
#
# average cross validation model accuracy = 94.12844036697247%
#
# Number of Iterations = 2499
# Minimum Cost (J) = 0.1974014960115492
# Weights of Model:  [-2.26859894 -0.13713212  0.46206111  0.18516325  0.16110271 -0.37490886
#   0.42504636 -0.21925235  0.27379825 -0.04991418]
# Accuracy:  93.57798165137615 %
# Error Rate:  6.422018348623854 %
# Precision:  94.5945945945946 %
# Recall:  87.5 %
# Number of Iterations = 2499
# Minimum Cost (J) = 0.18405267256712535
# Weights of Model:  [-2.29176257 -0.14824647  0.47301907  0.26833621  0.09438468 -0.51321793
#   0.48676821 -0.16376011  0.2492275   0.05480946]
# Accuracy:  93.57798165137615 %
# Error Rate:  6.422018348623854 %
# Precision:  92.3076923076923 %
# Recall:  90.0 %
#
# Number of Iterations = 2499
# Minimum Cost (J) = 0.20476881395916588
# Weights of Model:  [-2.25588693 -0.05256106  0.48691878  0.21987505  0.12369464 -0.46247708
#   0.37639627 -0.21106599  0.25505184 -0.00470238]
# Accuracy:  97.24770642201835 %
# Error Rate:  2.7522935779816518 %
# Precision:  94.5945945945946 %
# Recall:  97.22222222222221 %
#
# Number of Iterations = 2499
# Minimum Cost (J) = 0.19531811538517274
# Weights of Model:  [-2.17819385 -0.13990468  0.47161263  0.31430891  0.1594234  -0.50808707
#   0.45724685 -0.21719001  0.2342802  -0.04843294]
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  90.32258064516128 %
# Recall:  84.84848484848484 %
#
# Number of Iterations = 2499
# Minimum Cost (J) = 0.203759198234474
# Weights of Model:  [-2.34999586 -0.05268896  0.39641466  0.28646871  0.10449103 -0.41054131
#   0.35281116 -0.12742945  0.1676986   0.01079854]
# Accuracy:  96.3302752293578 %
# Error Rate:  3.669724770642202 %
# Precision:  97.36842105263158 %
# Recall:  92.5 %
#
# average cross validation model accuracy = 94.67889908256882%
#
# Number of Iterations = 2999
# Minimum Cost (J) = 0.18337215840085574
# Weights of Model:  [-2.5266839  -0.10808857  0.44306479  0.17348453  0.15898353 -0.34708144
#   0.41762883 -0.18798268  0.26739113 -0.03398781]
# Accuracy:  94.4954128440367 %
# Error Rate:  5.5045871559633035 %
# Precision:  94.73684210526315 %
# Recall:  90.0 %
#
# Number of Iterations = 2999
# Minimum Cost (J) = 0.16962803451736028
# Weights of Model:  [-2.55512437 -0.11963295  0.46085965  0.25419662  0.09012832 -0.49393996
#   0.48478327 -0.13730274  0.24917444  0.07489306]
# Accuracy:  93.57798165137615 %
# Error Rate:  6.422018348623854 %
# Precision:  92.3076923076923 %
# Recall:  90.0 %
#
# Number of Iterations = 2999
# Minimum Cost (J) = 0.1903463850240146
# Weights of Model:  [-2.51863738 -0.02629185  0.4674019   0.21733045  0.12475299 -0.44080648
#   0.36840071 -0.18123298  0.24977166  0.01648631]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  97.22222222222221 %
# Recall:  97.22222222222221 %
#
# Number of Iterations = 2999
# Minimum Cost (J) = 0.18216829559205003
# Weights of Model:  [-2.42897153 -0.11184372  0.45778055  0.30579085  0.15641289 -0.48668338
#   0.45010736 -0.18955452  0.22775472 -0.02843707]
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  90.32258064516128 %
# Recall:  84.84848484848484 %
#
# Number of Iterations = 2999
# Minimum Cost (J) = 0.1885997801426349
# Weights of Model:  [-2.61827847 -0.02483691  0.37549225  0.27627877  0.10433855 -0.38049906
#   0.3442335  -0.09661344  0.16066082  0.03142622]
# Accuracy:  97.24770642201835 %
# Error Rate:  2.7522935779816518 %
# Precision:  97.43589743589743 %
# Recall:  95.0 %
#
# average cross validation model accuracy = 95.22935779816514%
#
# Number of Iterations = 3499
# Minimum Cost (J) = 0.17186534964178013
# Weights of Model:  [-2.75972302 -0.08249641  0.42107824  0.16568178  0.15691111 -0.31898968
#   0.41014898 -0.15811786  0.26130683 -0.02027852]
# Accuracy:  95.41284403669725 %
# Error Rate:  4.587155963302752 %
# Precision:  94.87179487179486 %
# Recall:  92.5 %
#
# Number of Iterations = 3499
# Minimum Cost (J) = 0.1578834356681159
# Weights of Model:  [-2.79240632 -0.09398533  0.44502186  0.2435366   0.08696282 -0.47274066
#   0.48170359 -0.11288089  0.24892621  0.09119601]
# Accuracy:  93.57798165137615 %
# Error Rate:  6.422018348623854 %
# Precision:  92.3076923076923 %
# Recall:  90.0 %
#
# Number of Iterations = 3499
# Minimum Cost (J) = 0.17853475737697624
# Weights of Model:  [-2.75576921 -0.00295252  0.4437919   0.21821892  0.12608603 -0.41907333
#   0.36127979 -0.15380307  0.24489055  0.0354068 ]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  97.22222222222221 %
# Recall:  97.22222222222221 %
#
# Number of Iterations = 3499
# Minimum Cost (J) = 0.17133399125908655
# Weights of Model:  [-2.65578226 -0.08645148  0.43967901  0.3000172   0.15343437 -0.46357568
#   0.44265824 -0.16332628  0.22101965 -0.01014297]
# Accuracy:  93.57798165137615 %
# Error Rate:  6.422018348623854 %
# Precision:  90.625 %
# Recall:  87.87878787878788 %
#
# Number of Iterations = 3499
# Minimum Cost (J) = 0.17631084943235042
# Weights of Model:  [-2.85963241e+00 -4.98568994e-04  3.53729976e-01  2.69285326e-01
#   1.04833410e-01 -3.51968330e-01  3.36487326e-01 -6.88338505e-02
#   1.54581298e-01  4.94320848e-02]
# Accuracy:  97.24770642201835 %
# Error Rate:  2.7522935779816518 %
# Precision:  97.43589743589743 %
# Recall:  95.0 %
#
# average cross validation model accuracy = 95.59633027522936%
#
# Number of Iterations = 3999
# Minimum Cost (J) = 0.1622642120498286
# Weights of Model:  [-2.97227476 -0.05986177  0.3981826   0.16092261  0.15526755 -0.29200648
#   0.40317914 -0.13029224  0.25587613 -0.00838066]
# Accuracy:  95.41284403669725 %
# Error Rate:  4.587155963302752 %
# Precision:  94.87179487179486 %
# Recall:  92.5 %
#
# Number of Iterations = 3999
# Minimum Cost (J) = 0.14814824716442085
# Weights of Model:  [-3.00823273 -0.07093845  0.42753137  0.2358307   0.08492684 -0.45150629
#   0.47823035 -0.09058826  0.24867153  0.10488223]
# Accuracy:  93.57798165137615 %
# Error Rate:  6.422018348623854 %
# Precision:  92.3076923076923 %
# Recall:  90.0 %
#
# Number of Iterations = 3999
# Minimum Cost (J) = 0.16870662923732896
# Weights of Model:  [-2.97170561  0.01793627  0.41864877  0.2216128   0.12781898 -0.39845853
#   0.3551632  -0.12901793  0.24068119  0.05238884]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  97.22222222222221 %
# Recall:  97.22222222222221 %
#
# Number of Iterations = 3999
# Minimum Cost (J) = 0.16225824259143906
# Weights of Model:  [-2.86287814 -0.06348912  0.41942102  0.29685296  0.15085973 -0.44065534
#   0.43548551 -0.13891445  0.21462497  0.00664944]
# Accuracy:  93.57798165137615 %
# Error Rate:  6.422018348623854 %
# Precision:  90.625 %
# Recall:  87.87878787878788 %
#
# Number of Iterations = 3999
# Minimum Cost (J) = 0.16617618932188463
# Weights of Model:  [-3.07887719  0.02100403  0.33250301  0.26497249  0.10591969 -0.32596996
#   0.32977953 -0.04386127  0.14938767  0.06524925]
# Accuracy:  97.24770642201835 %
# Error Rate:  2.7522935779816518 %
# Precision:  97.43589743589743 %
# Recall:  95.0 %
#
# average cross validation model accuracy = 95.59633027522936%
#
# Number of Iterations = 4499
# Minimum Cost (J) = 0.1541419829578645
# Weights of Model:  [-3.16768352e+00 -3.97216192e-02  3.75526806e-01  1.58445272e-01
#   1.54148390e-01 -2.66716169e-01  3.96938852e-01 -1.04654937e-01
#   2.51154498e-01  2.10541947e-03]
# Accuracy:  95.41284403669725 %
# Error Rate:  4.587155963302752 %
# Precision:  94.87179487179486 %
# Recall:  92.5 %
#
# Number of Iterations = 4499
# Minimum Cost (J) = 0.13995923716157768
# Weights of Model:  [-3.20608348 -0.05014356  0.4095702   0.23047372  0.08386323 -0.43115361
#   0.47474416 -0.07025856  0.24845726  0.1167667 ]
# Accuracy:  93.57798165137615 %
# Error Rate:  6.422018348623854 %
# Precision:  92.3076923076923 %
# Recall:  90.0 %
#
# Number of Iterations = 4499
# Minimum Cost (J) = 0.1604221941834365
# Weights of Model:  [-3.16977934  0.03676773  0.39343068  0.22670487  0.1299596  -0.37943069
#   0.35001977 -0.10673403  0.23713999  0.06774996]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  97.22222222222221 %
# Recall:  97.22222222222221 %
#
# Number of Iterations = 4499
# Minimum Cost (J) = 0.1545526763624311
# Weights of Model:  [-3.05343189 -0.04268499  0.39833861  0.29587567  0.14879195 -0.41881811
#   0.42884891 -0.11637783  0.2087679   0.02219914]
# Accuracy:  93.57798165137615 %
# Error Rate:  6.422018348623854 %
# Precision:  90.625 %
# Recall:  87.87878787878788 %
#
# Number of Iterations = 4499
# Minimum Cost (J) = 0.15769359174325678
# Weights of Model:  [-3.27961708  0.04019527  0.31242839  0.26270326  0.10748593 -0.30268618
#   0.32408199 -0.02133173  0.14491273  0.07933262]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  100.0 %
# Recall:  95.0 %
#
# average cross validation model accuracy = 95.77981651376146%
# Number of Iterations = 4999
# Minimum Cost (J) = 0.1471907702080013
# Weights of Model:  [-3.34849658 -0.02167751  0.35371713  0.15763173  0.15353657 -0.24330546
#   0.39147366 -0.08113693  0.24709562  0.01151086]
# Accuracy:  95.41284403669725 %
# Error Rate:  4.587155963302752 %
# Precision:  94.87179487179486 %
# Recall:  92.5 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.13298408735645093
# Weights of Model:  [-3.38865801 -0.03129112  0.39181687  0.22692645  0.08357865 -0.41208718
#   0.47144344 -0.05165466  0.24828644  0.12738537]
# Accuracy:  93.57798165137615 %
# Error Rate:  6.422018348623854 %
# Precision:  92.3076923076923 %
# Recall:  90.0 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.1533610149151046
# Weights of Model:  [-3.35258543  0.05386139  0.36894127  0.23286772  0.13247204 -0.36210869
#   0.34575234 -0.08667839  0.2341755   0.08176001]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  97.22222222222221 %
# Recall:  97.22222222222221 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.14793546075333786
# Weights of Model:  [-3.22989065 -0.02377171  0.3772596   0.2966189   0.14722282 -0.39844613
#   0.42284506 -0.09563182  0.20348425  0.03673892]
# Accuracy:  93.57798165137615 %
# Error Rate:  6.422018348623854 %
# Precision:  90.625 %
# Recall:  87.87878787878788 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.15050126462495544
# Weights of Model:  [-3.46463918e+00  5.74824271e-02  2.93736243e-01  2.61909819e-01
#   1.09421849e-01 -2.81953569e-01  3.19282403e-01 -8.87811711e-04
#   1.40997669e-01  9.20592340e-02]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  100.0 %
# Recall:  95.0 %
#
# average cross validation model accuracy = 95.77981651376146%
#
# Number of Iterations = 5499
# Minimum Cost (J) = 0.14118193525080452
# Weights of Model:  [-3.51671046 -0.00539893  0.33304471  0.15800705  0.15337603 -0.22176308
#   0.38674759 -0.0595792   0.24362327  0.02008946]
# Accuracy:  95.41284403669725 %
# Error Rate:  4.587155963302752 %
# Precision:  94.87179487179486 %
# Recall:  92.5 %
#
# Number of Iterations = 5499
# Minimum Cost (J) = 0.1269777870682165
# Weights of Model:  [-3.55809695 -0.01411294  0.37464678  0.22474661  0.08389822 -0.39443907
#   0.46842164 -0.03454193  0.24815106  0.13708265]
# Accuracy:  93.57798165137615 %
# Error Rate:  6.422018348623854 %
# Precision:  92.3076923076923 %
# Recall:  90.0 %
#
# Number of Iterations = 5499
# Minimum Cost (J) = 0.14728342957904778
# Weights of Model:  [-3.52219323  0.06947751  0.34559518  0.23964012  0.13530478 -0.3464434
#   0.34224448 -0.06855659  0.23168147  0.09463743]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  97.22222222222221 %
# Recall:  97.22222222222221 %
#
# Number of Iterations = 5499
# Minimum Cost (J) = 0.14219645731118546
# Weights of Model:  [-3.39418793 -0.00650396  0.3566834   0.29866318  0.14610372 -0.37965496
#   0.4174871  -0.07653821  0.19874245  0.05045289]
# Accuracy:  93.57798165137615 %
# Error Rate:  6.422018348623854 %
# Precision:  90.625 %
# Recall:  87.87878787878788 %
#
# Number of Iterations = 5499
# Minimum Cost (J) = 0.1443331304900486
# Weights of Model:  [-3.63615061  0.07318425  0.2764641   0.26214303  0.11163373 -0.26349153
#   0.31525029  0.0177798   0.13751753  0.10371482]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  100.0 %
# Recall:  95.0 %
#
# average cross validation model accuracy = 95.77981651376146%
#
# Number of Iterations = 5999
# Minimum Cost (J) = 0.13594196538768208
# Weights of Model:  [-3.67392567  0.00938437  0.31362004  0.15921684  0.15360194 -0.20198454
#   0.38269088 -0.03979448  0.2406592   0.02802815]
# Accuracy:  95.41284403669725 %
# Error Rate:  4.587155963302752 %
# Precision:  94.87179487179486 %
# Recall:  92.5 %
#
# Number of Iterations = 5999
# Minimum Cost (J) = 0.12175582071000399
# Weights of Model:  [-3.71612739e+00  1.62092130e-03  3.58253059e-01  2.23583905e-01
#   8.46787445e-02 -3.78199641e-01  4.65712739e-01 -1.87127563e-02
#   2.48042253e-01  1.46079661e-01]
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  92.10526315789474 %
# Recall:  87.5 %
#
# Number of Iterations = 5999
# Minimum Cost (J) = 0.14200666564737813
# Weights of Model:  [-3.68028314  0.08382934  0.32357754  0.24669512  0.13840229 -0.33231132
#   0.33938224 -0.05209561  0.22956253  0.10655595]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  97.22222222222221 %
# Recall:  97.22222222222221 %
#
# Number of Iterations = 5999
# Minimum Cost (J) = 0.13717571320540006
# Weights of Model:  [-3.54788023  0.00933475  0.33689648  0.3016614   0.14537621 -0.36242394
#   0.41274637 -0.058945    0.19448776  0.06347871]
# Accuracy:  94.4954128440367 %
# Error Rate:  5.5045871559633035 %
# Precision:  93.54838709677419 %
# Recall:  87.87878787878788 %
#
# Number of Iterations = 5999
# Minimum Cost (J) = 0.138989942790319
# Weights of Model:  [-3.79593072  0.08755247  0.26055799  0.26306768  0.11404602 -0.24700294
#   0.31186328  0.03492716  0.13438045  0.11450901]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  100.0 %
# Recall:  95.0 %
#
# average cross validation model accuracy = 95.77981651376146%
#
# Number of Iterations = 6499
# Minimum Cost (J) = 0.1313368527064781
# Weights of Model:  [-3.82144869  0.02289268  0.29545245  0.16100125  0.15415246 -0.18382734
#   0.37922403 -0.02159619  0.23813266  0.03546199]
# Accuracy:  95.41284403669725 %
# Error Rate:  4.587155963302752 %
# Precision:  94.87179487179486 %
# Recall:  92.5 %
#
# Number of Iterations = 6499
# Minimum Cost (J) = 0.11717678796727991
# Weights of Model:  [-3.86416271  0.0161064   0.34272024  0.22316579  0.08580748 -0.36329008
#   0.46331818 -0.00399152  0.24795302  0.15452025]
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  92.10526315789474 %
# Recall:  87.5 %
#
# Number of Iterations = 6499
# Minimum Cost (J) = 0.1373891445335587
# Weights of Model:  [-3.82823948  0.09709246  0.30294004  0.25380786  0.14171068 -0.31956272
#   0.33706316 -0.0370577   0.22774085  0.11765343]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  97.22222222222221 %
# Recall:  97.22222222222221 %
#
# Number of Iterations = 6499
# Minimum Cost (J) = 0.1327493972736852
# Weights of Model:  [-3.69223987  0.0239314   0.31804866  0.30533806  0.14498412 -0.34666621
#   0.40857491 -0.04270381  0.19066173  0.07591697]
# Accuracy:  94.4954128440367 %
# Error Rate:  5.5045871559633035 %
# Precision:  93.54838709677419 %
# Recall:  87.87878787878788 %
#
# Number of Iterations = 6499
# Minimum Cost (J) = 0.134320024913123
# Weights of Model:  [-3.94543466  0.10078783  0.24592436  0.2644415   0.11659917 -0.23221427
#   0.30901539  0.05076342  0.13152029  0.12459513]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  100.0 %
# Recall:  95.0 %
#
# average cross validation model accuracy = 95.77981651376146%
#
# Number of Iterations = 6999
# Minimum Cost (J) = 0.1272615459720964
# Weights of Model:  [-3.96036202  0.035306    0.27849691  0.16317192  0.15497263 -0.16713947
#   0.3762693  -0.00481093  0.23598259  0.04248796]
# Accuracy:  95.41284403669725 %
# Error Rate:  4.587155963302752 %
# Precision:  94.87179487179486 %
# Recall:  92.5 %
#
# Number of Iterations = 6999
# Minimum Cost (J) = 0.11313069730016335
# Weights of Model:  [-4.00337368  0.02950967  0.32806923  0.22328245  0.08719698 -0.34960239
#   0.46122267  0.00976782  0.24787857  0.16250037]
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  92.10526315789474 %
# Recall:  87.5 %
#
# Number of Iterations = 6999
# Minimum Cost (J) = 0.13331973765501773
# Weights of Model:  [-3.96721636  0.10941219  0.283659    0.26082846  0.14518054 -0.30804574
#   0.33519889 -0.02324196  0.22615568  0.12804003]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  97.22222222222221 %
# Recall:  97.22222222222221 %
#
# Number of Iterations = 6999
# Minimum Cost (J) = 0.12882024050510724
# Weights of Model:  [-3.82832042  0.03744556  0.30020334  0.30947948  0.14487759 -0.33226656
#   0.40491782 -0.02767701  0.18720996  0.08784107]
# Accuracy:  95.41284403669725 %
# Error Rate:  4.587155963302752 %
# Precision:  96.66666666666667 %
# Recall:  87.87878787878788 %
#
# Number of Iterations = 6999
# Minimum Cost (J) = 0.13020615185773404
# Weights of Model:  [-4.08586674  0.1130519   0.23245642  0.26609275  0.1192467  -0.21888791
#   0.30661799  0.06545959  0.1288894   0.13408671]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  100.0 %
# Recall:  95.0 %
#
# average cross validation model accuracy = 95.96330275229357%
# Number of Iterations = 7499
# Minimum Cost (J) = 0.12363260953950285
# Weights of Model:  [-4.09157389  0.04677222  0.26268137  0.16559329  0.15601515 -0.15177352
#   0.37375565  0.0107171   0.23415717  0.04917593]
# Accuracy:  95.41284403669725 %
# Error Rate:  4.587155963302752 %
# Precision:  94.87179487179486 %
# Recall:  92.5 %
#
# Number of Iterations = 7499
# Minimum Cost (J) = 0.1095308510858677
# Weights of Model:  [-4.13474038  0.04197132  0.31428471  0.22377354  0.08877976 -0.33702095
#   0.45940325  0.02268611  0.2478159   0.17008618]
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  92.10526315789474 %
# Recall:  87.5 %
#
# Number of Iterations = 7499
# Minimum Cost (J) = 0.12971019597930075
# Weights of Model:  [-4.09818567  0.12090925  0.2656703   0.26766075  0.14876835 -0.29761781
#   0.33371493 -0.01048088  0.22476059  0.13780477]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  97.22222222222221 %
# Recall:  97.22222222222221 %
#
# Number of Iterations = 7499
# Minimum Cost (J) = 0.12531085211033463
# Weights of Model:  [-3.95700428  0.05001267  0.28337019  0.31392236  0.14501368 -0.31910165
#   0.40171972 -0.01374007  0.18408463  0.09930527]
# Accuracy:  96.3302752293578 %
# Error Rate:  3.669724770642202 %
# Precision:  96.7741935483871 %
# Recall:  90.9090909090909 %
#
# Number of Iterations = 7499
# Minimum Cost (J) = 0.1265564556014595
# Weights of Model:  [-4.21823416  0.12447597  0.22004699  0.26790125  0.12195258 -0.2068228
#   0.30459795  0.07915645  0.1264529   0.14306949]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  100.0 %
# Recall:  95.0 %
#
# average cross validation model accuracy = 96.14678899082568%
#
# Number of Iterations = 7999
# Minimum Cost (J) = 0.12038299541369632
# Weights of Model:  [-4.21585452  0.05741362  0.24792259  0.1681684   0.1572399  -0.13759303
#   0.37162036  0.02512557  0.23261256  0.05557673]
# Accuracy:  95.41284403669725 %
# Error Rate:  4.587155963302752 %
# Precision:  94.87179487179486 %
# Recall:  92.5 %
#
# Number of Iterations = 7999
# Minimum Cost (J) = 0.10630809364264894
# Weights of Model:  [-4.25909099  0.0536101   0.30133168  0.22451732  0.0905037  -0.3254336
#   0.45783439  0.03486362  0.24776342  0.17732525]
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  92.10526315789474 %
# Recall:  87.5 %
#
# Number of Iterations = 7999
# Minimum Cost (J) = 0.12648969937867693
# Weights of Model:  [-4.22197314e+00  1.31684414e-01  2.48890244e-01  2.74246476e-01
#   1.52436781e-01 -2.88150255e-01  3.32549126e-01  1.36443773e-03
#   2.23520430e-01  1.47020559e-01]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  97.22222222222221 %
# Recall:  97.22222222222221 %
#
# Number of Iterations = 7999
# Minimum Cost (J) = 0.12215894243063982
# Weights of Model:  [-4.07903793e+00  6.17475247e-02  2.67526482e-01  3.18543111e-01
#   1.45355844e-01 -3.07050645e-01  3.98928139e-01 -7.81656748e-04
#   1.81244744e-01  1.10350720e-01]
# Accuracy:  96.3302752293578 %
# Error Rate:  3.669724770642202 %
# Precision:  96.7741935483871 %
# Recall:  90.9090909090909 %
#
# Number of Iterations = 7999
# Minimum Cost (J) = 0.12329801547624711
# Weights of Model:  [-4.34338707  0.13516765  0.20859461  0.26978381  0.12468896 -0.19585051
#   0.30289523  0.09197098  0.12418473  0.15160983]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  100.0 %
# Recall:  95.0 %
#
# average cross validation model accuracy = 96.14678899082568%
#
# Number of Iterations = 8499
# Minimum Cost (J) = 0.11745825042769523
# Weights of Model:  [-4.33386326  0.06733207  0.23413501  0.17082822  0.15861306 -0.12447481
#   0.36980917  0.03853508  0.23131163  0.06172788]
# Accuracy:  95.41284403669725 %
# Error Rate:  4.587155963302752 %
# Precision:  94.87179487179486 %
# Recall:  92.5 %
#
# Number of Iterations = 8499
# Minimum Cost (J) = 0.10340665953735177
# Weights of Model:  [-4.37713116  0.06452639  0.28916537  0.22542185  0.09232844 -0.31473678
#   0.45649066  0.04638396  0.24772045  0.1842533 ]
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  92.10526315789474 %
# Recall:  87.5 %
#
# Number of Iterations = 8499
# Minimum Cost (J) = 0.12360086483112755
# Weights of Model:  [-4.33928579  0.14182216  0.23322788  0.28055358  0.15615454 -0.27952944
#   0.33164994  0.01240922  0.22240862  0.15574796]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  97.22222222222221 %
# Recall:  97.22222222222221 %
#
# Number of Iterations = 8499
# Minimum Cost (J) = 0.11931384694674424
# Weights of Model:  [-4.19505864  0.07274748  0.25263081  0.32324902  0.14587304 -0.2960003
#   0.396495    0.01129704  0.17865547  0.12100969]
# Accuracy:  97.24770642201835 %
# Error Rate:  2.7522935779816518 %
# Precision:  96.875 %
# Recall:  93.93939393939394 %
#
# Number of Iterations = 8499
# Minimum Cost (J) = 0.1203722697981531
# Weights of Model:  [-4.46204916  0.14521591  0.19800598  0.27168354  0.12743446 -0.18583029
#   0.30146046  0.10400133  0.12206482  0.15976023]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  100.0 %
# Recall:  95.0 %
#
# average cross validation model accuracy = 96.3302752293578%
#
# Number of Iterations = 8999
# Minimum Cost (J) = 0.11481372087237444
# Weights of Model:  [-4.44616917  0.07661297  0.22123565  0.17352387  0.16010621 -0.1123091
#   0.36827559  0.05105093  0.23022276  0.06765767]
# Accuracy:  95.41284403669725 %
# Error Rate:  4.587155963302752 %
# Precision:  94.87179487179486 %
# Recall:  92.5 %
#
# Number of Iterations = 8999
# Minimum Cost (J) = 0.100781130374211
# Weights of Model:  [-4.48946672  0.07480517  0.27773715  0.22641816  0.09422268 -0.30483747
#   0.45534811  0.0573173   0.24768695  0.19089844]
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  92.10526315789474 %
# Recall:  87.5 %
#
# Number of Iterations = 8999
# Minimum Cost (J) = 0.12099678132493247
# Weights of Model:  [-4.45073329  0.15139367  0.21859207  0.2865679   0.15989585 -0.27165621
#   0.33097468  0.02274931  0.221405    0.16403791]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  97.22222222222221 %
# Recall:  97.22222222222221 %
#
# Number of Iterations = 8999
# Minimum Cost (J) = 0.11673395819298435
# Weights of Model:  [-4.30561487  0.08309529  0.23863183  0.32797114  0.14653884 -0.28584716
#   0.39437711  0.02258353  0.1762873   0.13130851]
# Accuracy:  97.24770642201835 %
# Error Rate:  2.7522935779816518 %
# Precision:  96.875 %
# Recall:  93.93939393939394 %
#
# Number of Iterations = 8999
# Minimum Cost (J) = 0.11773168222341092
# Weights of Model:  [-4.57484122  0.15469491  0.18819666  0.27356208  0.13017271 -0.17664415
#   0.30025294  0.1153306   0.12007732  0.16756321]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  100.0 %
# Recall:  95.0 %
#
# average cross validation model accuracy = 96.3302752293578%
#
# Number of Iterations = 9499
# Minimum Cost (J) = 0.11241246345318152
# Weights of Model:  [-4.55326704  0.08532843  0.20914656  0.17622101  0.1616955  -0.10099888
#   0.36698002  0.062765    0.22931893  0.07338787]
# Accuracy:  95.41284403669725 %
# Error Rate:  4.587155963302752 %
# Precision:  94.87179487179486 %
# Recall:  92.5 %
#
# Number of Iterations = 9499
# Minimum Cost (J) = 0.09839417351453464
# Weights of Model:  [-4.59662133  0.08451855  0.26699787  0.22745484  0.09616208 -0.29565333
#   0.45438485  0.067723    0.24766328  0.19728369]
# Accuracy:  91.74311926605505 %
# Error Rate:  8.256880733944955 %
# Precision:  89.74358974358975 %
# Recall:  87.5 %
#
# Number of Iterations = 9499
# Minimum Cost (J) = 0.11863878018960325
# Weights of Model:  [-4.55684472  0.16045922  0.20489543  0.29228717  0.16363982 -0.26444465
#   0.33048797  0.03246487  0.2204941   0.17193376]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  97.22222222222221 %
# Recall:  97.22222222222221 %
#
# Number of Iterations = 9499
# Minimum Cost (J) = 0.11438480286540442
# Weights of Model:  [-4.41118224  0.09286156  0.22547381  0.33265871  0.14733064 -0.27649808
#   0.39253615  0.03315516  0.17411515  0.14126951]
# Accuracy:  97.24770642201835 %
# Error Rate:  2.7522935779816518 %
# Precision:  96.875 %
# Recall:  93.93939393939394 %
#
# Number of Iterations = 9499
# Minimum Cost (J) = 0.11533728559151463
# Weights of Model:  [-4.68229952  0.16366692  0.17909094  0.27539412  0.13289129 -0.16819277
#   0.29923894  0.12602977  0.11820934  0.17505384]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  100.0 %
# Recall:  95.0 %
#
# average cross validation model accuracy = 96.14678899082568%
# Number of Iterations = 9999
# Minimum Cost (J) = 0.11022366439813232
# Weights of Model:  [-4.65558989  0.09353973  0.19779595  0.1788957   0.1633609  -0.0904586
#   0.36588882  0.07375755  0.22857692  0.07893567]
# Accuracy:  95.41284403669725 %
# Error Rate:  4.587155963302752 %
# Precision:  92.6829268292683 %
# Recall:  95.0 %
#
# Number of Iterations = 9999
# Minimum Cost (J) = 0.09621484094827804
# Weights of Model:  [-4.69905052  0.09372797  0.25689978  0.22849396  0.09812766 -0.28711207
#   0.45358123  0.07765164  0.24765     0.20342855]
# Accuracy:  91.74311926605505 %
# Error Rate:  8.256880733944955 %
# Precision:  89.74358974358975 %
# Recall:  87.5 %
#
# Number of Iterations = 9999
# Minimum Cost (J) = 0.11649473993954064
# Weights of Model:  [-4.65808194  0.16907014  0.19205624  0.29771692  0.16736968 -0.25782042
#   0.33016044  0.04162333  0.21966397  0.17947281]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  97.22222222222221 %
# Recall:  97.22222222222221 %
#
# Number of Iterations = 9999
# Minimum Cost (J) = 0.1122375845341735
# Weights of Model:  [-4.51217602  0.10210671  0.2131001   0.33727491  0.14822907 -0.26786998
#   0.39093837  0.04308033  0.17211762  0.15091225]
# Accuracy:  97.24770642201835 %
# Error Rate:  2.7522935779816518 %
# Precision:  96.875 %
# Recall:  93.93939393939394 %
#
# Number of Iterations = 9999
# Minimum Cost (J) = 0.11315684833354785
# Weights of Model:  [-4.78489037  0.17218465  0.1706212   0.27716353  0.13558087 -0.16039201
#   0.29839037  0.13615991  0.11645014  0.18226157]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  100.0 %
# Recall:  95.0 %
#
# average cross validation model accuracy = 96.14678899082568%
#
# Number of Iterations = 10499
# Minimum Cost (J) = 0.10822142927448475
# Weights of Model:  [-4.75351895  0.10129926  0.18711844  0.18153152  0.16508561 -0.08061297
#   0.36497341  0.0840988   0.22797671  0.084315  ]
# Accuracy:  95.41284403669725 %
# Error Rate:  4.587155963302752 %
# Precision:  92.6829268292683 %
# Recall:  95.0 %
#
# Number of Iterations = 10499
# Minimum Cost (J) = 0.09421727492953541
# Weights of Model:  [-4.7971528   0.10248595  0.2473975   0.22950782  0.10010465 -0.27915045
#   0.45291974  0.08714665  0.24764777  0.20935002]
# Accuracy:  91.74311926605505 %
# Error Rate:  8.256880733944955 %
# Precision:  89.74358974358975 %
# Recall:  87.5 %
#
# Number of Iterations = 10499
# Minimum Cost (J) = 0.11453778450204215
# Weights of Model:  [-4.7548503   0.17727039  0.17999935  0.30286748  0.17107223 -0.25171927
#   0.32996764  0.05028183  0.21890516  0.18668737]
# Accuracy:  99.08256880733946 %
# Error Rate:  0.9174311926605505 %
# Precision:  97.2972972972973 %
# Recall:  100.0 %
#
# Number of Iterations = 10499
# Minimum Cost (J) = 0.11026806689264894
# Weights of Model:  [-4.60896101  0.11088269  0.20145524  0.34179348  0.14921748 -0.25988909
#   0.38955418  0.05241955  0.17027633  0.16025439]
# Accuracy:  97.24770642201835 %
# Error Rate:  2.7522935779816518 %
# Precision:  96.875 %
# Recall:  93.93939393939394 %
#
# Number of Iterations = 10499
# Minimum Cost (J) = 0.11116348868622795
# Weights of Model:  [-4.88302167  0.180293    0.16272723  0.27886061  0.13823449 -0.15317016
#   0.29768374  0.14577393  0.11479057  0.18921147]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  100.0 %
# Recall:  95.0 %
#
# average cross validation model accuracy = 96.3302752293578%
#
# Number of Iterations = 19999
# Minimum Cost (J) = 0.08844465389406335
# Weights of Model:  [-6.07866865  0.19967662  0.05976355  0.22044753  0.19889599  0.03091282
#   0.36239126  0.20902056  0.22943757  0.16430928]
# Accuracy:  94.4954128440367 %
# Error Rate:  5.5045871559633035 %
# Precision:  92.5 %
# Recall:  92.5 %
#
# Number of Iterations = 19999
# Minimum Cost (J) = 0.07393529514710306
# Weights of Model:  [-6.14405956  0.2195929   0.13879928  0.23582051  0.13316771 -0.19145262
#   0.45428272  0.21665065  0.25013895  0.2936514 ]
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  92.10526315789474 %
# Recall:  87.5 %
#
# Number of Iterations = 19999
# Minimum Cost (J) = 0.09536867164773999
# Weights of Model:  [-6.05756267  0.28624124  0.03824458  0.36525223  0.23079805 -0.18971537
#   0.33671291  0.15937057  0.21237166  0.28633658]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  94.73684210526315 %
# Recall:  100.0 %
#
# Number of Iterations = 19999
# Minimum Cost (J) = 0.09042521253660782
# Weights of Model:  [-5.93344525  0.22529066  0.06626215  0.40362574  0.17372888 -0.17578205
#   0.38278634  0.16481801  0.15184486  0.29756165]
# Accuracy:  97.24770642201835 %
# Error Rate:  2.7522935779816518 %
# Precision:  96.875 %
# Recall:  93.93939393939394 %
#
# Number of Iterations = 19999
# Minimum Cost (J) = 0.09137267984847976
# Weights of Model:  [-6.21308157  0.28808346  0.07554644  0.29830841  0.17980209 -0.07593303
#   0.29625337  0.26952552  0.09515355  0.29054526]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  100.0 %
# Recall:  95.0 %
#
# average cross validation model accuracy = 96.14678899082568%
# Text(0, 0.5, 'Model Accuracy (%)')

# %%
#Adjust size of datasets and compare accuracy
#Compare 5 different sizes

length = int(len(x_train))
length90 = int(length*0.9)
length75 = int(length*0.75)
length50 = int(length*0.5)
length25 = int(length*0.25)
length10 = int(length*0.1)

x_train_reduced = [x_train[:length90,:], x_train[:length75,:], x_train[:length50,:], x_train[:length25,:], x_train[:length10,:]] 
y_train_reduced = [y_train[:length90], y_train[:length75], y_train[:length50], y_train[:length25], y_train[:length10]]
percentage_of_original = [100, 90, 75, 50, 25]
lr_accuracy = []
nb_accuracy = []

lr_average_cross_validation_accuracy = cross_validation_LR(Model_Logistic_Regression, x_train, y_train, K = 5, num_steps = 5000, learning_rate = 0.01, min_error = 1e-2, random_shuffle = False)
nb_average_cross_validation_accuracy = cross_validation_NB(Model_Naive_Bayes, x_train, y_train, K = 5, random_shuffle = False)
lr_accuracy.append(lr_average_cross_validation_accuracy)
nb_accuracy.append(nb_average_cross_validation_accuracy)


lr_average_cross_validation_accuracy = cross_validation_LR(Model_Logistic_Regression, x_train[:length90,:], y_train[:length90], K = 5, num_steps = 5000, learning_rate = 0.01, min_error = 1e-2, random_shuffle = False)
nb_average_cross_validation_accuracy = cross_validation_NB(Model_Naive_Bayes, x_train[:length90,:], y_train[:length90], K = 5, random_shuffle = False)
lr_accuracy.append(lr_average_cross_validation_accuracy)
nb_accuracy.append(nb_average_cross_validation_accuracy)

lr_average_cross_validation_accuracy = cross_validation_LR(Model_Logistic_Regression, x_train[:length75,:], y_train[:length75], K = 5, num_steps = 5000, learning_rate = 0.01, min_error = 1e-2, random_shuffle = False)
nb_average_cross_validation_accuracy = cross_validation_NB(Model_Naive_Bayes, x_train[:length75,:], y_train[:length75], K = 5, random_shuffle = False)
lr_accuracy.append(lr_average_cross_validation_accuracy)
nb_accuracy.append(nb_average_cross_validation_accuracy)

lr_average_cross_validation_accuracy = cross_validation_LR(Model_Logistic_Regression, x_train[:length50,:], y_train[:length50], K = 5, num_steps = 5000, learning_rate = 0.01, min_error = 1e-2, random_shuffle = False)
nb_average_cross_validation_accuracy = cross_validation_NB(Model_Naive_Bayes, x_train[:length50,:], y_train[:length50], K = 5, random_shuffle = False)
lr_accuracy.append(lr_average_cross_validation_accuracy)
nb_accuracy.append(nb_average_cross_validation_accuracy)

lr_average_cross_validation_accuracy = cross_validation_LR(Model_Logistic_Regression, x_train[:length25,:], y_train[:length25], K = 5, num_steps = 5000, learning_rate = 0.01, min_error = 1e-2, random_shuffle = False)
nb_average_cross_validation_accuracy = cross_validation_NB(Model_Naive_Bayes, x_train[:length25,:], y_train[:length25], K = 5, random_shuffle = False)
lr_accuracy.append(lr_average_cross_validation_accuracy)
nb_accuracy.append(nb_average_cross_validation_accuracy)

#lr_average_cross_validation_accuracy = cross_validation_LR(Model_Logistic_Regression, x_train[:length10,:], y_train[:length10], K = 5, num_steps = 5000, learning_rate = 0.01, min_error = 1e-2, random_shuffle = False)
#nb_average_cross_validation_accuracy = cross_validation_NB(Model_Naive_Bayes, x_train[:length10,:], y_train[:length10], K = 5, random_shuffle = False)
#lr_accuracy.append(lr_average_cross_validation_accuracy)
#nb_accuracy.append(nb_average_cross_validation_accuracy)
        

#Plot
plt.plot(percentage_of_original, lr_accuracy)
plt.plot(percentage_of_original, nb_accuracy)
plt.title("Dataset Size vs Model Accuracy (Breast Cancer)")
plt.xlabel("Percent of Original Size (%)")
plt.ylabel("Model Accuracy (%)")
plt.legend(["Logistic Regression", "Naive Bayes"])
# Out:
# Number of Iterations = 4999
# Minimum Cost (J) = 0.1471907702080013
# Weights of Model:  [-3.34849658 -0.02167751  0.35371713  0.15763173  0.15353657 -0.24330546
#   0.39147366 -0.08113693  0.24709562  0.01151086]
# Accuracy:  95.41284403669725 %
# Error Rate:  4.587155963302752 %
# Precision:  94.87179487179486 %
# Recall:  92.5 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.13298408735645093
# Weights of Model:  [-3.38865801 -0.03129112  0.39181687  0.22692645  0.08357865 -0.41208718
#   0.47144344 -0.05165466  0.24828644  0.12738537]
# Accuracy:  93.57798165137615 %
# Error Rate:  6.422018348623854 %
# Precision:  92.3076923076923 %
# Recall:  90.0 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.1533610149151046
# Weights of Model:  [-3.35258543  0.05386139  0.36894127  0.23286772  0.13247204 -0.36210869
#   0.34575234 -0.08667839  0.2341755   0.08176001]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  97.22222222222221 %
# Recall:  97.22222222222221 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.14793546075333786
# Weights of Model:  [-3.22989065 -0.02377171  0.3772596   0.2966189   0.14722282 -0.39844613
#   0.42284506 -0.09563182  0.20348425  0.03673892]
# Accuracy:  93.57798165137615 %
# Error Rate:  6.422018348623854 %
# Precision:  90.625 %
# Recall:  87.87878787878788 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.15050126462495544
# Weights of Model:  [-3.46463918e+00  5.74824271e-02  2.93736243e-01  2.61909819e-01
#   1.09421849e-01 -2.81953569e-01  3.19282403e-01 -8.87811711e-04
#   1.40997669e-01  9.20592340e-02]
# Accuracy:  98.1651376146789 %
# Error Rate:  1.834862385321101 %
# Precision:  100.0 %
# Recall:  95.0 %
#
# average cross validation model accuracy = 95.77981651376146%
#
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  94.44444444444444 %
# Recall:  85.0 %
#
# Accuracy:  81.65137614678899 %
# Error Rate:  18.34862385321101 %
# Precision:  91.66666666666666 %
# Recall:  55.00000000000001 %
#
# Accuracy:  84.40366972477065 %
# Error Rate:  15.59633027522936 %
# Precision:  100.0 %
# Recall:  52.77777777777778 %
#
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  96.29629629629629 %
# Recall:  78.78787878787878 %
#
# Accuracy:  92.66055045871559 %
# Error Rate:  7.339449541284404 %
# Precision:  100.0 %
# Recall:  80.0 %
#
# average cross validation model accuracy = 88.80733944954129%
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.15001734482246248
# Weights of Model:  [-3.36765238  0.01898618  0.39106062  0.12550503  0.12979428 -0.23383105
#   0.35998148 -0.10175884  0.2138981   0.08119017]
# Accuracy:  96.93877551020408 %
# Error Rate:  3.061224489795918 %
# Precision:  94.44444444444444 %
# Recall:  97.14285714285714 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.1375238219504405
# Weights of Model:  [-3.34660495 -0.05747943  0.48607668  0.19452333  0.06093594 -0.32532691
#   0.42126093 -0.0783944   0.1679989   0.11411899]
# Accuracy:  89.79591836734694 %
# Error Rate:  10.204081632653061 %
# Precision:  93.75 %
# Recall:  78.94736842105263 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.1461706558887609
# Weights of Model:  [-3.4204871   0.05539934  0.37269293  0.23042786  0.1218862  -0.36694181
#   0.31590006 -0.02150417  0.25830566  0.08684498]
# Accuracy:  97.95918367346938 %
# Error Rate:  2.0408163265306123 %
# Precision:  93.93939393939394 %
# Recall:  100.0 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.1549202369811214
# Weights of Model:  [-3.38331329  0.06203312  0.33880158  0.22433562  0.08378569 -0.36522569
#   0.34358161 -0.03366521  0.1734565   0.17899815]
# Accuracy:  96.93877551020408 %
# Error Rate:  3.061224489795918 %
# Precision:  96.96969696969697 %
# Recall:  94.11764705882352 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.14582873225536552
# Weights of Model:  [-3.36998632  0.01591493  0.321036    0.34140453  0.15535271 -0.27805746
#   0.33592554 -0.04677151  0.11471525 -0.03233158]
# Accuracy:  94.89795918367348 %
# Error Rate:  5.1020408163265305 %
# Precision:  96.15384615384616 %
# Recall:  86.20689655172413 %
#
# average cross validation model accuracy = 95.30612244897961%
#
# Accuracy:  91.83673469387756 %
# Error Rate:  8.16326530612245 %
# Precision:  90.9090909090909 %
# Recall:  85.71428571428571 %
#
# Accuracy:  83.6734693877551 %
# Error Rate:  16.3265306122449 %
# Precision:  95.83333333333334 %
# Recall:  60.526315789473685 %
#
# Accuracy:  82.6530612244898 %
# Error Rate:  17.346938775510203 %
# Precision:  88.88888888888889 %
# Recall:  51.61290322580645 %
#
# Accuracy:  93.87755102040816 %
# Error Rate:  6.122448979591836 %
# Precision:  100.0 %
# Recall:  82.35294117647058 %
#
# Accuracy:  92.85714285714286 %
# Error Rate:  7.142857142857142 %
# Precision:  95.83333333333334 %
# Recall:  79.3103448275862 %
#
# average cross validation model accuracy = 88.9795918367347%
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.1625542676368206
# Weights of Model:  [-3.42827046e+00  5.63144226e-02  2.13985989e-01  2.46875233e-01
#   1.46657533e-01 -1.82270002e-01  3.12328066e-01  5.00301020e-04
#   1.14492449e-01  1.98441351e-02]
# Accuracy:  98.76543209876543 %
# Error Rate:  1.2345679012345678 %
# Precision:  96.29629629629629 %
# Recall:  100.0 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.13228832043895675
# Weights of Model:  [-3.39349898 -0.13718167  0.35846804  0.41570738  0.16635982 -0.1870763
#   0.35076695 -0.09649987  0.13771333 -0.11731543]
# Accuracy:  87.65432098765432 %
# Error Rate:  12.345679012345679 %
# Precision:  90.32258064516128 %
# Recall:  80.0 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.15108772111670168
# Weights of Model:  [-3.4106662   0.02742614  0.06610126  0.39777233  0.15329549 -0.29712345
#   0.32612326  0.11075205  0.14818769  0.00597917]
# Accuracy:  95.06172839506173 %
# Error Rate:  4.938271604938271 %
# Precision:  90.32258064516128 %
# Recall:  96.55172413793103 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.1577957467426742
# Weights of Model:  [-3.4400075   0.0942794   0.24829093  0.33916261  0.1552087  -0.29001826
#   0.26937903  0.00696824  0.12331396 -0.01218053]
# Accuracy:  97.53086419753086 %
# Error Rate:  2.4691358024691357 %
# Precision:  95.83333333333334 %
# Recall:  95.83333333333334 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.1520883158987262
# Weights of Model:  [-3.34392871  0.04367956  0.2790818   0.36734441  0.11558326 -0.34706503
#   0.35131099 -0.01276517  0.10334673  0.02639278]
# Accuracy:  96.29629629629629 %
# Error Rate:  3.7037037037037033 %
# Precision:  96.15384615384616 %
# Recall:  92.5925925925926 %
#
# average cross validation model accuracy = 95.06172839506173%
#
# Accuracy:  92.5925925925926 %
# Error Rate:  7.4074074074074066 %
# Precision:  95.45454545454545 %
# Recall:  80.76923076923077 %
#
# Accuracy:  80.24691358024691 %
# Error Rate:  19.753086419753085 %
# Precision:  91.30434782608695 %
# Recall:  60.0 %
#
# Accuracy:  82.71604938271605 %
# Error Rate:  17.28395061728395 %
# Precision:  89.47368421052632 %
# Recall:  58.620689655172406 %
#
# Accuracy:  83.9506172839506 %
# Error Rate:  16.049382716049383 %
# Precision:  100.0 %
# Recall:  45.83333333333333 %
#
# Accuracy:  91.35802469135803 %
# Error Rate:  8.641975308641975 %
# Precision:  95.45454545454545 %
# Recall:  77.77777777777779 %
#
# average cross validation model accuracy = 86.17283950617283%
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.16281572076531173
# Weights of Model:  [-3.30376185  0.19350064  0.49401065  0.27292976  0.08802494 -0.45649342
#   0.24630073 -0.05695242  0.07709844  0.04731179]
# Accuracy:  96.29629629629629 %
# Error Rate:  3.7037037037037033 %
# Precision:  100.0 %
# Recall:  90.0 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.1379284470666992
# Weights of Model:  [-3.36336286  0.02485222  0.394133    0.42160445  0.11620129 -0.24847068
#   0.32277826 -0.11570602  0.178349   -0.23700284]
# Accuracy:  88.88888888888889 %
# Error Rate:  11.11111111111111 %
# Precision:  85.0 %
# Recall:  85.0 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.12760087427350622
# Weights of Model:  [-3.37179625  0.02612968  0.74501458  0.45644902  0.03678924 -0.52920725
#   0.35975017 -0.13515015  0.03957432  0.00640038]
# Accuracy:  90.74074074074075 %
# Error Rate:  9.25925925925926 %
# Precision:  94.44444444444444 %
# Recall:  80.95238095238095 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.14067315759241547
# Weights of Model:  [-3.35995388  0.07798629  0.22042079  0.55217984  0.08738181 -0.56375954
#   0.34494626  0.12033587  0.1186243   0.06448674]
# Accuracy:  94.44444444444444 %
# Error Rate:  5.555555555555555 %
# Precision:  88.88888888888889 %
# Recall:  94.11764705882352 %
# Number of Iterations = 4999
# Minimum Cost (J) = 0.16214054035516703
# Weights of Model:  [-3.34849174  0.15686051  0.3474699   0.37442191  0.15211829 -0.45550801
#   0.23551201  0.01532976  0.11214515 -0.04646496]
# Accuracy:  98.14814814814815 %
# Error Rate:  1.8518518518518516 %
# Precision:  100.0 %
# Recall:  95.23809523809523 %
#
# average cross validation model accuracy = 93.70370370370371%
#
# Accuracy:  90.74074074074075 %
# Error Rate:  9.25925925925926 %
# Precision:  100.0 %
# Recall:  75.0 %
#
# Accuracy:  79.62962962962963 %
# Error Rate:  20.37037037037037 %
# Precision:  84.61538461538461 %
# Recall:  55.00000000000001 %
#
# Accuracy:  77.77777777777779 %
# Error Rate:  22.22222222222222 %
# Precision:  100.0 %
# Recall:  42.857142857142854 %
#
# Accuracy:  74.07407407407408 %
# Error Rate:  25.925925925925924 %
# Precision:  71.42857142857143 %
# Recall:  29.411764705882355 %
#
# Accuracy:  77.77777777777779 %
# Error Rate:  22.22222222222222 %
# Precision:  90.9090909090909 %
# Recall:  47.61904761904761 %
#
# average cross validation model accuracy = 80.0%
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.12547880691861305
# Weights of Model:  [-3.15662642  0.10594135  0.45881708  0.83802462  0.33887276 -0.95994714
#   0.20010312 -0.0126591   0.07103799 -0.02245342]
# Accuracy:  92.5925925925926 %
# Error Rate:  7.4074074074074066 %
# Precision:  100.0 %
# Recall:  81.81818181818183 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.1255392996862099
# Weights of Model:  [-3.18699368  0.02359364  0.6244644   0.70763728  0.25081164 -0.95872574
#   0.31058177  0.15477723 -0.12575006  0.16215502]
# Accuracy:  96.29629629629629 %
# Error Rate:  3.7037037037037033 %
# Precision:  100.0 %
# Recall:  88.88888888888889 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.1174645406820168
# Weights of Model:  [-3.30965408  0.01038423  0.38373242  0.76094586  0.26217785 -0.70199361
#   0.39193214 -0.06578684  0.02505264  0.12640541]
# Accuracy:  96.29629629629629 %
# Error Rate:  3.7037037037037033 %
# Precision:  85.71428571428571 %
# Recall:  100.0 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.07572325123277625
# Weights of Model:  [-3.17015462 -0.23100094  0.73054341  0.96233475  0.48261088 -0.95707054
#   0.28384376  0.11436518  0.13530749 -0.61947822]
# Accuracy:  81.48148148148148 %
# Error Rate:  18.51851851851852 %
# Precision:  84.61538461538461 %
# Recall:  78.57142857142857 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.12352781841619313
# Weights of Model:  [-3.35938738  0.01802169  0.39700374  0.66066628  0.03960586 -0.80078316
#   0.38060384  0.20026223  0.05373059  0.18927164]
# Accuracy:  96.29629629629629 %
# Error Rate:  3.7037037037037033 %
# Precision:  100.0 %
# Recall:  88.88888888888889 %
#
# average cross validation model accuracy = 92.59259259259258%
#
# Accuracy:  66.66666666666666 %
# Error Rate:  33.33333333333333 %
# Precision:  100.0 %
# Recall:  18.181818181818183 %
#
# Accuracy:  70.37037037037037 %
# Error Rate:  29.629629629629626 %
# Precision:  100.0 %
# Recall:  11.11111111111111 %
#
# Accuracy:  77.77777777777779 %
# Error Rate:  22.22222222222222 %
# Precision:  50.0 %
# Recall:  16.666666666666664 %
#
# Accuracy:  62.96296296296296 %
# Error Rate:  37.03703703703704 %
# Precision:  83.33333333333334 %
# Recall:  35.714285714285715 %
#
# Accuracy:  74.07407407407408 %
# Error Rate:  25.925925925925924 %
# Precision:  100.0 %
# Recall:  22.22222222222222 %
#
# average cross validation model accuracy = 70.37037037037035%

# %%
#The Accuracy of the Test set based on different sizes of the training set
#Need to choose optimum hyper-parameters on Logistic Regression

length = int(len(x_train))
length90 = int(length*0.90)
length80 = int(length*0.80)
length70 = int(length*0.70)
length60 = int(length*0.60)
length50 = int(length*0.50)
length40 = int(length*0.40)
length30 = int(length*0.30)
length20 = int(length*0.20)
length10 = int(length*0.10)

x_train_reduced = [x_train, x_train[:length90,:], x_train[:length80,:], x_train[:length70,:],x_train[:length60,:], x_train[:length50,:], x_train[:length40,:],x_train[:length30,:], x_train[:length20,:], x_train[:length10,:]] 
y_train_reduced = [y_train, y_train[:length90], y_train[:length80], y_train[:length70], y_train[:length60], y_train[:length50], y_train[:length40], y_train[:length30], y_train[:length20], y_train[:length10]]
percentage_of_original = [100, 90, 80, 70, 60, 50, 40, 30, 20, 10]
LR_accuracy = []
NB_accuracy = []


model_LR = LogisticRegression(intercept = True)
for i in range(len(x_train_reduced)):
    w = model_LR.fit(x_train_reduced[i], y_train_reduced[i], num_steps = 5000, learning_rate = 0.01, min_error = 1e-2)            
    
    y_pred = model_LR.predict(x_test, w)
    
    accuracy = model_LR.evaluate_acc(y_test, y_pred)
    LR_accuracy.append(accuracy)


model_NB = MultinomialNaiveBayes()
for i in range(len(x_train_reduced)):
    likelihoods, neg_prior,pos_prior = model_NB.fit(x_train_reduced[i], y_train_reduced[i])
    
    y_pred = model_NB.predict(x_test,likelihoods, neg_prior,pos_prior)
    
    accuracy = model_NB.evaluate_acc(y_test,y_pred)
    NB_accuracy.append(accuracy)
    

#Plot
plt.plot(percentage_of_original, LR_accuracy)
plt.plot(percentage_of_original, NB_accuracy)
plt.title("Training Set Size vs Model Accuracy (Breast Cancer)")
plt.xlabel("Percent of Original Training Size (%)")
plt.ylabel("Model Accuracy on Test Set(%)")
plt.legend(["Logistic Regression", "Naive Bayes"])
# Out:
# Number of Iterations = 4999
# Minimum Cost (J) = 0.14755923457877895
# Weights of Model:  [-3.35963168  0.01325988  0.35246235  0.23285905  0.12537747 -0.33584999
#   0.38521963 -0.06271908  0.20951595  0.07589413]
# Accuracy:  97.08029197080292 %
# Error Rate:  2.9197080291970803 %
# Precision:  97.91666666666666 %
# Recall:  94.0 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.14842450461534942
# Weights of Model:  [-3.38319305  0.02663874  0.38241785  0.20977609  0.10899646 -0.30565464
#   0.34969659 -0.0579119   0.18633252  0.09378719]
# Accuracy:  97.08029197080292 %
# Error Rate:  2.9197080291970803 %
# Precision:  97.91666666666666 %
# Recall:  94.0 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.15069898403480397
# Weights of Model:  [-3.46150369e+00  5.81003315e-02  2.97694512e-01  2.58996588e-01
#   1.09007088e-01 -2.83620485e-01  3.19018838e-01 -2.36923332e-04
#   1.40600527e-01  9.20421665e-02]
# Accuracy:  96.35036496350365 %
# Error Rate:  3.64963503649635 %
# Precision:  95.91836734693877 %
# Recall:  94.0 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.14695021202845088
# Weights of Model:  [-3.37444072  0.02062032  0.29919691  0.35562536  0.16267625 -0.27829217
#   0.33294463 -0.03911626  0.110093   -0.03255577]
# Accuracy:  95.62043795620438 %
# Error Rate:  4.37956204379562 %
# Precision:  95.83333333333334 %
# Recall:  92.0 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.15253276401541668
# Weights of Model:  [-3.33577252  0.04474374  0.27114494  0.37714084  0.11431712 -0.35229764
#   0.34917303 -0.01065333  0.10992612  0.02284398]
# Accuracy:  94.8905109489051 %
# Error Rate:  5.109489051094891 %
# Precision:  95.74468085106383 %
# Recall:  90.0 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.15026105518062857
# Weights of Model:  [-3.35116159  0.10849659  0.41447795  0.3996495   0.08909886 -0.4327876
#   0.29629311 -0.03419662  0.10770149 -0.02052971]
# Accuracy:  96.35036496350365 %
# Error Rate:  3.64963503649635 %
# Precision:  94.11764705882352 %
# Recall:  96.0 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.1628819325839437
# Weights of Model:  [-3.31298668  0.14983851  0.34874043  0.38202182  0.15209603 -0.45559359
#   0.23492569  0.01101057  0.11235279 -0.0458408 ]
# Accuracy:  96.35036496350365 %
# Error Rate:  3.64963503649635 %
# Precision:  94.11764705882352 %
# Recall:  96.0 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.14793981709375822
# Weights of Model:  [-3.33691233  0.13019807  0.02190476  0.60128594  0.23440703 -0.68040691
#   0.27775147  0.29059837  0.07778463  0.0308791 ]
# Accuracy:  92.7007299270073 %
# Error Rate:  7.2992700729927 %
# Precision:  90.0 %
# Recall:  90.0 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.123785062842846
# Weights of Model:  [-3.38428705  0.01734342  0.39048966  0.66542931  0.03993368 -0.78766537
#   0.3814703   0.18991129  0.05275697  0.19152506]
# Accuracy:  94.8905109489051 %
# Error Rate:  5.109489051094891 %
# Precision:  92.15686274509804 %
# Recall:  94.0 %
#
# Number of Iterations = 4999
# Minimum Cost (J) = 0.06023797336126613
# Weights of Model:  [-3.34554949 -0.29620767  0.60361532  0.81623779  0.23820893 -0.59660591
#   0.45610394 -0.09042739  0.4652601  -0.54685927]
# Accuracy:  94.16058394160584 %
# Error Rate:  5.839416058394161 %
# Precision:  92.0 %
# Recall:  92.0 %
#
# Accuracy:  93.43065693430657 %
# Error Rate:  6.569343065693431 %
# Precision:  93.61702127659575 %
# Recall:  88.0 %
#
# Accuracy:  93.43065693430657 %
# Error Rate:  6.569343065693431 %
# Precision:  93.61702127659575 %
# Recall:  88.0 %
#
# Accuracy:  91.97080291970804 %
# Error Rate:  8.02919708029197 %
# Precision:  93.33333333333333 %
# Recall:  84.0 %
#
# Accuracy:  91.97080291970804 %
# Error Rate:  8.02919708029197 %
# Precision:  93.33333333333333 %
# Recall:  84.0 %
#
# Accuracy:  91.24087591240875 %
# Error Rate:  8.75912408759124 %
# Precision:  93.18181818181817 %
# Recall:  82.0 %
#
# Accuracy:  86.86131386861314 %
# Error Rate:  13.138686131386862 %
# Precision:  92.10526315789474 %
# Recall:  70.0 %
#
# Accuracy:  81.02189781021897 %
# Error Rate:  18.97810218978102 %
# Precision:  90.0 %
# Recall:  54.0 %
#
# Accuracy:  74.45255474452554 %
# Error Rate:  25.547445255474454 %
# Precision:  89.47368421052632 %
# Recall:  34.0 %
#
# Accuracy:  66.42335766423358 %
# Error Rate:  33.57664233576642 %
# Precision:  83.33333333333334 %
# Recall:  10.0 %
#
# Accuracy:  53.284671532846716 %
# Error Rate:  46.715328467153284 %
# Precision:  0.0 %
# Recall:  0.0 %

# %%
#Plot
plt.plot(percentage_of_original, LR_accuracy)
plt.plot(percentage_of_original, NB_accuracy)
plt.title("Training Set Size vs Model Accuracy (Breast Cancer)")
plt.xlabel("Percent of Original Training Size (%)")
plt.ylabel("Model Accuracy on Test Set(%)")
plt.legend(["Logistic Regression", "Naive Bayes"])
